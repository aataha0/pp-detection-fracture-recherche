# %%
import os
import requests
from tempfile import NamedTemporaryFile
import zipfile
from xml.etree import cElementTree as ET
from tqdm import tqdm
import torch
import pandas as pd
from skimage import io, transform
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as patches
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, utils

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

plt.ion()   # interactive mode

# %% [markdown]
# Download and extract dataset

# %%
DATASET_URL = os.getenv("DATASET_URL", "https://figshare.com/ndownloader/files/41725659")
DATASET_DIR = os.getenv("DATASET_DIR", "./fracatlas")

def download_and_extract_dataset(merge_images = True):
    if os.path.exists(DATASET_DIR):
        print("Dataset already downloaded.")
        return

    zip_file = ""
    with NamedTemporaryFile(suffix=".zip") as f:
        zip_file = f.name
        print("Downloading dataset...")
        r = requests.get(DATASET_URL)
        print("Saving dataset to", zip_file)
        f.write(r.content)
        os.system(f"file {f.name}")
        
        print("Extracting dataset...")
        with zipfile.ZipFile(zip_file, 'r') as zip_ref:
            zip_ref.extractall(DATASET_DIR)

    for file in os.listdir(os.path.join(DATASET_DIR, "FracAtlas")):
        src_path = os.path.join(DATASET_DIR, "FracAtlas", file)
        dest_path = os.path.join(DATASET_DIR, file)
        os.rename(src_path, dest_path)
    os.rmdir(os.path.join(DATASET_DIR, "FracAtlas"))

    if merge_images:
        for subdir in ["Fractured", "Non_fractured"]:
            src_dir = os.path.join(DATASET_DIR, "images", subdir)
            dest_dir = os.path.join(DATASET_DIR, "images")
            for file in os.listdir(src_dir):
                src_path = os.path.join(src_dir, file)
                dest_path = os.path.join(dest_dir, file)
                os.rename(src_path, dest_path)
            os.rmdir(src_dir)

    return DATASET_DIR

download_and_extract_dataset()
# Out:
# Downloading dataset...
# Saving dataset to /tmp/tmpohsigvt_.zip
# /tmp/tmpohsigvt_.zip: Zip archive data, at least v2.0 to extract, compression method=store
# Extracting dataset...
# './fracatlas'

# %%
# https://stackoverflow.com/a/10077069
from collections import defaultdict

def etree_to_dict(t):
    d = {t.tag: {} if t.attrib else None}
    children = list(t)
    if children:
        dd = defaultdict(list)
        for dc in map(etree_to_dict, children):
            for k, v in dc.items():
                dd[k].append(v)
        d = {t.tag: {k:v[0] if len(v) == 1 else v for k, v in dd.items()}}
    if t.attrib:
        d[t.tag].update(('@' + k, v) for k, v in t.attrib.items())
    if t.text:
        text = t.text.strip()
        if children or t.attrib:
            if text:
              d[t.tag]['#text'] = text
        else:
            d[t.tag] = text
    return d

# %%
def get_image_metadata(image: str):
    if os.path.extsep in image:
        image = os.path.splitext(image)[0]

    annotation_path = os.path.join(
        DATASET_DIR, "Annotations", "PASCAL VOC", image + ".xml"
    )
    with open(annotation_path, "r") as f:
        annotation_etree = ET.XML(f.read())
        annotation = etree_to_dict(annotation_etree)["annotation"]
    print(annotation)

    if annotation.get("object") is None:
        return {
            "filename": annotation["filename"],
            "width": annotation["size"]["width"],
            "height": annotation["size"]["height"],
            "fractured": False,
        }
    else:
        if type(annotation["object"]) is dict:
            annotation["object"] = [annotation["object"]]
        return {
            "filename": annotation["filename"],
            "width": annotation["size"]["width"],
            "height": annotation["size"]["height"],
            "fractured": True,
            "objects": [
                {
                    "fractured": obj["name"] == "fractured",
                    "bbox": {
                        "xmin": obj["bndbox"]["xmin"],
                        "ymin": obj["bndbox"]["ymin"],
                        "xmax": obj["bndbox"]["xmax"],
                        "ymax": obj["bndbox"]["ymax"],
                    },
                } for obj in annotation["object"]
            ],
        }


def dir_len(dir):
    return len(
        [name for name in os.listdir(dir) if os.path.isfile(os.path.join(dir, name))]
    )

# https://christianbernecker.medium.com/convert-bounding-boxes-from-coco-to-pascal-voc-to-yolo-and-back-660dc6178742
def pascal_voc_to_xywh(x1, y1, x2, y2):
    return [x1,y1, x2 - x1, y2 - y1]

# %%
class FracAtlasDataset(Dataset):
    """FracAtlas dataset."""

    def __init__(self, root_dir = DATASET_DIR, transform=None):
        """
        Arguments:
            root_dir (string): The dataset's directory.
            transform (callable, optional): Optional transform to be applied
                on a sample.
        """

        self.root_dir = root_dir
        self.images_dir = os.path.join(root_dir, "images")
        self.images = [get_image_metadata(i) for i in os.listdir(self.images_dir)]
        self.transform = transform

    def __len__(self):
        return dir_len(self.images_dir)

    def __getitem__(self, idx):
        if torch.is_tensor(idx):
            idx = idx.tolist()

        img_name = os.path.join(self.images_dir,
                                self.images[idx]["filename"])
        image = io.imread(img_name)
        print(self.images[idx])
        bbox = [list(obj["bbox"].values()) for obj in self.images[idx]["objects"]] if self.images[idx]["fractured"] else []
        bbox = np.array([bbox], dtype=float).reshape(-1, 4)
        print(bbox)
        sample = {'image': image, 'bbox': bbox}

        if self.transform:
            sample = self.transform(sample)

        return sample

# %%
frac_dataset = FracAtlasDataset()

fig = plt.figure()

# for i in range(9):
i=4
ax = plt.subplot()# 2, 5, i + 1
plt.tight_layout()
ax.set_title('Sample #{}'.format(i))
ax.axis('off')
plt.imshow(frac_dataset[i]["image"])
for bbox in frac_dataset[i]["bbox"]:
  x, y, w, h = pascal_voc_to_xywh(*bbox)
  rect = patches.Rectangle((x, y), w, h, linewidth=1, edgecolor='r', facecolor='none')
  ax.add_patch(rect)

plt.show()
# Out:
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003673.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003928.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000723.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001235.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0004376.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0', 'object': {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '200', 'ymin': '157', 'xmax': '222', 'ymax': '171'}}}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000023.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '2304', 'height': '2880', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000907.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003537.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003857.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003984.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001862.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000112.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '2304', 'height': '2880', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002208.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '64', 'ymin': '230', 'xmax': '98', 'ymax': '253'}}, {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '268', 'ymin': '226', 'xmax': '308', 'ymax': '248'}}]}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002244.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002859.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000812.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001526.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002152.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000809.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001818.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003571.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003776.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002309.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '2304', 'height': '2880', 'depth': '3'}, 'segmented': '0', 'object': {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1144', 'ymin': '1935', 'xmax': '1388', 'ymax': '2151'}}}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001211.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002576.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '72', 'ymin': '175', 'xmax': '105', 'ymax': '200'}}, {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '274', 'ymin': '177', 'xmax': '309', 'ymax': '202'}}]}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000381.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002909.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001426.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002787.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002211.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002565.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '74', 'ymin': '216', 'xmax': '105', 'ymax': '262'}}, {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '290', 'ymin': '203', 'xmax': '317', 'ymax': '224'}}]}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002460.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0', 'object': {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '63', 'ymin': '316', 'xmax': '86', 'ymax': '347'}}}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003181.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0004107.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002267.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002445.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '248', 'ymin': '132', 'xmax': '271', 'ymax': '150'}}, {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '268', 'ymin': '167', 'xmax': '287', 'ymax': '197'}}]}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003392.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0004148.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0
name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '217', 'ymin': '107', 'xmax': '240', 'ymax': '151'}}, {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '246', 'ymin': '96', 'xmax': '262', 'ymax': '132'}}]}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002459.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0', 'object': {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '185', 'ymin': '226', 'xmax': '233', 'ymax': '296'}}}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003016.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002722.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001355.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003182.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0', 'object': {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '147', 'ymin': '107', 'xmax': '198', 'ymax': '218'}}}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000667.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002491.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0', 'object': {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '126', 'ymin': '104', 'xmax': '144', 'ymax': '122'}}}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002056.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001746.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003176.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003202.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003831.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003848.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0', 'object': {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '205', 'ymin': '217', 'xmax': '230', 'ymax': '238'}}}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003034.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0', 'object': {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '168', 'ymin': '100', 'xmax': '186', 'ymax': '123'}}}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003607.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003225.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001688.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000149.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '2304', 'height': '2880', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003027.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001168.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000930.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002085.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0', 'object': {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '156', 'ymin': '221', 'xmax': '168', 'ymax': '245'}}}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001586.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003374.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0', 'object': {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '221', 'ymin': '160', 'xmax': '251', 'ymax': '190'}}}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001371.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001135.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002074.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003360.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000887.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002567.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '73', 'ymin': '134', 'xmax': '87', 'ymax': '170'}}, {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '95', 'ymin': '101', 'xmax': '103', 'ymax': '129'}}, {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '349', 'ymin': '349', 'xmax': '357', 'ymax': '366'}}]}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001376.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003815.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001830.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002643.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002780.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003107.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000606.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002863.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000189.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '2304', 'height': '2880', 'depth': '3'}, 'segmented': '0', 'object': {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '840', 'ymin': '1575', 'xmax': '935', 'ymax': '1656'}}}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000205.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '2304', 'height': '2880', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000135.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '2304', 'height': '2880', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002613.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '140', 'ymin': '174', 'xmax': '186', 'ymax': '270'}}, {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '179', 'ymin': '235', 'xmax': '190', 'ymax': '278'}}]}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002147.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000775.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003028.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003544.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003719.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002443.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0', 'object': [{'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '208', 'ymin': '243', 'xmax': '229', 'ymax': '293'}}, {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '226', 'ymin': '208', 'xmax': '260', 'ymax': '264'}}, {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '222', 'ymin': '139', 'xmax': '237', 'ymax': '185'}}]}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003303.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000050.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '2880', 'height': '2304', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003579.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001114.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002354.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '2304', 'height': '2880', 'depth': '3'}, 'segmented': '0', 'object': {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '1156', 'ymin': '1332', 'xmax': '1355', 'ymax': '1486'}}}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002661.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000863.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002199.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002450.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0', 'object': {'name': 'fractured', 'pose': 'Unspecified', 'truncated': '0', 'difficult': '0', 'bndbox': {'xmin': '116', 'ymin': '156', 'xmax': '168', 'ymax': '192'}}}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000575.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001034.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000388.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0003352.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000664.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0004109.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002963.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0001715.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000711.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002918.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000737.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002139.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0002686.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '454', 'height': '373', 'depth': '3'}, 'segmented': '0'}
# {'folder': 'PASCAL VOC', 'filename': 'IMG0000645.jpg', 'source': {'database': 'MLBFR'}, 'size': {'width': '373', 'height': '454', 'depth': '3'}, 'segmented': '0'}
# {'filename': 'IMG0004376.jpg', 'width': '373', 'height': '454', 'fractured': True, 'objects': [{'fractured': True, 'bbox': {'xmin': '200', 'ymin': '157', 'xmax': '222', 'ymax': '171'}}]}
# [[200. 157. 222. 171.]]
# {'filename': 'IMG0004376.jpg', 'width': '373', 'height': '454', 'fractured': True, 'objects': [{'fractured': True, 'bbox': {'xmin': '200', 'ymin': '157', 'xmax': '222', 'ymax': '171'}}]}
# [[200. 157. 222. 171.]]
