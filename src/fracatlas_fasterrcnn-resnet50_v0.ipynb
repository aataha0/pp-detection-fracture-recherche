# %%
# %pip uninstall torch torchvision torchaudio torchtext torchdata fastai -y
# %pip install torchvision==0.16 torch==2.1

import torch
import torchvision

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

print("pytorch", torch.__version__)
print("torchvision", torchvision.__version__)
# Out:
# Found existing installation: torch 2.0.1+cu118
# Uninstalling torch-2.0.1+cu118:
#   Successfully uninstalled torch-2.0.1+cu118
# Found existing installation: torchvision 0.15.2+cu118
# Uninstalling torchvision-0.15.2+cu118:
#   Successfully uninstalled torchvision-0.15.2+cu118
# Found existing installation: torchaudio 2.0.2+cu118
# Uninstalling torchaudio-2.0.2+cu118:
#   Successfully uninstalled torchaudio-2.0.2+cu118
# Found existing installation: torchtext 0.15.2
# Uninstalling torchtext-0.15.2:
#   Successfully uninstalled torchtext-0.15.2
# Found existing installation: torchdata 0.6.1
# Uninstalling torchdata-0.6.1:
#   Successfully uninstalled torchdata-0.6.1
# Found existing installation: fastai 2.7.12
# Uninstalling fastai-2.7.12:
#   Successfully uninstalled fastai-2.7.12
# Collecting torchvision==0.16
#   Downloading torchvision-0.16.0-cp310-cp310-manylinux1_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 54.4 MB/s eta 0:00:00
# Collecting torch==2.1
#   Downloading torch-2.1.0-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 68.1 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.1)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 68.1 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.1)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 103.6 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.1)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.4 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.1)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.1)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.6 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.1)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 15.9 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.1)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.1)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.2 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.18.1 (from torch==2.1)
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 5.9 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.1)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 13.9 MB/s eta 0:00:00
# Collecting triton==2.1.0 (from torch==2.1)
#   Downloading triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 8.5 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1)
#   Downloading nvidia_nvjitlink_cu12-12.2.140-py3-none-manylinux1_x86_64.whl (20.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 89.3 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.1) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1) (1.3.0)
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 2.0.0
#     Uninstalling triton-2.0.0:
#       Successfully uninstalled triton-2.0.0
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.2.140 nvidia-nvtx-cu12-12.1.105 torch-2.1.0 torchvision-0.16.0 triton-2.1.0
# pytorch 2.1.0+cu121
# torchvision 0.16.0+cu121

# %%
from torchvision.transforms import functional as F
from torchvision.datasets.vision import VisionDataset
from torchvision.datasets.utils import download_and_extract_archive, verify_str_arg
from torchvision.ops import box_area

from PIL import Image

import collections
import os
from xml.etree.ElementTree import Element as ET_Element

try:
    from defusedxml.ElementTree import parse as ET_parse
except ImportError:
    from xml.etree.ElementTree import parse as ET_parse
from typing import Any, Callable, Dict, List, Optional, Tuple


class FracAtlasDetection(VisionDataset):
    """FracAtlas dataset."""

    def __init__(
        self,
        root: str,
        image_set: str = "train",
        # download: bool = False,
        transform: Optional[Callable] = None,
        target_transform: Optional[Callable] = None,
        transforms: Optional[Callable] = None,
    ):
        super().__init__(root, transforms, transform, target_transform)

        valid_image_sets = ["test", "train", "val"]
        self.image_set = verify_str_arg(image_set, "image_set", valid_image_sets)

        self.url = "https://figshare.com/ndownloader/files/41725659"
        self.filename = "fracatlas.zip"

        # if download:
        if not os.path.isdir("data/FracAtlas"):
            os.makedirs("data", exist_ok=True)
            download_and_extract_archive(self.url, os.path.dirname(self.root), filename=self.filename, remove_finished=True)
            for subdir in ["Fractured", "Non_fractured"]:
                dirpath = os.path.join(self.root, "images")
                subdirpath = os.path.join(dirpath, subdir)
                for f in os.listdir(subdirpath):
                    if not f.lower().endswith(".jpg"): continue
                    os.rename(os.path.join(subdirpath, f), os.path.join(dirpath, f))
                os.rmdir(subdirpath)
            print(os.listdir("data"))
        if not os.path.isdir(self.root):
            raise RuntimeError(
                "Dataset not found or corrupted. You can use download=True to download it"
            )

        splits_dir = os.path.join(self.root, "Utilities", "Fracture Split")
        splits_f = os.path.join(splits_dir, image_set.rstrip("\n") + ".csv")
        with open(os.path.join(splits_f)) as f:
            file_names = [
                os.path.splitext(x.strip())[0]
                for x in f.readlines()
                if x.strip() != "image_id"
            ]

        image_dir = os.path.join(self.root, "images")
        self.images = [os.path.join(image_dir, x + ".jpg") for x in file_names]

        target_dir = os.path.join(self.root, "Annotations", "PASCAL VOC")
        self.targets = [os.path.join(target_dir, x + ".xml") for x in file_names]

        assert len(self.images) == len(self.targets)

    @property
    def annotations(self) -> List[str]:
        return self.targets

    def __getitem__(self, index: int) -> Tuple[Any, Any]:
        """
        Args:
            index (int): Index

        Returns:
            tuple: (image, target) where target is a dictionary of the XML tree.
        """
        img = Image.open(self.images[index]).convert("RGB")
        img = F.to_tensor(img)
        voc_dict = self.parse_voc_xml(ET_parse(self.annotations[index]).getroot())
        target = self.voc_dict_to_target(index, voc_dict)
        # print(target)

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self) -> int:
        return len(self.images)

    @staticmethod
    def parse_voc_xml(node: ET_Element) -> Dict[str, Any]:
        voc_dict: Dict[str, Any] = {}
        children = list(node)
        if children:
            def_dic: Dict[str, Any] = collections.defaultdict(list)
            for dc in map(FracAtlasDetection.parse_voc_xml, children):
                for ind, v in dc.items():
                    def_dic[ind].append(v)
            if node.tag == "annotation":
                def_dic["object"] = [def_dic["object"]]
            voc_dict = {
                node.tag: {
                    ind: v[0] if len(v) == 1 else v for ind, v in def_dic.items()
                }
            }
        if node.text:
            text = node.text.strip()
            if not children:
                voc_dict[node.tag] = text
        return voc_dict

    def voc_dict_to_target(self, index: int, item):
        width = int(item["annotation"]["size"]["width"])
        height = int(item["annotation"]["size"]["height"])

        num_fractures = len(item["annotation"]["object"])

        boxes = [
            (
                int(obj["bndbox"]["xmin"]),
                int(obj["bndbox"]["ymin"]),
                int(obj["bndbox"]["xmax"]),
                int(obj["bndbox"]["ymax"]),
            )
            for obj in item["annotation"]["object"]
        ]

        # guard against no boxes via resizing (https://github.com/pytorch/vision/blob/aa32c9376c46eb284f2b091f3eb98aec4fd64b03/references/detection/coco_utils.py#L63-L66)
        boxes = torch.as_tensor(boxes, dtype=torch.float32).reshape(-1, 4)
        boxes[:, 2:] += boxes[:, :2]
        boxes[:, 0::2].clamp_(min=0, max=width)
        boxes[:, 1::2].clamp_(min=0, max=height)

        # extract labels
        labels = torch.ones((num_fractures,), dtype=torch.int64)

        image_id = index
        area = box_area(boxes)

        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_fractures,), dtype=torch.int64)

        # remove invalid boxes (https://github.com/pytorch/vision/blob/aa32c9376c46eb284f2b091f3eb98aec4fd64b03/references/detection/coco_utils.py#L82-L85)
        keep = (boxes[:, 3] > boxes[:, 1]) & (boxes[:, 2] > boxes[:, 0])
        boxes = boxes[keep]

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd

        return target

# %%
from torchvision.transforms import v2 as T


def get_transform(train):
    transforms = []
    # if train:
    #     transforms.append(T.RandomHorizontalFlip(0.5))
    transforms.append(T.ToImage())
    transforms.append(T.ToDtype(torch.float32, scale=True))
    # transforms.append(T.ToDtype(torch.float))
    # transforms.append(T.ToPureTensor())
    return T.Compose(transforms)

# %%
# os.makedirs("lib", exist_ok=True)
if not os.path.exists("engine.py"):
    os.system(
        "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py -O engine.py"
    )
if not os.path.exists("utils.py"):
    os.system(
        "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py -O utils.py"
    )
if not os.path.exists("transforms.py"):
    os.system(
        "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py -O transforms.py"
    )
if not os.path.exists("coco_utils.py"):
    os.system(
        "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py -O coco_utils.py"
    )
if not os.path.exists("coco_eval.py"):
    os.system(
        "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py -O coco_eval.py"
    )

# you also need to tweak them a bit to work with relative imports

# %%
from torchvision.models.detection import fasterrcnn_resnet50_fpn, FasterRCNN_ResNet50_FPN_Weights
from utils import collate_fn

model = fasterrcnn_resnet50_fpn(weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT)
dataset = FracAtlasDetection("data/FracAtlas", image_set="train", transform=get_transform(train=True))
data_loader = torch.utils.data.DataLoader(
  dataset,
  batch_size=2,
  shuffle=True,
  num_workers=4,
  collate_fn=collate_fn,
)

# For Training
images, targets = next(iter(data_loader))
images = list(image for image in images)
targets = [{k: v for k, v in t.items()} for t in targets]
output = model(images, targets)  # Returns losses and detections
print(output)

# For inference
model.eval()
x = [torch.rand(3, 300, 400), torch.rand(3, 500, 400)]
predictions = model(x)  # Returns predictions
print(predictions[0])
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_resnet50_fpn_coco-258fb6c6.pth
# 100%|██████████| 160M/160M [00:02<00:00, 68.5MB/s]
# Downloading https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/41725659/FracAtlas.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20231010/eu-west-1/s3/aws4_request&X-Amz-Date=20231010T211517Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=daf7d76c80786744b82f5107ddeba3d011a5f24e99b99cd3626d9c05179349a3 to data/fracatlas.zip
# 100%|██████████| 338412751/338412751 [00:11<00:00, 29487072.21it/s]
# Extracting data/fracatlas.zip to data
# ['FracAtlas']
# {'loss_classifier': tensor(0.3163, grad_fn=<NllLossBackward0>), 'loss_box_reg': tensor(0.1430, grad_fn=<DivBackward0>), 'loss_objectness': tensor(0.0559, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>), 'loss_rpn_box_reg': tensor(0.0157, grad_fn=<DivBackward0>)}
# {'boxes': tensor([], size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], dtype=torch.int64), 'scores': tensor([], grad_fn=<IndexBackward0>)}

# %%
from engine import train_one_epoch, evaluate
from utils import collate_fn

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print("device:", device)

# use our dataset and defined transformations
dataset = FracAtlasDetection('data/FracAtlas', image_set="train", transform=get_transform(train=True))
dataset_test = FracAtlasDetection('data/FracAtlas', image_set="test", transform=get_transform(train=False))

# split the dataset in train and test set
# indices = torch.randperm(len(dataset)).tolist()
# dataset = torch.utils.data.Subset(dataset, indices[:-50])
# dataset_test = torch.utils.data.Subset(dataset_test, indices[-50:])

# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=2,
    shuffle=True,
    num_workers=4,
    collate_fn=collate_fn,
)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test,
    batch_size=1,
    shuffle=False,
    num_workers=4,
    collate_fn=collate_fn,
)

model = fasterrcnn_resnet50_fpn(weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
    params,
    lr=0.005,
    momentum=0.9,
    weight_decay=0.0005
)

# and a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=3,
    gamma=0.1
)

# let's train it for 5 epochs
num_epochs = 5

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)

print("That's it!")

print("Saving")
torch.save(model, 'fracatlas_fasterrcnn-resnet50_v0.pth')
print("Saved")
# Out:
# device: cuda
# Epoch: [0]  [  0/287]  eta: 0:56:25  lr: 0.000022  loss: 0.6530 (0.6530)  loss_classifier: 0.3595 (0.3595)  loss_box_reg: 0.2382 (0.2382)  loss_objectness: 0.0434 (0.0434)  loss_rpn_box_reg: 0.0120 (0.0120)  time: 11.7955  data: 1.7431  max mem: 2096
# Epoch: [0]  [ 10/287]  eta: 0:06:58  lr: 0.000197  loss: 0.6530 (0.6461)  loss_classifier: 0.3595 (0.3548)  loss_box_reg: 0.2382 (0.2391)  loss_objectness: 0.0251 (0.0339)  loss_rpn_box_reg: 0.0174 (0.0182)  time: 1.5106  data: 0.1728  max mem: 2537
# Epoch: [0]  [ 20/287]  eta: 0:04:32  lr: 0.000372  loss: 0.5304 (0.5753)  loss_classifier: 0.2588 (0.2933)  loss_box_reg: 0.2196 (0.2327)  loss_objectness: 0.0243 (0.0342)  loss_rpn_box_reg: 0.0110 (0.0151)  time: 0.4815  data: 0.0194  max mem: 2538
# Epoch: [0]  [ 30/287]  eta: 0:03:39  lr: 0.000546  loss: 0.3627 (0.5046)  loss_classifier: 0.1589 (0.2494)  loss_box_reg: 0.1814 (0.2134)  loss_objectness: 0.0167 (0.0289)  loss_rpn_box_reg: 0.0083 (0.0129)  time: 0.4950  data: 0.0221  max mem: 2680
# Epoch: [0]  [ 40/287]  eta: 0:03:09  lr: 0.000721  loss: 0.3346 (0.4559)  loss_classifier: 0.1292 (0.2177)  loss_box_reg: 0.1521 (0.1981)  loss_objectness: 0.0156 (0.0272)  loss_rpn_box_reg: 0.0098 (0.0130)  time: 0.5041  data: 0.0221  max mem: 2680
# Epoch: [0]  [ 50/287]  eta: 0:02:48  lr: 0.000896  loss: 0.2860 (0.4270)  loss_classifier: 0.1147 (0.1960)  loss_box_reg: 0.1437 (0.1916)  loss_objectness: 0.0181 (0.0268)  loss_rpn_box_reg: 0.0111 (0.0127)  time: 0.4838  data: 0.0187  max mem: 2680
# Epoch: [0]  [ 60/287]  eta: 0:02:32  lr: 0.001070  loss: 0.3011 (0.4089)  loss_classifier: 0.1086 (0.1832)  loss_box_reg: 0.1522 (0.1875)  loss_objectness: 0.0211 (0.0259)  loss_rpn_box_reg: 0.0110 (0.0123)  time: 0.4703  data: 0.0105  max mem: 2680
# Epoch: [0]  [ 70/287]  eta: 0:02:19  lr: 0.001245  loss: 0.3011 (0.3925)  loss_classifier: 0.1088 (0.1730)  loss_box_reg: 0.1514 (0.1835)  loss_objectness: 0.0158 (0.0245)  loss_rpn_box_reg: 0.0084 (0.0116)  time: 0.4744  data: 0.0117  max mem: 2680
# Epoch: [0]  [ 80/287]  eta: 0:02:09  lr: 0.001420  loss: 0.2888 (0.3802)  loss_classifier: 0.1002 (0.1645)  loss_box_reg: 0.1466 (0.1810)  loss_objectness: 0.0134 (0.0237)  loss_rpn_box_reg: 0.0057 (0.0110)  time: 0.4864  data: 0.0168  max mem: 2680
# Epoch: [0]  [ 90/287]  eta: 0:02:00  lr: 0.001594  loss: 0.2776 (0.3655)  loss_classifier: 0.0992 (0.1571)  loss_box_reg: 0.1380 (0.1758)  loss_objectness: 0.0102 (0.0223)  loss_rpn_box_reg: 0.0054 (0.0104)  time: 0.4934  data: 0.0158  max mem: 2680
# Epoch: [0]  [100/287]  eta: 0:01:52  lr: 0.001769  loss: 0.2865 (0.3594)  loss_classifier: 0.0992 (0.1520)  loss_box_reg: 0.1484 (0.1760)  loss_objectness: 0.0102 (0.0213)  loss_rpn_box_reg: 0.0054 (0.0100)  time: 0.5096  data: 0.0145  max mem: 3288
# Epoch: [0]  [110/287]  eta: 0:01:45  lr: 0.001944  loss: 0.2955 (0.3560)  loss_classifier: 0.1070 (0.1489)  loss_box_reg: 0.1692 (0.1766)  loss_objectness: 0.0122 (0.0206)  loss_rpn_box_reg: 0.0066 (0.0099)  time: 0.5256  data: 0.0175  max mem: 3288
# Epoch: [0]  [120/287]  eta: 0:01:38  lr: 0.002118  loss: 0.2849 (0.3499)  loss_classifier: 0.1022 (0.1448)  loss_box_reg: 0.1619 (0.1747)  loss_objectness: 0.0128 (0.0206)  loss_rpn_box_reg: 0.0077 (0.0098)  time: 0.5154  data: 0.0191  max mem: 3288
# Epoch: [0]  [130/287]  eta: 0:01:31  lr: 0.002293  loss: 0.2475 (0.3444)  loss_classifier: 0.0874 (0.1414)  loss_box_reg: 0.1454 (0.1723)  loss_objectness: 0.0147 (0.0211)  loss_rpn_box_reg: 0.0049 (0.0096)  time: 0.5119  data: 0.0176  max mem: 3288
# Epoch: [0]  [140/287]  eta: 0:01:25  lr: 0.002468  loss: 0.2473 (0.3392)  loss_classifier: 0.0892 (0.1385)  loss_box_reg: 0.1400 (0.1707)  loss_objectness: 0.0127 (0.0206)  loss_rpn_box_reg: 0.0044 (0.0093)  time: 0.5449  data: 0.0266  max mem: 3288
# Epoch: [0]  [150/287]  eta: 0:01:19  lr: 0.002642  loss: 0.2344 (0.3327)  loss_classifier: 0.0897 (0.1357)  loss_box_reg: 0.1229 (0.1677)  loss_objectness: 0.0138 (0.0203)  loss_rpn_box_reg: 0.0044 (0.0090)  time: 0.5533  data: 0.0244  max mem: 3288
# Epoch: [0]  [160/287]  eta: 0:01:12  lr: 0.002817  loss: 0.2291 (0.3261)  loss_classifier: 0.0865 (0.1329)  loss_box_reg: 0.1191 (0.1648)  loss_objectness: 0.0101 (0.0197)  loss_rpn_box_reg: 0.0042 (0.0087)  time: 0.5152  data: 0.0134  max mem: 3288
# Epoch: [0]  [170/287]  eta: 0:01:06  lr: 0.002992  loss: 0.2269 (0.3200)  loss_classifier: 0.0829 (0.1301)  loss_box_reg: 0.1191 (0.1622)  loss_objectness: 0.0100 (0.0192)  loss_rpn_box_reg: 0.0039 (0.0084)  time: 0.5124  data: 0.0155  max mem: 3288
# Epoch: [0]  [180/287]  eta: 0:01:00  lr: 0.003166  loss: 0.2454 (0.3171)  loss_classifier: 0.0866 (0.1283)  loss_box_reg: 0.1287 (0.1618)  loss_objectness: 0.0081 (0.0186)  loss_rpn_box_reg: 0.0042 (0.0083)  time: 0.5159  data: 0.0158  max mem: 3288
# Epoch: [0]  [190/287]  eta: 0:00:54  lr: 0.003341  loss: 0.2511 (0.3159)  loss_classifier: 0.0962 (0.1275)  loss_box_reg: 0.1466 (0.1620)  loss_objectness: 0.0067 (0.0182)  loss_rpn_box_reg: 0.0043 (0.0082)  time: 0.5165  data: 0.0125  max mem: 3288
# Epoch: [0]  [200/287]  eta: 0:00:49  lr: 0.003515  loss: 0.2409 (0.3125)  loss_classifier: 0.0894 (0.1257)  loss_box_reg: 0.1340 (0.1609)  loss_objectness: 0.0088 (0.0178)  loss_rpn_box_reg: 0.0043 (0.0080)  time: 0.5312  data: 0.0145  max mem: 3288
# Epoch: [0]  [210/287]  eta: 0:00:43  lr: 0.003690  loss: 0.2350 (0.3094)  loss_classifier: 0.0894 (0.1242)  loss_box_reg: 0.1333 (0.1598)  loss_objectness: 0.0078 (0.0176)  loss_rpn_box_reg: 0.0044 (0.0079)  time: 0.5220  data: 0.0137  max mem: 3288
# Epoch: [0]  [220/287]  eta: 0:00:37  lr: 0.003865  loss: 0.2310 (0.3061)  loss_classifier: 0.0796 (0.1226)  loss_box_reg: 0.1241 (0.1583)  loss_objectness: 0.0094 (0.0174)  loss_rpn_box_reg: 0.0047 (0.0077)  time: 0.5220  data: 0.0131  max mem: 3288
# Epoch: [0]  [230/287]  eta: 0:00:31  lr: 0.004039  loss: 0.2117 (0.3029)  loss_classifier: 0.0807 (0.1211)  loss_box_reg: 0.1229 (0.1570)  loss_objectness: 0.0111 (0.0172)  loss_rpn_box_reg: 0.0035 (0.0076)  time: 0.5397  data: 0.0167  max mem: 3288
# Epoch: [0]  [240/287]  eta: 0:00:26  lr: 0.004214  loss: 0.2384 (0.3014)  loss_classifier: 0.0865 (0.1203)  loss_box_reg: 0.1229 (0.1560)  loss_objectness: 0.0100 (0.0175)  loss_rpn_box_reg: 0.0035 (0.0075)  time: 0.5260  data: 0.0135  max mem: 3288
# Epoch: [0]  [250/287]  eta: 0:00:20  lr: 0.004389  loss: 0.2449 (0.2993)  loss_classifier: 0.0860 (0.1191)  loss_box_reg: 0.1391 (0.1556)  loss_objectness: 0.0098 (0.0172)  loss_rpn_box_reg: 0.0042 (0.0075)  time: 0.5268  data: 0.0160  max mem: 3288
# Epoch: [0]  [260/287]  eta: 0:00:14  lr: 0.004563  loss: 0.2453 (0.2982)  loss_classifier: 0.0850 (0.1181)  loss_box_reg: 0.1453 (0.1557)  loss_objectness: 0.0105 (0.0171)  loss_rpn_box_reg: 0.0048 (0.0074)  time: 0.5291  data: 0.0154  max mem: 3288
# Epoch: [0]  [270/287]  eta: 0:00:09  lr: 0.004738  loss: 0.2668 (0.2977)  loss_classifier: 0.0874 (0.1176)  loss_box_reg: 0.1437 (0.1554)  loss_objectness: 0.0105 (0.0174)  loss_rpn_box_reg: 0.0050 (0.0074)  time: 0.5198  data: 0.0118  max mem: 3288
# Epoch: [0]  [280/287]  eta: 0:00:03  lr: 0.004913  loss: 0.2499 (0.2957)  loss_classifier: 0.0905 (0.1167)  loss_box_reg: 0.1300 (0.1545)  loss_objectness: 0.0082 (0.0172)  loss_rpn_box_reg: 0.0059 (0.0073)  time: 0.5414  data: 0.0175  max mem: 3288
# Epoch: [0]  [286/287]  eta: 0:00:00  lr: 0.005000  loss: 0.2182 (0.2936)  loss_classifier: 0.0905 (0.1158)  loss_box_reg: 0.1181 (0.1534)  loss_objectness: 0.0081 (0.0171)  loss_rpn_box_reg: 0.0037 (0.0073)  time: 0.5289  data: 0.0160  max mem: 3288
# Epoch: [0] Total time: 0:02:38 (0.5537 s / it)
# creating index...
# index created!
# Test:  [ 0/61]  eta: 0:00:39  model_time: 0.1705 (0.1705)  evaluator_time: 0.0116 (0.0116)  time: 0.6472  data: 0.4633  max mem: 3288
# Test:  [60/61]  eta: 0:00:00  model_time: 0.0990 (0.1011)  evaluator_time: 0.0020 (0.0019)  time: 0.1108  data: 0.0082  max mem: 3288
# Test: Total time: 0:00:07 (0.1241 s / it)
# Averaged stats: model_time: 0.0990 (0.1011)  evaluator_time: 0.0020 (0.0019)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.219
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.651
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.108
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.035
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.223
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.269
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.434
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.464
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.800
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.459
# Epoch: [1]  [  0/287]  eta: 0:06:24  lr: 0.005000  loss: 0.1008 (0.1008)  loss_classifier: 0.0297 (0.0297)  loss_box_reg: 0.0637 (0.0637)  loss_objectness: 0.0067 (0.0067)  loss_rpn_box_reg: 0.0007 (0.0007)  time: 1.3406  data: 0.7532  max mem: 3288
# Epoch: [1]  [ 10/287]  eta: 0:02:51  lr: 0.005000  loss: 0.2231 (0.2163)  loss_classifier: 0.0955 (0.0863)  loss_box_reg: 0.1027 (0.1098)  loss_objectness: 0.0147 (0.0159)  loss_rpn_box_reg: 0.0041 (0.0044)  time: 0.6208  data: 0.0856  max mem: 3288
# Epoch: [1]  [ 20/287]  eta: 0:02:31  lr: 0.005000  loss: 0.2532 (0.2689)  loss_classifier: 0.1003 (0.1042)  loss_box_reg: 0.1308 (0.1379)  loss_objectness: 0.0147 (0.0202)  loss_rpn_box_reg: 0.0058 (0.0065)  time: 0.5296  data: 0.0175  max mem: 3288
# Epoch: [1]  [ 30/287]  eta: 0:02:23  lr: 0.005000  loss: 0.2640 (0.2684)  loss_classifier: 0.1047 (0.1042)  loss_box_reg: 0.1416 (0.1377)  loss_objectness: 0.0159 (0.0192)  loss_rpn_box_reg: 0.0069 (0.0072)  time: 0.5244  data: 0.0183  max mem: 3288
# Epoch: [1]  [ 40/287]  eta: 0:02:16  lr: 0.005000  loss: 0.2443 (0.2625)  loss_classifier: 0.0997 (0.1025)  loss_box_reg: 0.1304 (0.1348)  loss_objectness: 0.0140 (0.0179)  loss_rpn_box_reg: 0.0059 (0.0073)  time: 0.5330  data: 0.0172  max mem: 3288
# Epoch: [1]  [ 50/287]  eta: 0:02:08  lr: 0.005000  loss: 0.2258 (0.2623)  loss_classifier: 0.0871 (0.1017)  loss_box_reg: 0.1276 (0.1363)  loss_objectness: 0.0129 (0.0172)  loss_rpn_box_reg: 0.0057 (0.0071)  time: 0.5221  data: 0.0135  max mem: 3288
# Epoch: [1]  [ 60/287]  eta: 0:02:03  lr: 0.005000  loss: 0.2690 (0.2625)  loss_classifier: 0.0899 (0.1002)  loss_box_reg: 0.1526 (0.1393)  loss_objectness: 0.0079 (0.0162)  loss_rpn_box_reg: 0.0043 (0.0067)  time: 0.5338  data: 0.0203  max mem: 3288
# Epoch: [1]  [ 70/287]  eta: 0:01:57  lr: 0.005000  loss: 0.2498 (0.2605)  loss_classifier: 0.0893 (0.0994)  loss_box_reg: 0.1415 (0.1399)  loss_objectness: 0.0075 (0.0148)  loss_rpn_box_reg: 0.0039 (0.0064)  time: 0.5363  data: 0.0214  max mem: 3288
# Epoch: [1]  [ 80/287]  eta: 0:01:52  lr: 0.005000  loss: 0.2108 (0.2561)  loss_classifier: 0.0693 (0.0973)  loss_box_reg: 0.1298 (0.1386)  loss_objectness: 0.0075 (0.0140)  loss_rpn_box_reg: 0.0037 (0.0061)  time: 0.5312  data: 0.0154  max mem: 3288
# Epoch: [1]  [ 90/287]  eta: 0:01:46  lr: 0.005000  loss: 0.2185 (0.2582)  loss_classifier: 0.0840 (0.0980)  loss_box_reg: 0.1275 (0.1400)  loss_objectness: 0.0094 (0.0141)  loss_rpn_box_reg: 0.0039 (0.0062)  time: 0.5338  data: 0.0176  max mem: 3288
# Epoch: [1]  [100/287]  eta: 0:01:40  lr: 0.005000  loss: 0.2185 (0.2533)  loss_classifier: 0.0790 (0.0960)  loss_box_reg: 0.1227 (0.1378)  loss_objectness: 0.0098 (0.0136)  loss_rpn_box_reg: 0.0044 (0.0060)  time: 0.5203  data: 0.0172  max mem: 3288
# Epoch: [1]  [110/287]  eta: 0:01:35  lr: 0.005000  loss: 0.2244 (0.2535)  loss_classifier: 0.0810 (0.0959)  loss_box_reg: 0.1230 (0.1386)  loss_objectness: 0.0082 (0.0132)  loss_rpn_box_reg: 0.0034 (0.0059)  time: 0.5266  data: 0.0161  max mem: 3288
# Epoch: [1]  [120/287]  eta: 0:01:29  lr: 0.005000  loss: 0.2179 (0.2499)  loss_classifier: 0.0810 (0.0940)  loss_box_reg: 0.1239 (0.1375)  loss_objectness: 0.0065 (0.0128)  loss_rpn_box_reg: 0.0028 (0.0056)  time: 0.5363  data: 0.0153  max mem: 3288
# Epoch: [1]  [130/287]  eta: 0:01:24  lr: 0.005000  loss: 0.2398 (0.2535)  loss_classifier: 0.0926 (0.0956)  loss_box_reg: 0.1285 (0.1394)  loss_objectness: 0.0096 (0.0128)  loss_rpn_box_reg: 0.0038 (0.0056)  time: 0.5221  data: 0.0116  max mem: 3288
# Epoch: [1]  [140/287]  eta: 0:01:18  lr: 0.005000  loss: 0.2519 (0.2519)  loss_classifier: 0.0902 (0.0946)  loss_box_reg: 0.1481 (0.1393)  loss_objectness: 0.0096 (0.0125)  loss_rpn_box_reg: 0.0045 (0.0055)  time: 0.5188  data: 0.0121  max mem: 3288
# Epoch: [1]  [150/287]  eta: 0:01:13  lr: 0.005000  loss: 0.2260 (0.2520)  loss_classifier: 0.0824 (0.0949)  loss_box_reg: 0.1444 (0.1393)  loss_objectness: 0.0080 (0.0123)  loss_rpn_box_reg: 0.0038 (0.0055)  time: 0.5222  data: 0.0137  max mem: 3288
# Epoch: [1]  [160/287]  eta: 0:01:08  lr: 0.005000  loss: 0.2260 (0.2530)  loss_classifier: 0.0881 (0.0952)  loss_box_reg: 0.1353 (0.1399)  loss_objectness: 0.0080 (0.0123)  loss_rpn_box_reg: 0.0038 (0.0055)  time: 0.5474  data: 0.0198  max mem: 3288
# Epoch: [1]  [170/287]  eta: 0:01:03  lr: 0.005000  loss: 0.2310 (0.2534)  loss_classifier: 0.0853 (0.0953)  loss_box_reg: 0.1334 (0.1405)  loss_objectness: 0.0080 (0.0121)  loss_rpn_box_reg: 0.0055 (0.0055)  time: 0.5754  data: 0.0255  max mem: 3288
# Epoch: [1]  [180/287]  eta: 0:00:57  lr: 0.005000  loss: 0.2346 (0.2530)  loss_classifier: 0.0847 (0.0948)  loss_box_reg: 0.1349 (0.1408)  loss_objectness: 0.0054 (0.0120)  loss_rpn_box_reg: 0.0053 (0.0055)  time: 0.5460  data: 0.0184  max mem: 3288
# Epoch: [1]  [190/287]  eta: 0:00:52  lr: 0.005000  loss: 0.2700 (0.2542)  loss_classifier: 0.0850 (0.0951)  loss_box_reg: 0.1577 (0.1418)  loss_objectness: 0.0053 (0.0117)  loss_rpn_box_reg: 0.0049 (0.0056)  time: 0.5337  data: 0.0181  max mem: 3288
# Epoch: [1]  [200/287]  eta: 0:00:46  lr: 0.005000  loss: 0.2747 (0.2549)  loss_classifier: 0.0938 (0.0952)  loss_box_reg: 0.1615 (0.1427)  loss_objectness: 0.0053 (0.0115)  loss_rpn_box_reg: 0.0048 (0.0055)  time: 0.5426  data: 0.0220  max mem: 3288
# Epoch: [1]  [210/287]  eta: 0:00:41  lr: 0.005000  loss: 0.2684 (0.2551)  loss_classifier: 0.0978 (0.0956)  loss_box_reg: 0.1525 (0.1425)  loss_objectness: 0.0061 (0.0116)  loss_rpn_box_reg: 0.0046 (0.0055)  time: 0.5170  data: 0.0164  max mem: 3288
# Epoch: [1]  [220/287]  eta: 0:00:35  lr: 0.005000  loss: 0.2589 (0.2550)  loss_classifier: 0.0926 (0.0953)  loss_box_reg: 0.1450 (0.1428)  loss_objectness: 0.0058 (0.0114)  loss_rpn_box_reg: 0.0038 (0.0054)  time: 0.5265  data: 0.0182  max mem: 3288
# Epoch: [1]  [230/287]  eta: 0:00:30  lr: 0.005000  loss: 0.2163 (0.2528)  loss_classifier: 0.0787 (0.0942)  loss_box_reg: 0.1375 (0.1420)  loss_objectness: 0.0059 (0.0113)  loss_rpn_box_reg: 0.0032 (0.0053)  time: 0.5454  data: 0.0169  max mem: 3288
# Epoch: [1]  [240/287]  eta: 0:00:25  lr: 0.005000  loss: 0.2068 (0.2526)  loss_classifier: 0.0680 (0.0940)  loss_box_reg: 0.1236 (0.1422)  loss_objectness: 0.0069 (0.0112)  loss_rpn_box_reg: 0.0019 (0.0052)  time: 0.5298  data: 0.0105  max mem: 3288
# Epoch: [1]  [250/287]  eta: 0:00:19  lr: 0.005000  loss: 0.2445 (0.2536)  loss_classifier: 0.0931 (0.0948)  loss_box_reg: 0.1270 (0.1423)  loss_objectness: 0.0086 (0.0113)  loss_rpn_box_reg: 0.0031 (0.0052)  time: 0.5275  data: 0.0133  max mem: 3288
# Epoch: [1]  [260/287]  eta: 0:00:14  lr: 0.005000  loss: 0.2425 (0.2547)  loss_classifier: 0.0926 (0.0953)  loss_box_reg: 0.1427 (0.1427)  loss_objectness: 0.0101 (0.0114)  loss_rpn_box_reg: 0.0045 (0.0052)  time: 0.5283  data: 0.0176  max mem: 3288
# Epoch: [1]  [270/287]  eta: 0:00:09  lr: 0.005000  loss: 0.2353 (0.2540)  loss_classifier: 0.0852 (0.0949)  loss_box_reg: 0.1355 (0.1426)  loss_objectness: 0.0073 (0.0113)  loss_rpn_box_reg: 0.0040 (0.0052)  time: 0.5305  data: 0.0151  max mem: 3288
# Epoch: [1]  [280/287]  eta: 0:00:03  lr: 0.005000  loss: 0.2553 (0.2550)  loss_classifier: 0.0852 (0.0952)  loss_box_reg: 0.1355 (0.1432)  loss_objectness: 0.0098 (0.0113)  loss_rpn_box_reg: 0.0044 (0.0052)  time: 0.5326  data: 0.0109  max mem: 3288
# Epoch: [1]  [286/287]  eta: 0:00:00  lr: 0.005000  loss: 0.2759 (0.2559)  loss_classifier: 0.0908 (0.0954)  loss_box_reg: 0.1619 (0.1439)  loss_objectness: 0.0107 (0.0114)  loss_rpn_box_reg: 0.0044 (0.0052)  time: 0.5212  data: 0.0093  max mem: 3288
# Epoch: [1] Total time: 0:02:33 (0.5364 s / it)
# creating index...
# index created!
# Test:  [ 0/61]  eta: 0:00:35  model_time: 0.1037 (0.1037)  evaluator_time: 0.0023 (0.0023)  time: 0.5746  data: 0.4669  max mem: 3288
# Test:  [60/61]  eta: 0:00:00  model_time: 0.1016 (0.1017)  evaluator_time: 0.0015 (0.0017)  time: 0.1077  data: 0.0032  max mem: 3288
# Test: Total time: 0:00:07 (0.1243 s / it)
# Averaged stats: model_time: 0.1016 (0.1017)  evaluator_time: 0.0015 (0.0017)
# Accumulating evaluation results...
# DONE (t=0.04s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.213
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.601
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.106
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.217
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.236
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.421
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.443
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.450
# Epoch: [2]  [  0/287]  eta: 0:11:07  lr: 0.005000  loss: 0.3198 (0.3198)  loss_classifier: 0.0981 (0.0981)  loss_box_reg: 0.2065 (0.2065)  loss_objectness: 0.0096 (0.0096)  loss_rpn_box_reg: 0.0055 (0.0055)  time: 2.3267  data: 1.6884  max mem: 3288
# Epoch: [2]  [ 10/287]  eta: 0:03:11  lr: 0.005000  loss: 0.2553 (0.2723)  loss_classifier: 0.0962 (0.0985)  loss_box_reg: 0.1533 (0.1583)  loss_objectness: 0.0096 (0.0096)  loss_rpn_box_reg: 0.0050 (0.0059)  time: 0.6907  data: 0.1673  max mem: 3288
# Epoch: [2]  [ 20/287]  eta: 0:02:41  lr: 0.005000  loss: 0.2538 (0.2701)  loss_classifier: 0.0944 (0.0974)  loss_box_reg: 0.1433 (0.1560)  loss_objectness: 0.0096 (0.0112)  loss_rpn_box_reg: 0.0039 (0.0056)  time: 0.5191  data: 0.0125  max mem: 3288
# Epoch: [2]  [ 30/287]  eta: 0:02:31  lr: 0.005000  loss: 0.2538 (0.2626)  loss_classifier: 0.0831 (0.0945)  loss_box_reg: 0.1433 (0.1533)  loss_objectness: 0.0067 (0.0097)  loss_rpn_box_reg: 0.0028 (0.0051)  time: 0.5316  data: 0.0143  max mem: 3288
# Epoch: [2]  [ 40/287]  eta: 0:02:21  lr: 0.005000  loss: 0.2646 (0.2676)  loss_classifier: 0.0980 (0.0986)  loss_box_reg: 0.1455 (0.1533)  loss_objectness: 0.0067 (0.0104)  loss_rpn_box_reg: 0.0046 (0.0053)  time: 0.5423  data: 0.0157  max mem: 3288
# Epoch: [2]  [ 50/287]  eta: 0:02:13  lr: 0.005000  loss: 0.2423 (0.2628)  loss_classifier: 0.0970 (0.0958)  loss_box_reg: 0.1455 (0.1519)  loss_objectness: 0.0076 (0.0100)  loss_rpn_box_reg: 0.0044 (0.0051)  time: 0.5266  data: 0.0114  max mem: 3288
# Epoch: [2]  [ 60/287]  eta: 0:02:07  lr: 0.005000  loss: 0.2200 (0.2595)  loss_classifier: 0.0757 (0.0956)  loss_box_reg: 0.1280 (0.1479)  loss_objectness: 0.0094 (0.0111)  loss_rpn_box_reg: 0.0030 (0.0049)  time: 0.5392  data: 0.0173  max mem: 3288
# Epoch: [2]  [ 70/287]  eta: 0:02:00  lr: 0.005000  loss: 0.2111 (0.2571)  loss_classifier: 0.0798 (0.0957)  loss_box_reg: 0.1206 (0.1459)  loss_objectness: 0.0105 (0.0109)  loss_rpn_box_reg: 0.0027 (0.0046)  time: 0.5407  data: 0.0204  max mem: 3288
# Epoch: [2]  [ 80/287]  eta: 0:01:54  lr: 0.005000  loss: 0.2199 (0.2514)  loss_classifier: 0.0729 (0.0936)  loss_box_reg: 0.1219 (0.1430)  loss_objectness: 0.0076 (0.0104)  loss_rpn_box_reg: 0.0030 (0.0045)  time: 0.5191  data: 0.0142  max mem: 3288
# Epoch: [2]  [ 90/287]  eta: 0:01:48  lr: 0.005000  loss: 0.2283 (0.2556)  loss_classifier: 0.0729 (0.0941)  loss_box_reg: 0.1477 (0.1467)  loss_objectness: 0.0065 (0.0102)  loss_rpn_box_reg: 0.0034 (0.0045)  time: 0.5200  data: 0.0165  max mem: 3288
# Epoch: [2]  [100/287]  eta: 0:01:42  lr: 0.005000  loss: 0.2656 (0.2542)  loss_classifier: 0.0974 (0.0942)  loss_box_reg: 0.1518 (0.1451)  loss_objectness: 0.0095 (0.0104)  loss_rpn_box_reg: 0.0042 (0.0045)  time: 0.5214  data: 0.0155  max mem: 3288
# Epoch: [2]  [110/287]  eta: 0:01:36  lr: 0.005000  loss: 0.2257 (0.2532)  loss_classifier: 0.0854 (0.0936)  loss_box_reg: 0.1379 (0.1449)  loss_objectness: 0.0103 (0.0104)  loss_rpn_box_reg: 0.0036 (0.0044)  time: 0.5242  data: 0.0118  max mem: 3288
# Epoch: [2]  [120/287]  eta: 0:01:30  lr: 0.005000  loss: 0.2297 (0.2539)  loss_classifier: 0.0802 (0.0938)  loss_box_reg: 0.1416 (0.1456)  loss_objectness: 0.0084 (0.0101)  loss_rpn_box_reg: 0.0036 (0.0044)  time: 0.5275  data: 0.0160  max mem: 3288
# Epoch: [2]  [130/287]  eta: 0:01:25  lr: 0.005000  loss: 0.2461 (0.2519)  loss_classifier: 0.0859 (0.0926)  loss_box_reg: 0.1458 (0.1452)  loss_objectness: 0.0054 (0.0097)  loss_rpn_box_reg: 0.0037 (0.0044)  time: 0.5357  data: 0.0168  max mem: 3288
# Epoch: [2]  [140/287]  eta: 0:01:19  lr: 0.005000  loss: 0.2461 (0.2549)  loss_classifier: 0.0920 (0.0942)  loss_box_reg: 0.1458 (0.1461)  loss_objectness: 0.0058 (0.0100)  loss_rpn_box_reg: 0.0045 (0.0045)  time: 0.5491  data: 0.0195  max mem: 3288
# Epoch: [2]  [150/287]  eta: 0:01:14  lr: 0.005000  loss: 0.2455 (0.2521)  loss_classifier: 0.0930 (0.0936)  loss_box_reg: 0.1109 (0.1441)  loss_objectness: 0.0094 (0.0100)  loss_rpn_box_reg: 0.0036 (0.0044)  time: 0.5327  data: 0.0174  max mem: 3288
# Epoch: [2]  [160/287]  eta: 0:01:08  lr: 0.005000  loss: 0.2332 (0.2516)  loss_classifier: 0.0930 (0.0942)  loss_box_reg: 0.1091 (0.1429)  loss_objectness: 0.0077 (0.0102)  loss_rpn_box_reg: 0.0028 (0.0043)  time: 0.5230  data: 0.0156  max mem: 3288
# Epoch: [2]  [170/287]  eta: 0:01:03  lr: 0.005000  loss: 0.2312 (0.2514)  loss_classifier: 0.0886 (0.0942)  loss_box_reg: 0.1264 (0.1424)  loss_objectness: 0.0064 (0.0104)  loss_rpn_box_reg: 0.0038 (0.0044)  time: 0.5466  data: 0.0261  max mem: 3288
# Epoch: [2]  [180/287]  eta: 0:00:57  lr: 0.005000  loss: 0.2072 (0.2498)  loss_classifier: 0.0787 (0.0938)  loss_box_reg: 0.1145 (0.1412)  loss_objectness: 0.0064 (0.0104)  loss_rpn_box_reg: 0.0044 (0.0044)  time: 0.5393  data: 0.0233  max mem: 3288
# Epoch: [2]  [190/287]  eta: 0:00:52  lr: 0.005000  loss: 0.2092 (0.2508)  loss_classifier: 0.0795 (0.0941)  loss_box_reg: 0.1164 (0.1419)  loss_objectness: 0.0100 (0.0104)  loss_rpn_box_reg: 0.0041 (0.0044)  time: 0.5229  data: 0.0175  max mem: 3288
# Epoch: [2]  [200/287]  eta: 0:00:47  lr: 0.005000  loss: 0.2247 (0.2500)  loss_classifier: 0.0740 (0.0935)  loss_box_reg: 0.1503 (0.1416)  loss_objectness: 0.0106 (0.0105)  loss_rpn_box_reg: 0.0031 (0.0044)  time: 0.5365  data: 0.0189  max mem: 3288
# Epoch: [2]  [210/287]  eta: 0:00:41  lr: 0.005000  loss: 0.2282 (0.2510)  loss_classifier: 0.0800 (0.0939)  loss_box_reg: 0.1430 (0.1420)  loss_objectness: 0.0093 (0.0106)  loss_rpn_box_reg: 0.0030 (0.0044)  time: 0.5298  data: 0.0127  max mem: 3288
# Epoch: [2]  [220/287]  eta: 0:00:36  lr: 0.005000  loss: 0.2648 (0.2516)  loss_classifier: 0.0925 (0.0942)  loss_box_reg: 0.1480 (0.1424)  loss_objectness: 0.0086 (0.0105)  loss_rpn_box_reg: 0.0036 (0.0044)  time: 0.5466  data: 0.0131  max mem: 3289
# Epoch: [2]  [230/287]  eta: 0:00:30  lr: 0.005000  loss: 0.2321 (0.2528)  loss_classifier: 0.0925 (0.0944)  loss_box_reg: 0.1436 (0.1433)  loss_objectness: 0.0084 (0.0107)  loss_rpn_box_reg: 0.0046 (0.0045)  time: 0.5607  data: 0.0202  max mem: 3289
# Epoch: [2]  [240/287]  eta: 0:00:25  lr: 0.005000  loss: 0.2321 (0.2528)  loss_classifier: 0.0872 (0.0945)  loss_box_reg: 0.1436 (0.1432)  loss_objectness: 0.0061 (0.0105)  loss_rpn_box_reg: 0.0034 (0.0045)  time: 0.5270  data: 0.0181  max mem: 3289
# Epoch: [2]  [250/287]  eta: 0:00:19  lr: 0.005000  loss: 0.2367 (0.2520)  loss_classifier: 0.0829 (0.0940)  loss_box_reg: 0.1386 (0.1431)  loss_objectness: 0.0049 (0.0104)  loss_rpn_box_reg: 0.0022 (0.0044)  time: 0.5212  data: 0.0161  max mem: 3289
# Epoch: [2]  [260/287]  eta: 0:00:14  lr: 0.005000  loss: 0.2253 (0.2516)  loss_classifier: 0.0738 (0.0935)  loss_box_reg: 0.1311 (0.1432)  loss_objectness: 0.0058 (0.0104)  loss_rpn_box_reg: 0.0025 (0.0045)  time: 0.5262  data: 0.0151  max mem: 3289
# Epoch: [2]  [270/287]  eta: 0:00:09  lr: 0.005000  loss: 0.1997 (0.2504)  loss_classifier: 0.0691 (0.0928)  loss_box_reg: 0.1259 (0.1430)  loss_objectness: 0.0059 (0.0102)  loss_rpn_box_reg: 0.0047 (0.0045)  time: 0.5228  data: 0.0120  max mem: 3289
# Epoch: [2]  [280/287]  eta: 0:00:03  lr: 0.005000  loss: 0.2186 (0.2515)  loss_classifier: 0.0716 (0.0934)  loss_box_reg: 0.1263 (0.1433)  loss_objectness: 0.0057 (0.0104)  loss_rpn_box_reg: 0.0034 (0.0045)  time: 0.5215  data: 0.0143  max mem: 3289
# Epoch: [2]  [286/287]  eta: 0:00:00  lr: 0.005000  loss: 0.2273 (0.2513)  loss_classifier: 0.0805 (0.0932)  loss_box_reg: 0.1340 (0.1433)  loss_objectness: 0.0058 (0.0103)  loss_rpn_box_reg: 0.0038 (0.0045)  time: 0.5176  data: 0.0146  max mem: 3289
# Epoch: [2] Total time: 0:02:34 (0.5387 s / it)
# creating index...
# index created!
# Test:  [ 0/61]  eta: 0:00:35  model_time: 0.1026 (0.1026)  evaluator_time: 0.0021 (0.0021)  time: 0.5826  data: 0.4733  max mem: 3289
# Test:  [60/61]  eta: 0:00:00  model_time: 0.1013 (0.1014)  evaluator_time: 0.0020 (0.0017)  time: 0.1084  data: 0.0035  max mem: 3289
# Test: Total time: 0:00:07 (0.1246 s / it)
# Averaged stats: model_time: 0.1013 (0.1014)  evaluator_time: 0.0020 (0.0017)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.264
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.610
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.158
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.050
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.269
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.490
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.504
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.400
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.506
# Epoch: [3]  [  0/287]  eta: 0:11:22  lr: 0.000500  loss: 0.2185 (0.2185)  loss_classifier: 0.0631 (0.0631)  loss_box_reg: 0.1448 (0.1448)  loss_objectness: 0.0078 (0.0078)  loss_rpn_box_reg: 0.0029 (0.0029)  time: 2.3781  data: 1.7819  max mem: 3289
# Epoch: [3]  [ 10/287]  eta: 0:03:06  lr: 0.000500  loss: 0.2404 (0.2619)  loss_classifier: 0.0895 (0.0942)  loss_box_reg: 0.1478 (0.1548)  loss_objectness: 0.0077 (0.0080)  loss_rpn_box_reg: 0.0051 (0.0049)  time: 0.6719  data: 0.1722  max mem: 3289
# Epoch: [3]  [ 20/287]  eta: 0:02:39  lr: 0.000500  loss: 0.2276 (0.2568)  loss_classifier: 0.0895 (0.0978)  loss_box_reg: 0.1289 (0.1469)  loss_objectness: 0.0071 (0.0082)  loss_rpn_box_reg: 0.0036 (0.0039)  time: 0.5087  data: 0.0139  max mem: 3289
# Epoch: [3]  [ 30/287]  eta: 0:02:36  lr: 0.000500  loss: 0.2276 (0.2510)  loss_classifier: 0.0876 (0.0974)  loss_box_reg: 0.1289 (0.1417)  loss_objectness: 0.0070 (0.0081)  loss_rpn_box_reg: 0.0021 (0.0038)  time: 0.5727  data: 0.0248  max mem: 3289
# Epoch: [3]  [ 40/287]  eta: 0:02:26  lr: 0.000500  loss: 0.2481 (0.2499)  loss_classifier: 0.0876 (0.0950)  loss_box_reg: 0.1330 (0.1418)  loss_objectness: 0.0100 (0.0091)  loss_rpn_box_reg: 0.0030 (0.0040)  time: 0.5842  data: 0.0278  max mem: 3289
# Epoch: [3]  [ 50/287]  eta: 0:02:15  lr: 0.000500  loss: 0.2123 (0.2414)  loss_classifier: 0.0713 (0.0905)  loss_box_reg: 0.1255 (0.1383)  loss_objectness: 0.0100 (0.0085)  loss_rpn_box_reg: 0.0030 (0.0042)  time: 0.5202  data: 0.0174  max mem: 3289
# Epoch: [3]  [ 60/287]  eta: 0:02:07  lr: 0.000500  loss: 0.2039 (0.2401)  loss_classifier: 0.0706 (0.0907)  loss_box_reg: 0.1132 (0.1371)  loss_objectness: 0.0059 (0.0083)  loss_rpn_box_reg: 0.0030 (0.0041)  time: 0.5074  data: 0.0129  max mem: 3289
# Epoch: [3]  [ 70/287]  eta: 0:02:01  lr: 0.000500  loss: 0.2213 (0.2432)  loss_classifier: 0.0866 (0.0922)  loss_box_reg: 0.1357 (0.1380)  loss_objectness: 0.0102 (0.0087)  loss_rpn_box_reg: 0.0033 (0.0043)  time: 0.5196  data: 0.0133  max mem: 3289
# Epoch: [3]  [ 80/287]  eta: 0:01:54  lr: 0.000500  loss: 0.2350 (0.2391)  loss_classifier: 0.0892 (0.0912)  loss_box_reg: 0.1205 (0.1346)  loss_objectness: 0.0106 (0.0089)  loss_rpn_box_reg: 0.0038 (0.0044)  time: 0.5219  data: 0.0148  max mem: 3289
# Epoch: [3]  [ 90/287]  eta: 0:01:48  lr: 0.000500  loss: 0.2262 (0.2402)  loss_classifier: 0.0892 (0.0918)  loss_box_reg: 0.1203 (0.1351)  loss_objectness: 0.0087 (0.0090)  loss_rpn_box_reg: 0.0039 (0.0044)  time: 0.5289  data: 0.0176  max mem: 3289
# Epoch: [3]  [100/287]  eta: 0:01:42  lr: 0.000500  loss: 0.2274 (0.2378)  loss_classifier: 0.0876 (0.0910)  loss_box_reg: 0.1259 (0.1333)  loss_objectness: 0.0074 (0.0091)  loss_rpn_box_reg: 0.0037 (0.0044)  time: 0.5354  data: 0.0145  max mem: 3289
# Epoch: [3]  [110/287]  eta: 0:01:36  lr: 0.000500  loss: 0.1923 (0.2325)  loss_classifier: 0.0731 (0.0891)  loss_box_reg: 0.0977 (0.1305)  loss_objectness: 0.0067 (0.0089)  loss_rpn_box_reg: 0.0022 (0.0042)  time: 0.5250  data: 0.0103  max mem: 3289
# Epoch: [3]  [120/287]  eta: 0:01:31  lr: 0.000500  loss: 0.1916 (0.2298)  loss_classifier: 0.0663 (0.0876)  loss_box_reg: 0.1138 (0.1296)  loss_objectness: 0.0055 (0.0087)  loss_rpn_box_reg: 0.0018 (0.0040)  time: 0.5288  data: 0.0159  max mem: 3289
# Epoch: [3]  [130/287]  eta: 0:01:25  lr: 0.000500  loss: 0.1916 (0.2282)  loss_classifier: 0.0663 (0.0858)  loss_box_reg: 0.1178 (0.1295)  loss_objectness: 0.0052 (0.0087)  loss_rpn_box_reg: 0.0030 (0.0042)  time: 0.5408  data: 0.0178  max mem: 3289
# Epoch: [3]  [140/287]  eta: 0:01:20  lr: 0.000500  loss: 0.1906 (0.2271)  loss_classifier: 0.0725 (0.0854)  loss_box_reg: 0.1017 (0.1288)  loss_objectness: 0.0082 (0.0087)  loss_rpn_box_reg: 0.0040 (0.0041)  time: 0.5392  data: 0.0189  max mem: 3289
# Epoch: [3]  [150/287]  eta: 0:01:14  lr: 0.000500  loss: 0.1988 (0.2263)  loss_classifier: 0.0809 (0.0848)  loss_box_reg: 0.1034 (0.1289)  loss_objectness: 0.0074 (0.0086)  loss_rpn_box_reg: 0.0029 (0.0041)  time: 0.5301  data: 0.0179  max mem: 3289
# Epoch: [3]  [160/287]  eta: 0:01:08  lr: 0.000500  loss: 0.1988 (0.2261)  loss_classifier: 0.0706 (0.0848)  loss_box_reg: 0.1102 (0.1287)  loss_objectness: 0.0058 (0.0084)  loss_rpn_box_reg: 0.0039 (0.0041)  time: 0.5158  data: 0.0110  max mem: 3289
# Epoch: [3]  [170/287]  eta: 0:01:03  lr: 0.000500  loss: 0.2056 (0.2259)  loss_classifier: 0.0746 (0.0848)  loss_box_reg: 0.1144 (0.1287)  loss_objectness: 0.0058 (0.0083)  loss_rpn_box_reg: 0.0037 (0.0041)  time: 0.5292  data: 0.0141  max mem: 3289
# Epoch: [3]  [180/287]  eta: 0:00:57  lr: 0.000500  loss: 0.1968 (0.2242)  loss_classifier: 0.0728 (0.0843)  loss_box_reg: 0.1159 (0.1275)  loss_objectness: 0.0048 (0.0083)  loss_rpn_box_reg: 0.0029 (0.0041)  time: 0.5418  data: 0.0170  max mem: 3289
# Epoch: [3]  [190/287]  eta: 0:00:52  lr: 0.000500  loss: 0.1968 (0.2253)  loss_classifier: 0.0768 (0.0848)  loss_box_reg: 0.1159 (0.1279)  loss_objectness: 0.0059 (0.0085)  loss_rpn_box_reg: 0.0026 (0.0041)  time: 0.5270  data: 0.0146  max mem: 3289
# Epoch: [3]  [200/287]  eta: 0:00:47  lr: 0.000500  loss: 0.1832 (0.2223)  loss_classifier: 0.0699 (0.0837)  loss_box_reg: 0.1077 (0.1262)  loss_objectness: 0.0072 (0.0085)  loss_rpn_box_reg: 0.0023 (0.0040)  time: 0.5384  data: 0.0208  max mem: 3289
# Epoch: [3]  [210/287]  eta: 0:00:41  lr: 0.000500  loss: 0.1608 (0.2212)  loss_classifier: 0.0674 (0.0833)  loss_box_reg: 0.0863 (0.1255)  loss_objectness: 0.0055 (0.0085)  loss_rpn_box_reg: 0.0020 (0.0039)  time: 0.5357  data: 0.0200  max mem: 3289
# Epoch: [3]  [220/287]  eta: 0:00:36  lr: 0.000500  loss: 0.2017 (0.2213)  loss_classifier: 0.0674 (0.0829)  loss_box_reg: 0.1204 (0.1261)  loss_objectness: 0.0052 (0.0084)  loss_rpn_box_reg: 0.0026 (0.0039)  time: 0.5168  data: 0.0136  max mem: 3289
# Epoch: [3]  [230/287]  eta: 0:00:30  lr: 0.000500  loss: 0.2249 (0.2216)  loss_classifier: 0.0573 (0.0825)  loss_box_reg: 0.1416 (0.1269)  loss_objectness: 0.0067 (0.0083)  loss_rpn_box_reg: 0.0034 (0.0039)  time: 0.5395  data: 0.0186  max mem: 3289
# Epoch: [3]  [240/287]  eta: 0:00:25  lr: 0.000500  loss: 0.2108 (0.2236)  loss_classifier: 0.0702 (0.0831)  loss_box_reg: 0.1236 (0.1281)  loss_objectness: 0.0065 (0.0083)  loss_rpn_box_reg: 0.0035 (0.0040)  time: 0.5479  data: 0.0191  max mem: 3289
# Epoch: [3]  [250/287]  eta: 0:00:19  lr: 0.000500  loss: 0.2080 (0.2229)  loss_classifier: 0.0733 (0.0828)  loss_box_reg: 0.1181 (0.1279)  loss_objectness: 0.0045 (0.0083)  loss_rpn_box_reg: 0.0032 (0.0040)  time: 0.5198  data: 0.0141  max mem: 3289
# Epoch: [3]  [260/287]  eta: 0:00:14  lr: 0.000500  loss: 0.1941 (0.2235)  loss_classifier: 0.0761 (0.0830)  loss_box_reg: 0.1146 (0.1282)  loss_objectness: 0.0045 (0.0083)  loss_rpn_box_reg: 0.0033 (0.0040)  time: 0.5175  data: 0.0141  max mem: 3289
# Epoch: [3]  [270/287]  eta: 0:00:09  lr: 0.000500  loss: 0.2062 (0.2231)  loss_classifier: 0.0756 (0.0826)  loss_box_reg: 0.1363 (0.1283)  loss_objectness: 0.0063 (0.0082)  loss_rpn_box_reg: 0.0033 (0.0040)  time: 0.5196  data: 0.0150  max mem: 3289
# Epoch: [3]  [280/287]  eta: 0:00:03  lr: 0.000500  loss: 0.1876 (0.2227)  loss_classifier: 0.0610 (0.0825)  loss_box_reg: 0.1193 (0.1279)  loss_objectness: 0.0060 (0.0082)  loss_rpn_box_reg: 0.0031 (0.0040)  time: 0.5166  data: 0.0148  max mem: 3289
# Epoch: [3]  [286/287]  eta: 0:00:00  lr: 0.000500  loss: 0.1858 (0.2224)  loss_classifier: 0.0614 (0.0824)  loss_box_reg: 0.1178 (0.1278)  loss_objectness: 0.0056 (0.0082)  loss_rpn_box_reg: 0.0026 (0.0040)  time: 0.5130  data: 0.0146  max mem: 3289
# Epoch: [3] Total time: 0:02:34 (0.5372 s / it)
# creating index...
# index created!
# Test:  [ 0/61]  eta: 0:00:35  model_time: 0.1065 (0.1065)  evaluator_time: 0.0021 (0.0021)  time: 0.5830  data: 0.4727  max mem: 3289
# Test:  [60/61]  eta: 0:00:00  model_time: 0.1007 (0.1012)  evaluator_time: 0.0012 (0.0013)  time: 0.1064  data: 0.0031  max mem: 3289
# Test: Total time: 0:00:07 (0.1199 s / it)
# Averaged stats: model_time: 0.1007 (0.1012)  evaluator_time: 0.0012 (0.0013)
# Accumulating evaluation results...
# DONE (t=0.03s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.309
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.670
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.202
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.100
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.313
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.281
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.524
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.537
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.500
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.538
# Epoch: [4]  [  0/287]  eta: 0:05:25  lr: 0.000500  loss: 0.2687 (0.2687)  loss_classifier: 0.0807 (0.0807)  loss_box_reg: 0.1709 (0.1709)  loss_objectness: 0.0123 (0.0123)  loss_rpn_box_reg: 0.0048 (0.0048)  time: 1.1332  data: 0.5310  max mem: 3289
# Epoch: [4]  [ 10/287]  eta: 0:02:50  lr: 0.000500  loss: 0.2648 (0.2516)  loss_classifier: 0.0889 (0.0880)  loss_box_reg: 0.1585 (0.1503)  loss_objectness: 0.0090 (0.0088)  loss_rpn_box_reg: 0.0048 (0.0046)  time: 0.6164  data: 0.0660  max mem: 3289
# Epoch: [4]  [ 20/287]  eta: 0:02:32  lr: 0.000500  loss: 0.2154 (0.2374)  loss_classifier: 0.0767 (0.0843)  loss_box_reg: 0.1169 (0.1395)  loss_objectness: 0.0088 (0.0093)  loss_rpn_box_reg: 0.0028 (0.0044)  time: 0.5439  data: 0.0175  max mem: 3289
# Epoch: [4]  [ 30/287]  eta: 0:02:22  lr: 0.000500  loss: 0.1900 (0.2338)  loss_classifier: 0.0637 (0.0834)  loss_box_reg: 0.1145 (0.1370)  loss_objectness: 0.0060 (0.0089)  loss_rpn_box_reg: 0.0032 (0.0045)  time: 0.5212  data: 0.0151  max mem: 3289
# Epoch: [4]  [ 40/287]  eta: 0:02:15  lr: 0.000500  loss: 0.2010 (0.2291)  loss_classifier: 0.0645 (0.0798)  loss_box_reg: 0.1225 (0.1361)  loss_objectness: 0.0061 (0.0088)  loss_rpn_box_reg: 0.0034 (0.0045)  time: 0.5244  data: 0.0145  max mem: 3289
# Epoch: [4]  [ 50/287]  eta: 0:02:09  lr: 0.000500  loss: 0.1932 (0.2257)  loss_classifier: 0.0633 (0.0804)  loss_box_reg: 0.1208 (0.1330)  loss_objectness: 0.0053 (0.0080)  loss_rpn_box_reg: 0.0032 (0.0043)  time: 0.5280  data: 0.0142  max mem: 3289
# Epoch: [4]  [ 60/287]  eta: 0:02:03  lr: 0.000500  loss: 0.1836 (0.2172)  loss_classifier: 0.0625 (0.0780)  loss_box_reg: 0.1011 (0.1271)  loss_objectness: 0.0060 (0.0081)  loss_rpn_box_reg: 0.0029 (0.0040)  time: 0.5341  data: 0.0153  max mem: 3289
# Epoch: [4]  [ 70/287]  eta: 0:01:58  lr: 0.000500  loss: 0.1857 (0.2153)  loss_classifier: 0.0682 (0.0780)  loss_box_reg: 0.0997 (0.1256)  loss_objectness: 0.0075 (0.0079)  loss_rpn_box_reg: 0.0027 (0.0039)  time: 0.5530  data: 0.0145  max mem: 3289
# Epoch: [4]  [ 80/287]  eta: 0:01:52  lr: 0.000500  loss: 0.1962 (0.2170)  loss_classifier: 0.0802 (0.0798)  loss_box_reg: 0.1097 (0.1254)  loss_objectness: 0.0059 (0.0078)  loss_rpn_box_reg: 0.0030 (0.0040)  time: 0.5475  data: 0.0127  max mem: 3289
# Epoch: [4]  [ 90/287]  eta: 0:01:47  lr: 0.000500  loss: 0.2027 (0.2157)  loss_classifier: 0.0802 (0.0793)  loss_box_reg: 0.1124 (0.1244)  loss_objectness: 0.0085 (0.0081)  loss_rpn_box_reg: 0.0030 (0.0039)  time: 0.5465  data: 0.0210  max mem: 3289
# Epoch: [4]  [100/287]  eta: 0:01:41  lr: 0.000500  loss: 0.1918 (0.2128)  loss_classifier: 0.0627 (0.0774)  loss_box_reg: 0.1124 (0.1238)  loss_objectness: 0.0044 (0.0077)  loss_rpn_box_reg: 0.0032 (0.0039)  time: 0.5306  data: 0.0207  max mem: 3289
# Epoch: [4]  [110/287]  eta: 0:01:36  lr: 0.000500  loss: 0.1920 (0.2193)  loss_classifier: 0.0615 (0.0801)  loss_box_reg: 0.1249 (0.1268)  loss_objectness: 0.0035 (0.0083)  loss_rpn_box_reg: 0.0036 (0.0041)  time: 0.5268  data: 0.0153  max mem: 3289
# Epoch: [4]  [120/287]  eta: 0:01:30  lr: 0.000500  loss: 0.2020 (0.2180)  loss_classifier: 0.0725 (0.0797)  loss_box_reg: 0.1249 (0.1261)  loss_objectness: 0.0055 (0.0082)  loss_rpn_box_reg: 0.0024 (0.0040)  time: 0.5556  data: 0.0243  max mem: 3289
# Epoch: [4]  [130/287]  eta: 0:01:25  lr: 0.000500  loss: 0.1818 (0.2171)  loss_classifier: 0.0708 (0.0793)  loss_box_reg: 0.1076 (0.1258)  loss_objectness: 0.0039 (0.0080)  loss_rpn_box_reg: 0.0022 (0.0039)  time: 0.5432  data: 0.0252  max mem: 3289
# Epoch: [4]  [140/287]  eta: 0:01:19  lr: 0.000500  loss: 0.1776 (0.2165)  loss_classifier: 0.0695 (0.0787)  loss_box_reg: 0.1050 (0.1262)  loss_objectness: 0.0031 (0.0077)  loss_rpn_box_reg: 0.0023 (0.0038)  time: 0.5255  data: 0.0195  max mem: 3289
# Epoch: [4]  [150/287]  eta: 0:01:14  lr: 0.000500  loss: 0.2039 (0.2155)  loss_classifier: 0.0695 (0.0781)  loss_box_reg: 0.1294 (0.1260)  loss_objectness: 0.0035 (0.0076)  loss_rpn_box_reg: 0.0030 (0.0038)  time: 0.5350  data: 0.0193  max mem: 3289
# Epoch: [4]  [160/287]  eta: 0:01:08  lr: 0.000500  loss: 0.2167 (0.2151)  loss_classifier: 0.0713 (0.0780)  loss_box_reg: 0.1277 (0.1259)  loss_objectness: 0.0059 (0.0075)  loss_rpn_box_reg: 0.0032 (0.0038)  time: 0.5302  data: 0.0157  max mem: 3289
# Epoch: [4]  [170/287]  eta: 0:01:03  lr: 0.000500  loss: 0.2121 (0.2160)  loss_classifier: 0.0720 (0.0783)  loss_box_reg: 0.1189 (0.1264)  loss_objectness: 0.0064 (0.0075)  loss_rpn_box_reg: 0.0037 (0.0038)  time: 0.5278  data: 0.0117  max mem: 3289
# Epoch: [4]  [180/287]  eta: 0:00:57  lr: 0.000500  loss: 0.2070 (0.2156)  loss_classifier: 0.0666 (0.0781)  loss_box_reg: 0.1163 (0.1263)  loss_objectness: 0.0064 (0.0075)  loss_rpn_box_reg: 0.0033 (0.0038)  time: 0.5382  data: 0.0147  max mem: 3289
# Epoch: [4]  [190/287]  eta: 0:00:52  lr: 0.000500  loss: 0.2040 (0.2164)  loss_classifier: 0.0660 (0.0783)  loss_box_reg: 0.1224 (0.1270)  loss_objectness: 0.0054 (0.0074)  loss_rpn_box_reg: 0.0027 (0.0038)  time: 0.5193  data: 0.0164  max mem: 3289
# Epoch: [4]  [200/287]  eta: 0:00:46  lr: 0.000500  loss: 0.2070 (0.2153)  loss_classifier: 0.0707 (0.0781)  loss_box_reg: 0.1177 (0.1261)  loss_objectness: 0.0068 (0.0075)  loss_rpn_box_reg: 0.0023 (0.0037)  time: 0.5341  data: 0.0153  max mem: 3289
# Epoch: [4]  [210/287]  eta: 0:00:41  lr: 0.000500  loss: 0.2072 (0.2179)  loss_classifier: 0.0743 (0.0793)  loss_box_reg: 0.1177 (0.1272)  loss_objectness: 0.0094 (0.0076)  loss_rpn_box_reg: 0.0024 (0.0037)  time: 0.5390  data: 0.0154  max mem: 3289
# Epoch: [4]  [220/287]  eta: 0:00:36  lr: 0.000500  loss: 0.2176 (0.2170)  loss_classifier: 0.0743 (0.0792)  loss_box_reg: 0.1137 (0.1266)  loss_objectness: 0.0062 (0.0075)  loss_rpn_box_reg: 0.0028 (0.0037)  time: 0.5186  data: 0.0143  max mem: 3289
# Epoch: [4]  [230/287]  eta: 0:00:30  lr: 0.000500  loss: 0.1787 (0.2167)  loss_classifier: 0.0673 (0.0791)  loss_box_reg: 0.1102 (0.1266)  loss_objectness: 0.0058 (0.0074)  loss_rpn_box_reg: 0.0026 (0.0037)  time: 0.5275  data: 0.0152  max mem: 3289
# Epoch: [4]  [240/287]  eta: 0:00:25  lr: 0.000500  loss: 0.2008 (0.2166)  loss_classifier: 0.0694 (0.0794)  loss_box_reg: 0.1208 (0.1261)  loss_objectness: 0.0058 (0.0075)  loss_rpn_box_reg: 0.0019 (0.0036)  time: 0.5345  data: 0.0152  max mem: 3289
# Epoch: [4]  [250/287]  eta: 0:00:19  lr: 0.000500  loss: 0.2145 (0.2173)  loss_classifier: 0.0885 (0.0799)  loss_box_reg: 0.1221 (0.1262)  loss_objectness: 0.0059 (0.0074)  loss_rpn_box_reg: 0.0031 (0.0037)  time: 0.5213  data: 0.0136  max mem: 3289
# Epoch: [4]  [260/287]  eta: 0:00:14  lr: 0.000500  loss: 0.2163 (0.2172)  loss_classifier: 0.0885 (0.0801)  loss_box_reg: 0.1158 (0.1258)  loss_objectness: 0.0057 (0.0075)  loss_rpn_box_reg: 0.0032 (0.0037)  time: 0.5180  data: 0.0169  max mem: 3289
# Epoch: [4]  [270/287]  eta: 0:00:09  lr: 0.000500  loss: 0.1844 (0.2166)  loss_classifier: 0.0765 (0.0799)  loss_box_reg: 0.1040 (0.1256)  loss_objectness: 0.0047 (0.0075)  loss_rpn_box_reg: 0.0024 (0.0037)  time: 0.5114  data: 0.0134  max mem: 3289
# Epoch: [4]  [280/287]  eta: 0:00:03  lr: 0.000500  loss: 0.2031 (0.2172)  loss_classifier: 0.0683 (0.0800)  loss_box_reg: 0.1215 (0.1260)  loss_objectness: 0.0045 (0.0075)  loss_rpn_box_reg: 0.0025 (0.0037)  time: 0.5016  data: 0.0091  max mem: 3289
# Epoch: [4]  [286/287]  eta: 0:00:00  lr: 0.000500  loss: 0.2068 (0.2177)  loss_classifier: 0.0688 (0.0800)  loss_box_reg: 0.1215 (0.1263)  loss_objectness: 0.0060 (0.0076)  loss_rpn_box_reg: 0.0038 (0.0038)  time: 0.5150  data: 0.0117  max mem: 3289
# Epoch: [4] Total time: 0:02:33 (0.5351 s / it)
# creating index...
# index created!
# Test:  [ 0/61]  eta: 0:00:41  model_time: 0.1145 (0.1145)  evaluator_time: 0.0021 (0.0021)  time: 0.6862  data: 0.5680  max mem: 3289
# Test:  [60/61]  eta: 0:00:00  model_time: 0.1011 (0.1015)  evaluator_time: 0.0013 (0.0014)  time: 0.1069  data: 0.0032  max mem: 3289
# Test: Total time: 0:00:07 (0.1218 s / it)
# Averaged stats: model_time: 0.1011 (0.1015)  evaluator_time: 0.0013 (0.0014)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.319
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.709
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.193
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.150
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.323
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.296
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.527
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.537
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.600
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.536
# That's it!
# Saving
# Saved
