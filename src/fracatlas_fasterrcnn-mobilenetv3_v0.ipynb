# %%
# %pip uninstall torch torchvision torchaudio torchtext torchdata fastai -y
# %pip install torchvision==0.16 torch==2.1

import torch
import torchvision

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

print("pytorch", torch.__version__)
print("torchvision", torchvision.__version__)
# Out:
# Found existing installation: torch 2.0.1+cu118
# Uninstalling torch-2.0.1+cu118:
#   Successfully uninstalled torch-2.0.1+cu118
# Found existing installation: torchvision 0.15.2+cu118
# Uninstalling torchvision-0.15.2+cu118:
#   Successfully uninstalled torchvision-0.15.2+cu118
# Found existing installation: torchaudio 2.0.2+cu118
# Uninstalling torchaudio-2.0.2+cu118:
#   Successfully uninstalled torchaudio-2.0.2+cu118
# Found existing installation: torchtext 0.15.2
# Uninstalling torchtext-0.15.2:
#   Successfully uninstalled torchtext-0.15.2
# Found existing installation: torchdata 0.6.1
# Uninstalling torchdata-0.6.1:
#   Successfully uninstalled torchdata-0.6.1
# Found existing installation: fastai 2.7.12
# Uninstalling fastai-2.7.12:
#   Successfully uninstalled fastai-2.7.12
# Collecting torchvision==0.16
#   Downloading torchvision-0.16.0-cp310-cp310-manylinux1_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 59.1 MB/s eta 0:00:00
# Collecting torch==2.1
#   Downloading torch-2.1.0-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 67.0 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.1)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 58.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.1)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 90.9 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.1)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.1)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.1)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.4 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.1)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 12.0 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.1)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.1 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.1)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.1 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.18.1 (from torch==2.1)
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 5.7 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.1)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 14.4 MB/s eta 0:00:00
# Collecting triton==2.1.0 (from torch==2.1)
#   Downloading triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 8.5 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1)
#   Downloading nvidia_nvjitlink_cu12-12.2.140-py3-none-manylinux1_x86_64.whl (20.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 89.5 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.1) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1) (1.3.0)
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 2.0.0
#     Uninstalling triton-2.0.0:
#       Successfully uninstalled triton-2.0.0
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.2.140 nvidia-nvtx-cu12-12.1.105 torch-2.1.0 torchvision-0.16.0 triton-2.1.0
# pytorch 2.1.0+cu121
# torchvision 0.16.0+cu121

# %%
from torchvision.transforms import functional as F
from torchvision.datasets.vision import VisionDataset
from torchvision.datasets.utils import download_and_extract_archive, verify_str_arg
from torchvision.ops import box_area

from PIL import Image

import collections
import os
from xml.etree.ElementTree import Element as ET_Element

try:
    from defusedxml.ElementTree import parse as ET_parse
except ImportError:
    from xml.etree.ElementTree import parse as ET_parse
from typing import Any, Callable, Dict, List, Optional, Tuple


class FracAtlasDetection(VisionDataset):
    """FracAtlas dataset."""

    def __init__(
        self,
        root: str,
        image_set: str = "train",
        # download: bool = False,
        transform: Optional[Callable] = None,
        target_transform: Optional[Callable] = None,
        transforms: Optional[Callable] = None,
    ):
        super().__init__(root, transforms, transform, target_transform)

        valid_image_sets = ["test", "train", "val"]
        self.image_set = verify_str_arg(image_set, "image_set", valid_image_sets)

        self.url = "https://figshare.com/ndownloader/files/41725659"
        self.filename = "fracatlas.zip"

        # if download:
        if not os.path.isdir("data/FracAtlas"):
            os.makedirs("data", exist_ok=True)
            download_and_extract_archive(self.url, os.path.dirname(self.root), filename=self.filename, remove_finished=True)
            for subdir in ["Fractured", "Non_fractured"]:
                dirpath = os.path.join(self.root, "images")
                subdirpath = os.path.join(dirpath, subdir)
                for f in os.listdir(subdirpath):
                    if not f.lower().endswith(".jpg"): continue
                    os.rename(os.path.join(subdirpath, f), os.path.join(dirpath, f))
                os.rmdir(subdirpath)
            print(os.listdir("data"))
        if not os.path.isdir(self.root):
            raise RuntimeError(
                "Dataset not found or corrupted. You can use download=True to download it"
            )

        splits_dir = os.path.join(self.root, "Utilities", "Fracture Split")
        splits_f = os.path.join(splits_dir, image_set.rstrip("\n") + ".csv")
        with open(os.path.join(splits_f)) as f:
            file_names = [
                os.path.splitext(x.strip())[0]
                for x in f.readlines()
                if x.strip() != "image_id"
            ]

        image_dir = os.path.join(self.root, "images")
        self.images = [os.path.join(image_dir, x + ".jpg") for x in file_names]

        target_dir = os.path.join(self.root, "Annotations", "PASCAL VOC")
        self.targets = [os.path.join(target_dir, x + ".xml") for x in file_names]

        assert len(self.images) == len(self.targets)

    @property
    def annotations(self) -> List[str]:
        return self.targets

    def __getitem__(self, index: int) -> Tuple[Any, Any]:
        """
        Args:
            index (int): Index

        Returns:
            tuple: (image, target) where target is a dictionary of the XML tree.
        """
        img = Image.open(self.images[index]).convert("RGB")
        img = F.to_tensor(img)
        voc_dict = self.parse_voc_xml(ET_parse(self.annotations[index]).getroot())
        target = self.voc_dict_to_target(index, voc_dict)
        # print(target)

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self) -> int:
        return len(self.images)

    @staticmethod
    def parse_voc_xml(node: ET_Element) -> Dict[str, Any]:
        voc_dict: Dict[str, Any] = {}
        children = list(node)
        if children:
            def_dic: Dict[str, Any] = collections.defaultdict(list)
            for dc in map(FracAtlasDetection.parse_voc_xml, children):
                for ind, v in dc.items():
                    def_dic[ind].append(v)
            if node.tag == "annotation":
                def_dic["object"] = [def_dic["object"]]
            voc_dict = {
                node.tag: {
                    ind: v[0] if len(v) == 1 else v for ind, v in def_dic.items()
                }
            }
        if node.text:
            text = node.text.strip()
            if not children:
                voc_dict[node.tag] = text
        return voc_dict

    def voc_dict_to_target(self, index: int, item):
        width = int(item["annotation"]["size"]["width"])
        height = int(item["annotation"]["size"]["height"])

        num_fractures = len(item["annotation"]["object"])

        boxes = [
            (
                int(obj["bndbox"]["xmin"]),
                int(obj["bndbox"]["ymin"]),
                int(obj["bndbox"]["xmax"]),
                int(obj["bndbox"]["ymax"]),
            )
            for obj in item["annotation"]["object"]
        ]

        # guard against no boxes via resizing (https://github.com/pytorch/vision/blob/aa32c9376c46eb284f2b091f3eb98aec4fd64b03/references/detection/coco_utils.py#L63-L66)
        boxes = torch.as_tensor(boxes, dtype=torch.float32).reshape(-1, 4)
        boxes[:, 2:] += boxes[:, :2]
        boxes[:, 0::2].clamp_(min=0, max=width)
        boxes[:, 1::2].clamp_(min=0, max=height)

        # extract labels
        labels = torch.ones((num_fractures,), dtype=torch.int64)

        image_id = index
        area = box_area(boxes)

        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_fractures,), dtype=torch.int64)

        # remove invalid boxes (https://github.com/pytorch/vision/blob/aa32c9376c46eb284f2b091f3eb98aec4fd64b03/references/detection/coco_utils.py#L82-L85)
        keep = (boxes[:, 3] > boxes[:, 1]) & (boxes[:, 2] > boxes[:, 0])
        boxes = boxes[keep]

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd

        return target

# %%
from torchvision.transforms import v2 as T


def get_transform(train):
    transforms = []
    # if train:
    #     transforms.append(T.RandomHorizontalFlip(0.5))
    transforms.append(T.ToImage())
    transforms.append(T.ToDtype(torch.float32, scale=True))
    # transforms.append(T.ToDtype(torch.float))
    # transforms.append(T.ToPureTensor())
    return T.Compose(transforms)

# %%
# os.makedirs("lib", exist_ok=True)
if not os.path.exists("engine.py"):
    os.system(
        "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py -O engine.py"
    )
if not os.path.exists("utils.py"):
    os.system(
        "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py -O utils.py"
    )
if not os.path.exists("transforms.py"):
    os.system(
        "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py -O transforms.py"
    )
if not os.path.exists("coco_utils.py"):
    os.system(
        "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py -O coco_utils.py"
    )
if not os.path.exists("coco_eval.py"):
    os.system(
        "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py -O coco_eval.py"
    )

# you also need to tweak them a bit to work with relative imports

# %%
from torchvision.models.detection import fasterrcnn_mobilenet_v3_large_fpn, FasterRCNN_MobileNet_V3_Large_FPN_Weights
from utils import collate_fn

model = fasterrcnn_mobilenet_v3_large_fpn(weights=FasterRCNN_MobileNet_V3_Large_FPN_Weights.DEFAULT)
dataset = FracAtlasDetection("data/FracAtlas", image_set="train", transform=get_transform(train=True))
data_loader = torch.utils.data.DataLoader(
  dataset,
  batch_size=2,
  shuffle=True,
  num_workers=4,
  collate_fn=collate_fn,
)

# For Training
images, targets = next(iter(data_loader))
images = list(image for image in images)
targets = [{k: v for k, v in t.items()} for t in targets]
output = model(images, targets)  # Returns losses and detections
print(output)

# For inference
model.eval()
x = [torch.rand(3, 300, 400), torch.rand(3, 500, 400)]
predictions = model(x)  # Returns predictions
print(predictions[0])
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_mobilenet_v3_large_fpn-fb6a3cc7.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_mobilenet_v3_large_fpn-fb6a3cc7.pth
# 100%|██████████| 74.2M/74.2M [00:00<00:00, 97.9MB/s]
# Downloading https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/41725659/FracAtlas.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20231010/eu-west-1/s3/aws4_request&X-Amz-Date=20231010T213811Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=f07a3c5a88a228c935f0e36924f95902209f565fd0c3768b5d8f35021168a069 to data/fracatlas.zip
# 100%|██████████| 338412751/338412751 [00:24<00:00, 13574015.49it/s]
# Extracting data/fracatlas.zip to data
# ['FracAtlas']
# {'loss_classifier': tensor(0.5121, grad_fn=<NllLossBackward0>), 'loss_box_reg': tensor(0.0309, grad_fn=<DivBackward0>), 'loss_objectness': tensor(0.6228, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>), 'loss_rpn_box_reg': tensor(0.0327, grad_fn=<DivBackward0>)}
# {'boxes': tensor([], size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], dtype=torch.int64), 'scores': tensor([], grad_fn=<IndexBackward0>)}

# %%
from engine import train_one_epoch, evaluate
from utils import collate_fn

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print("device:", device)

# use our dataset and defined transformations
dataset = FracAtlasDetection('data/FracAtlas', image_set="train", transform=get_transform(train=True))
dataset_test = FracAtlasDetection('data/FracAtlas', image_set="test", transform=get_transform(train=False))

# split the dataset in train and test set
# indices = torch.randperm(len(dataset)).tolist()
# dataset = torch.utils.data.Subset(dataset, indices[:-50])
# dataset_test = torch.utils.data.Subset(dataset_test, indices[-50:])

# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=2,
    shuffle=True,
    num_workers=4,
    collate_fn=collate_fn,
)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test,
    batch_size=1,
    shuffle=False,
    num_workers=4,
    collate_fn=collate_fn,
)

model = fasterrcnn_mobilenet_v3_large_fpn(weights=FasterRCNN_MobileNet_V3_Large_FPN_Weights.DEFAULT)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
    params,
    lr=0.005,
    momentum=0.9,
    weight_decay=0.0005
)

# and a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=3,
    gamma=0.1
)

# let's train it for 5 epochs
num_epochs = 5

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)

print("That's it!")

print("Saving")
torch.save(model, 'fracatlas_fasterrcnn-mobilenetv3_v0.pth')
print("Saved")
# Out:
# device: cuda
# Epoch: [0]  [  0/287]  eta: 0:52:02  lr: 0.000022  loss: 0.6759 (0.6759)  loss_classifier: 0.2515 (0.2515)  loss_box_reg: 0.0408 (0.0408)  loss_objectness: 0.3631 (0.3631)  loss_rpn_box_reg: 0.0205 (0.0205)  time: 10.8792  data: 1.5330  max mem: 866
# Epoch: [0]  [ 10/287]  eta: 0:05:20  lr: 0.000197  loss: 1.1438 (1.1696)  loss_classifier: 0.4476 (0.4881)  loss_box_reg: 0.1778 (0.2467)  loss_objectness: 0.3434 (0.3938)  loss_rpn_box_reg: 0.0295 (0.0410)  time: 1.1587  data: 0.1614  max mem: 925
# Epoch: [0]  [ 20/287]  eta: 0:03:09  lr: 0.000372  loss: 0.8827 (0.9753)  loss_classifier: 0.3133 (0.3678)  loss_box_reg: 0.1778 (0.2098)  loss_objectness: 0.2795 (0.3485)  loss_rpn_box_reg: 0.0361 (0.0492)  time: 0.2007  data: 0.0284  max mem: 1060
# Epoch: [0]  [ 30/287]  eta: 0:02:28  lr: 0.000546  loss: 0.6196 (0.8632)  loss_classifier: 0.1946 (0.3034)  loss_box_reg: 0.1608 (0.1926)  loss_objectness: 0.2429 (0.3165)  loss_rpn_box_reg: 0.0434 (0.0506)  time: 0.2609  data: 0.0363  max mem: 1060
# Epoch: [0]  [ 40/287]  eta: 0:01:58  lr: 0.000721  loss: 0.6244 (0.8136)  loss_classifier: 0.1948 (0.2804)  loss_box_reg: 0.2235 (0.2095)  loss_objectness: 0.1700 (0.2777)  loss_rpn_box_reg: 0.0324 (0.0459)  time: 0.2355  data: 0.0325  max mem: 1060
# Epoch: [0]  [ 50/287]  eta: 0:01:37  lr: 0.000896  loss: 0.7161 (0.8024)  loss_classifier: 0.2219 (0.2735)  loss_box_reg: 0.2648 (0.2322)  loss_objectness: 0.1273 (0.2545)  loss_rpn_box_reg: 0.0205 (0.0422)  time: 0.1542  data: 0.0237  max mem: 1060
# Epoch: [0]  [ 60/287]  eta: 0:01:23  lr: 0.001070  loss: 0.7366 (0.7832)  loss_classifier: 0.2298 (0.2626)  loss_box_reg: 0.3192 (0.2480)  loss_objectness: 0.1233 (0.2322)  loss_rpn_box_reg: 0.0197 (0.0404)  time: 0.1442  data: 0.0225  max mem: 1060
# Epoch: [0]  [ 70/287]  eta: 0:01:13  lr: 0.001245  loss: 0.7075 (0.7805)  loss_classifier: 0.2079 (0.2620)  loss_box_reg: 0.3412 (0.2634)  loss_objectness: 0.1084 (0.2178)  loss_rpn_box_reg: 0.0177 (0.0373)  time: 0.1515  data: 0.0205  max mem: 1060
# Epoch: [0]  [ 80/287]  eta: 0:01:05  lr: 0.001420  loss: 0.6762 (0.7720)  loss_classifier: 0.2250 (0.2604)  loss_box_reg: 0.3145 (0.2698)  loss_objectness: 0.1118 (0.2072)  loss_rpn_box_reg: 0.0127 (0.0347)  time: 0.1551  data: 0.0174  max mem: 1060
# Epoch: [0]  [ 90/287]  eta: 0:00:58  lr: 0.001594  loss: 0.6842 (0.7663)  loss_classifier: 0.2389 (0.2594)  loss_box_reg: 0.3116 (0.2753)  loss_objectness: 0.1118 (0.1984)  loss_rpn_box_reg: 0.0163 (0.0331)  time: 0.1588  data: 0.0177  max mem: 1060
# Epoch: [0]  [100/287]  eta: 0:00:54  lr: 0.001769  loss: 0.7356 (0.7683)  loss_classifier: 0.2406 (0.2596)  loss_box_reg: 0.3298 (0.2841)  loss_objectness: 0.1050 (0.1919)  loss_rpn_box_reg: 0.0215 (0.0327)  time: 0.1838  data: 0.0250  max mem: 1060
# Epoch: [0]  [110/287]  eta: 0:00:48  lr: 0.001944  loss: 0.8023 (0.7717)  loss_classifier: 0.2652 (0.2620)  loss_box_reg: 0.3407 (0.2933)  loss_objectness: 0.1050 (0.1849)  loss_rpn_box_reg: 0.0207 (0.0315)  time: 0.1673  data: 0.0248  max mem: 1060
# Epoch: [0]  [120/287]  eta: 0:00:45  lr: 0.002118  loss: 0.8023 (0.7765)  loss_classifier: 0.2908 (0.2656)  loss_box_reg: 0.3779 (0.3024)  loss_objectness: 0.1056 (0.1783)  loss_rpn_box_reg: 0.0142 (0.0302)  time: 0.1823  data: 0.0242  max mem: 1060
# Epoch: [0]  [130/287]  eta: 0:00:41  lr: 0.002293  loss: 0.8139 (0.7831)  loss_classifier: 0.2908 (0.2696)  loss_box_reg: 0.4141 (0.3121)  loss_objectness: 0.0988 (0.1722)  loss_rpn_box_reg: 0.0130 (0.0292)  time: 0.1996  data: 0.0277  max mem: 1060
# Epoch: [0]  [140/287]  eta: 0:00:37  lr: 0.002468  loss: 0.7286 (0.7755)  loss_classifier: 0.2561 (0.2685)  loss_box_reg: 0.3617 (0.3132)  loss_objectness: 0.0695 (0.1657)  loss_rpn_box_reg: 0.0117 (0.0281)  time: 0.1494  data: 0.0186  max mem: 1060
# Epoch: [0]  [150/287]  eta: 0:00:33  lr: 0.002642  loss: 0.6925 (0.7759)  loss_classifier: 0.2671 (0.2706)  loss_box_reg: 0.3251 (0.3166)  loss_objectness: 0.0698 (0.1614)  loss_rpn_box_reg: 0.0126 (0.0273)  time: 0.1350  data: 0.0136  max mem: 1060
# Epoch: [0]  [160/287]  eta: 0:00:30  lr: 0.002817  loss: 0.7633 (0.7783)  loss_classifier: 0.2866 (0.2709)  loss_box_reg: 0.3530 (0.3220)  loss_objectness: 0.0967 (0.1587)  loss_rpn_box_reg: 0.0126 (0.0268)  time: 0.1556  data: 0.0236  max mem: 1060
# Epoch: [0]  [170/287]  eta: 0:00:27  lr: 0.002992  loss: 0.8082 (0.7840)  loss_classifier: 0.2781 (0.2721)  loss_box_reg: 0.4005 (0.3283)  loss_objectness: 0.0967 (0.1569)  loss_rpn_box_reg: 0.0191 (0.0267)  time: 0.1705  data: 0.0290  max mem: 1060
# Epoch: [0]  [180/287]  eta: 0:00:24  lr: 0.003166  loss: 0.8082 (0.7890)  loss_classifier: 0.3014 (0.2742)  loss_box_reg: 0.4417 (0.3339)  loss_objectness: 0.0993 (0.1546)  loss_rpn_box_reg: 0.0196 (0.0263)  time: 0.1456  data: 0.0204  max mem: 1060
# Epoch: [0]  [190/287]  eta: 0:00:21  lr: 0.003341  loss: 0.7475 (0.7901)  loss_classifier: 0.2943 (0.2758)  loss_box_reg: 0.3975 (0.3373)  loss_objectness: 0.0993 (0.1513)  loss_rpn_box_reg: 0.0123 (0.0257)  time: 0.1231  data: 0.0137  max mem: 1060
# Epoch: [0]  [200/287]  eta: 0:00:19  lr: 0.003515  loss: 0.7436 (0.7908)  loss_classifier: 0.3001 (0.2777)  loss_box_reg: 0.3662 (0.3399)  loss_objectness: 0.0748 (0.1479)  loss_rpn_box_reg: 0.0119 (0.0252)  time: 0.1482  data: 0.0163  max mem: 1060
# Epoch: [0]  [210/287]  eta: 0:00:16  lr: 0.003690  loss: 0.7102 (0.7869)  loss_classifier: 0.2895 (0.2774)  loss_box_reg: 0.3561 (0.3394)  loss_objectness: 0.0707 (0.1453)  loss_rpn_box_reg: 0.0134 (0.0247)  time: 0.1512  data: 0.0169  max mem: 1060
# Epoch: [0]  [220/287]  eta: 0:00:14  lr: 0.003865  loss: 0.7583 (0.7903)  loss_classifier: 0.2772 (0.2786)  loss_box_reg: 0.3873 (0.3432)  loss_objectness: 0.0753 (0.1440)  loss_rpn_box_reg: 0.0162 (0.0244)  time: 0.1794  data: 0.0180  max mem: 1060
# Epoch: [0]  [230/287]  eta: 0:00:12  lr: 0.004039  loss: 0.8032 (0.7938)  loss_classifier: 0.2970 (0.2811)  loss_box_reg: 0.4294 (0.3464)  loss_objectness: 0.1102 (0.1423)  loss_rpn_box_reg: 0.0162 (0.0241)  time: 0.2010  data: 0.0242  max mem: 1060
# Epoch: [0]  [240/287]  eta: 0:00:10  lr: 0.004214  loss: 0.7346 (0.7916)  loss_classifier: 0.2865 (0.2811)  loss_box_reg: 0.3669 (0.3461)  loss_objectness: 0.0815 (0.1406)  loss_rpn_box_reg: 0.0117 (0.0238)  time: 0.1447  data: 0.0192  max mem: 1060
# Epoch: [0]  [250/287]  eta: 0:00:07  lr: 0.004389  loss: 0.6864 (0.7901)  loss_classifier: 0.2761 (0.2819)  loss_box_reg: 0.3158 (0.3469)  loss_objectness: 0.0747 (0.1379)  loss_rpn_box_reg: 0.0111 (0.0233)  time: 0.1364  data: 0.0150  max mem: 1060
# Epoch: [0]  [260/287]  eta: 0:00:05  lr: 0.004563  loss: 0.7718 (0.7927)  loss_classifier: 0.2941 (0.2840)  loss_box_reg: 0.3817 (0.3486)  loss_objectness: 0.0821 (0.1370)  loss_rpn_box_reg: 0.0114 (0.0231)  time: 0.1673  data: 0.0231  max mem: 1060
# Epoch: [0]  [270/287]  eta: 0:00:03  lr: 0.004738  loss: 0.7685 (0.7902)  loss_classifier: 0.3050 (0.2838)  loss_box_reg: 0.3535 (0.3467)  loss_objectness: 0.0987 (0.1367)  loss_rpn_box_reg: 0.0116 (0.0229)  time: 0.1550  data: 0.0205  max mem: 1060
# Epoch: [0]  [280/287]  eta: 0:00:01  lr: 0.004913  loss: 0.7024 (0.7870)  loss_classifier: 0.2367 (0.2823)  loss_box_reg: 0.3394 (0.3475)  loss_objectness: 0.0884 (0.1347)  loss_rpn_box_reg: 0.0130 (0.0225)  time: 0.1292  data: 0.0146  max mem: 1060
# Epoch: [0]  [286/287]  eta: 0:00:00  lr: 0.005000  loss: 0.6496 (0.7849)  loss_classifier: 0.2222 (0.2817)  loss_box_reg: 0.3471 (0.3473)  loss_objectness: 0.0790 (0.1337)  loss_rpn_box_reg: 0.0097 (0.0222)  time: 0.1231  data: 0.0118  max mem: 1060
# Epoch: [0] Total time: 0:00:58 (0.2026 s / it)
# creating index...
# index created!
# Test:  [ 0/61]  eta: 0:00:40  model_time: 0.1597 (0.1597)  evaluator_time: 0.0073 (0.0073)  time: 0.6669  data: 0.4985  max mem: 1060
# Test:  [60/61]  eta: 0:00:00  model_time: 0.0330 (0.0346)  evaluator_time: 0.0016 (0.0017)  time: 0.0413  data: 0.0052  max mem: 1060
# Test: Total time: 0:00:03 (0.0581 s / it)
# Averaged stats: model_time: 0.0330 (0.0346)  evaluator_time: 0.0016 (0.0017)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.174
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.557
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.029
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.177
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.215
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.373
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.373
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.379
# Epoch: [1]  [  0/287]  eta: 0:03:51  lr: 0.005000  loss: 0.6419 (0.6419)  loss_classifier: 0.1989 (0.1989)  loss_box_reg: 0.2112 (0.2112)  loss_objectness: 0.2157 (0.2157)  loss_rpn_box_reg: 0.0162 (0.0162)  time: 0.8075  data: 0.5607  max mem: 1060
# Epoch: [1]  [ 10/287]  eta: 0:01:19  lr: 0.005000  loss: 0.5609 (0.5937)  loss_classifier: 0.2058 (0.2234)  loss_box_reg: 0.2767 (0.2855)  loss_objectness: 0.0689 (0.0746)  loss_rpn_box_reg: 0.0084 (0.0101)  time: 0.2854  data: 0.1341  max mem: 1060
# Epoch: [1]  [ 20/287]  eta: 0:00:57  lr: 0.005000  loss: 0.5609 (0.6325)  loss_classifier: 0.2129 (0.2382)  loss_box_reg: 0.3203 (0.3054)  loss_objectness: 0.0689 (0.0779)  loss_rpn_box_reg: 0.0101 (0.0110)  time: 0.1864  data: 0.0551  max mem: 1060
# Epoch: [1]  [ 30/287]  eta: 0:00:51  lr: 0.005000  loss: 0.7187 (0.6528)  loss_classifier: 0.2538 (0.2500)  loss_box_reg: 0.3365 (0.3141)  loss_objectness: 0.0677 (0.0775)  loss_rpn_box_reg: 0.0109 (0.0112)  time: 0.1563  data: 0.0251  max mem: 1060
# Epoch: [1]  [ 40/287]  eta: 0:00:46  lr: 0.005000  loss: 0.7340 (0.6815)  loss_classifier: 0.2909 (0.2611)  loss_box_reg: 0.3608 (0.3309)  loss_objectness: 0.0621 (0.0785)  loss_rpn_box_reg: 0.0082 (0.0110)  time: 0.1629  data: 0.0234  max mem: 1060
# Epoch: [1]  [ 50/287]  eta: 0:00:41  lr: 0.005000  loss: 0.7626 (0.7160)  loss_classifier: 0.2904 (0.2706)  loss_box_reg: 0.4213 (0.3522)  loss_objectness: 0.0731 (0.0811)  loss_rpn_box_reg: 0.0104 (0.0122)  time: 0.1378  data: 0.0136  max mem: 1060
# Epoch: [1]  [ 60/287]  eta: 0:00:38  lr: 0.005000  loss: 0.7403 (0.7200)  loss_classifier: 0.2764 (0.2735)  loss_box_reg: 0.3803 (0.3526)  loss_objectness: 0.0797 (0.0814)  loss_rpn_box_reg: 0.0133 (0.0125)  time: 0.1231  data: 0.0121  max mem: 1060
# Epoch: [1]  [ 70/287]  eta: 0:00:35  lr: 0.005000  loss: 0.7330 (0.7322)  loss_classifier: 0.2764 (0.2800)  loss_box_reg: 0.3392 (0.3581)  loss_objectness: 0.0680 (0.0810)  loss_rpn_box_reg: 0.0133 (0.0132)  time: 0.1319  data: 0.0121  max mem: 1060
# Epoch: [1]  [ 80/287]  eta: 0:00:35  lr: 0.005000  loss: 0.6343 (0.7286)  loss_classifier: 0.2674 (0.2796)  loss_box_reg: 0.3248 (0.3555)  loss_objectness: 0.0636 (0.0804)  loss_rpn_box_reg: 0.0133 (0.0132)  time: 0.1875  data: 0.0256  max mem: 1060
# Epoch: [1]  [ 90/287]  eta: 0:00:34  lr: 0.005000  loss: 0.6924 (0.7394)  loss_classifier: 0.2842 (0.2866)  loss_box_reg: 0.3248 (0.3582)  loss_objectness: 0.0712 (0.0811)  loss_rpn_box_reg: 0.0122 (0.0136)  time: 0.2147  data: 0.0354  max mem: 1060
# Epoch: [1]  [100/287]  eta: 0:00:32  lr: 0.005000  loss: 0.7260 (0.7339)  loss_classifier: 0.2842 (0.2835)  loss_box_reg: 0.3516 (0.3577)  loss_objectness: 0.0712 (0.0794)  loss_rpn_box_reg: 0.0105 (0.0133)  time: 0.1887  data: 0.0322  max mem: 1060
# Epoch: [1]  [110/287]  eta: 0:00:30  lr: 0.005000  loss: 0.6967 (0.7283)  loss_classifier: 0.2511 (0.2825)  loss_box_reg: 0.3516 (0.3528)  loss_objectness: 0.0582 (0.0793)  loss_rpn_box_reg: 0.0114 (0.0137)  time: 0.1622  data: 0.0241  max mem: 1060
# Epoch: [1]  [120/287]  eta: 0:00:28  lr: 0.005000  loss: 0.6373 (0.7281)  loss_classifier: 0.2490 (0.2823)  loss_box_reg: 0.3201 (0.3515)  loss_objectness: 0.0679 (0.0805)  loss_rpn_box_reg: 0.0134 (0.0138)  time: 0.1577  data: 0.0233  max mem: 1060
# Epoch: [1]  [130/287]  eta: 0:00:26  lr: 0.005000  loss: 0.5981 (0.7220)  loss_classifier: 0.2606 (0.2798)  loss_box_reg: 0.3201 (0.3459)  loss_objectness: 0.0776 (0.0820)  loss_rpn_box_reg: 0.0139 (0.0143)  time: 0.1618  data: 0.0263  max mem: 1060
# Epoch: [1]  [140/287]  eta: 0:00:24  lr: 0.005000  loss: 0.6769 (0.7212)  loss_classifier: 0.2621 (0.2798)  loss_box_reg: 0.2981 (0.3450)  loss_objectness: 0.0819 (0.0820)  loss_rpn_box_reg: 0.0148 (0.0143)  time: 0.1492  data: 0.0188  max mem: 1060
# Epoch: [1]  [150/287]  eta: 0:00:23  lr: 0.005000  loss: 0.7012 (0.7196)  loss_classifier: 0.2498 (0.2784)  loss_box_reg: 0.3680 (0.3454)  loss_objectness: 0.0762 (0.0814)  loss_rpn_box_reg: 0.0103 (0.0145)  time: 0.1477  data: 0.0178  max mem: 1060
# Epoch: [1]  [160/287]  eta: 0:00:21  lr: 0.005000  loss: 0.7012 (0.7176)  loss_classifier: 0.2467 (0.2783)  loss_box_reg: 0.3486 (0.3443)  loss_objectness: 0.0567 (0.0809)  loss_rpn_box_reg: 0.0103 (0.0141)  time: 0.1472  data: 0.0200  max mem: 1060
# Epoch: [1]  [170/287]  eta: 0:00:20  lr: 0.005000  loss: 0.6056 (0.7125)  loss_classifier: 0.2236 (0.2763)  loss_box_reg: 0.2887 (0.3415)  loss_objectness: 0.0612 (0.0806)  loss_rpn_box_reg: 0.0111 (0.0140)  time: 0.1944  data: 0.0280  max mem: 1060
# Epoch: [1]  [180/287]  eta: 0:00:18  lr: 0.005000  loss: 0.5882 (0.7051)  loss_classifier: 0.2155 (0.2737)  loss_box_reg: 0.2733 (0.3385)  loss_objectness: 0.0507 (0.0788)  loss_rpn_box_reg: 0.0122 (0.0141)  time: 0.2357  data: 0.0395  max mem: 1060
# Epoch: [1]  [190/287]  eta: 0:00:16  lr: 0.005000  loss: 0.6149 (0.7101)  loss_classifier: 0.2633 (0.2767)  loss_box_reg: 0.3000 (0.3406)  loss_objectness: 0.0382 (0.0786)  loss_rpn_box_reg: 0.0118 (0.0142)  time: 0.1983  data: 0.0332  max mem: 1060
# Epoch: [1]  [200/287]  eta: 0:00:14  lr: 0.005000  loss: 0.7391 (0.7118)  loss_classifier: 0.2938 (0.2777)  loss_box_reg: 0.3369 (0.3416)  loss_objectness: 0.0694 (0.0784)  loss_rpn_box_reg: 0.0115 (0.0141)  time: 0.1476  data: 0.0205  max mem: 1060
# Epoch: [1]  [210/287]  eta: 0:00:13  lr: 0.005000  loss: 0.7206 (0.7141)  loss_classifier: 0.2932 (0.2791)  loss_box_reg: 0.3326 (0.3419)  loss_objectness: 0.0724 (0.0791)  loss_rpn_box_reg: 0.0105 (0.0140)  time: 0.1400  data: 0.0190  max mem: 1060
# Epoch: [1]  [220/287]  eta: 0:00:11  lr: 0.005000  loss: 0.7080 (0.7134)  loss_classifier: 0.2714 (0.2786)  loss_box_reg: 0.3292 (0.3401)  loss_objectness: 0.0821 (0.0806)  loss_rpn_box_reg: 0.0118 (0.0140)  time: 0.1473  data: 0.0192  max mem: 1060
# Epoch: [1]  [230/287]  eta: 0:00:09  lr: 0.005000  loss: 0.6943 (0.7131)  loss_classifier: 0.2661 (0.2780)  loss_box_reg: 0.3030 (0.3390)  loss_objectness: 0.0952 (0.0821)  loss_rpn_box_reg: 0.0118 (0.0140)  time: 0.1384  data: 0.0181  max mem: 1060
# Epoch: [1]  [240/287]  eta: 0:00:07  lr: 0.005000  loss: 0.5703 (0.7077)  loss_classifier: 0.2483 (0.2759)  loss_box_reg: 0.2627 (0.3362)  loss_objectness: 0.0836 (0.0818)  loss_rpn_box_reg: 0.0113 (0.0138)  time: 0.1339  data: 0.0178  max mem: 1060
# Epoch: [1]  [250/287]  eta: 0:00:06  lr: 0.005000  loss: 0.5539 (0.7058)  loss_classifier: 0.2196 (0.2752)  loss_box_reg: 0.2674 (0.3354)  loss_objectness: 0.0703 (0.0814)  loss_rpn_box_reg: 0.0103 (0.0138)  time: 0.1435  data: 0.0166  max mem: 1060
# Epoch: [1]  [260/287]  eta: 0:00:04  lr: 0.005000  loss: 0.5965 (0.7022)  loss_classifier: 0.2252 (0.2737)  loss_box_reg: 0.3008 (0.3337)  loss_objectness: 0.0703 (0.0809)  loss_rpn_box_reg: 0.0098 (0.0139)  time: 0.1798  data: 0.0313  max mem: 1060
# Epoch: [1]  [270/287]  eta: 0:00:02  lr: 0.005000  loss: 0.6212 (0.7013)  loss_classifier: 0.2383 (0.2736)  loss_box_reg: 0.3000 (0.3331)  loss_objectness: 0.0635 (0.0807)  loss_rpn_box_reg: 0.0116 (0.0139)  time: 0.2195  data: 0.0443  max mem: 1060
# Epoch: [1]  [280/287]  eta: 0:00:01  lr: 0.005000  loss: 0.6447 (0.7004)  loss_classifier: 0.2397 (0.2727)  loss_box_reg: 0.3253 (0.3337)  loss_objectness: 0.0447 (0.0802)  loss_rpn_box_reg: 0.0117 (0.0138)  time: 0.2133  data: 0.0319  max mem: 1060
# Epoch: [1]  [286/287]  eta: 0:00:00  lr: 0.005000  loss: 0.6218 (0.7007)  loss_classifier: 0.2413 (0.2724)  loss_box_reg: 0.3253 (0.3349)  loss_objectness: 0.0511 (0.0796)  loss_rpn_box_reg: 0.0117 (0.0138)  time: 0.1627  data: 0.0200  max mem: 1060
# Epoch: [1] Total time: 0:00:49 (0.1709 s / it)
# creating index...
# index created!
# Test:  [ 0/61]  eta: 0:00:25  model_time: 0.0422 (0.0422)  evaluator_time: 0.0017 (0.0017)  time: 0.4218  data: 0.3761  max mem: 1060
# Test:  [60/61]  eta: 0:00:00  model_time: 0.0227 (0.0243)  evaluator_time: 0.0009 (0.0010)  time: 0.0280  data: 0.0032  max mem: 1060
# Test: Total time: 0:00:02 (0.0397 s / it)
# Averaged stats: model_time: 0.0227 (0.0243)  evaluator_time: 0.0009 (0.0010)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.252
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.692
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.122
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.256
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.270
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.466
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.466
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.473
# Epoch: [2]  [  0/287]  eta: 0:02:47  lr: 0.005000  loss: 0.5481 (0.5481)  loss_classifier: 0.2171 (0.2171)  loss_box_reg: 0.2346 (0.2346)  loss_objectness: 0.0916 (0.0916)  loss_rpn_box_reg: 0.0049 (0.0049)  time: 0.5826  data: 0.3896  max mem: 1060
# Epoch: [2]  [ 10/287]  eta: 0:00:52  lr: 0.005000  loss: 0.5982 (0.6368)  loss_classifier: 0.2566 (0.2646)  loss_box_reg: 0.2362 (0.2783)  loss_objectness: 0.0895 (0.0803)  loss_rpn_box_reg: 0.0112 (0.0136)  time: 0.1905  data: 0.0625  max mem: 1060
# Epoch: [2]  [ 20/287]  eta: 0:00:44  lr: 0.005000  loss: 0.6459 (0.6433)  loss_classifier: 0.2479 (0.2592)  loss_box_reg: 0.2997 (0.2969)  loss_objectness: 0.0634 (0.0735)  loss_rpn_box_reg: 0.0129 (0.0137)  time: 0.1448  data: 0.0244  max mem: 1060
# Epoch: [2]  [ 30/287]  eta: 0:00:38  lr: 0.005000  loss: 0.5787 (0.6300)  loss_classifier: 0.2249 (0.2545)  loss_box_reg: 0.3011 (0.2912)  loss_objectness: 0.0591 (0.0708)  loss_rpn_box_reg: 0.0125 (0.0135)  time: 0.1277  data: 0.0146  max mem: 1060
# Epoch: [2]  [ 40/287]  eta: 0:00:35  lr: 0.005000  loss: 0.6573 (0.6334)  loss_classifier: 0.2249 (0.2560)  loss_box_reg: 0.3051 (0.2971)  loss_objectness: 0.0507 (0.0680)  loss_rpn_box_reg: 0.0085 (0.0123)  time: 0.1194  data: 0.0120  max mem: 1060
# Epoch: [2]  [ 50/287]  eta: 0:00:34  lr: 0.005000  loss: 0.6737 (0.6438)  loss_classifier: 0.2608 (0.2597)  loss_box_reg: 0.3125 (0.3007)  loss_objectness: 0.0507 (0.0702)  loss_rpn_box_reg: 0.0117 (0.0131)  time: 0.1435  data: 0.0204  max mem: 1060
# Epoch: [2]  [ 60/287]  eta: 0:00:37  lr: 0.005000  loss: 0.5924 (0.6396)  loss_classifier: 0.2487 (0.2591)  loss_box_reg: 0.2424 (0.2964)  loss_objectness: 0.0841 (0.0710)  loss_rpn_box_reg: 0.0143 (0.0132)  time: 0.2053  data: 0.0322  max mem: 1060
# Epoch: [2]  [ 70/287]  eta: 0:00:38  lr: 0.005000  loss: 0.5395 (0.6351)  loss_classifier: 0.2251 (0.2592)  loss_box_reg: 0.2365 (0.2927)  loss_objectness: 0.0538 (0.0704)  loss_rpn_box_reg: 0.0088 (0.0127)  time: 0.2458  data: 0.0429  max mem: 1060
# Epoch: [2]  [ 80/287]  eta: 0:00:36  lr: 0.005000  loss: 0.5395 (0.6271)  loss_classifier: 0.2200 (0.2555)  loss_box_reg: 0.2298 (0.2892)  loss_objectness: 0.0465 (0.0697)  loss_rpn_box_reg: 0.0089 (0.0127)  time: 0.2063  data: 0.0356  max mem: 1060
# Epoch: [2]  [ 90/287]  eta: 0:00:33  lr: 0.005000  loss: 0.5969 (0.6288)  loss_classifier: 0.2397 (0.2552)  loss_box_reg: 0.3058 (0.2930)  loss_objectness: 0.0487 (0.0678)  loss_rpn_box_reg: 0.0114 (0.0127)  time: 0.1471  data: 0.0195  max mem: 1060
# Epoch: [2]  [100/287]  eta: 0:00:31  lr: 0.005000  loss: 0.6714 (0.6382)  loss_classifier: 0.2804 (0.2585)  loss_box_reg: 0.3385 (0.2999)  loss_objectness: 0.0557 (0.0671)  loss_rpn_box_reg: 0.0100 (0.0126)  time: 0.1385  data: 0.0181  max mem: 1060
# Epoch: [2]  [110/287]  eta: 0:00:29  lr: 0.005000  loss: 0.6385 (0.6359)  loss_classifier: 0.2625 (0.2571)  loss_box_reg: 0.3209 (0.2999)  loss_objectness: 0.0473 (0.0662)  loss_rpn_box_reg: 0.0109 (0.0127)  time: 0.1601  data: 0.0239  max mem: 1060
# Epoch: [2]  [120/287]  eta: 0:00:27  lr: 0.005000  loss: 0.6043 (0.6360)  loss_classifier: 0.2464 (0.2563)  loss_box_reg: 0.2674 (0.3015)  loss_objectness: 0.0438 (0.0654)  loss_rpn_box_reg: 0.0109 (0.0128)  time: 0.1521  data: 0.0235  max mem: 1060
# Epoch: [2]  [130/287]  eta: 0:00:25  lr: 0.005000  loss: 0.6087 (0.6365)  loss_classifier: 0.2498 (0.2572)  loss_box_reg: 0.3046 (0.3019)  loss_objectness: 0.0407 (0.0648)  loss_rpn_box_reg: 0.0102 (0.0126)  time: 0.1278  data: 0.0151  max mem: 1060
# Epoch: [2]  [140/287]  eta: 0:00:24  lr: 0.005000  loss: 0.5924 (0.6344)  loss_classifier: 0.2410 (0.2548)  loss_box_reg: 0.3089 (0.3010)  loss_objectness: 0.0684 (0.0658)  loss_rpn_box_reg: 0.0103 (0.0128)  time: 0.1599  data: 0.0201  max mem: 1060
# Epoch: [2]  [150/287]  eta: 0:00:23  lr: 0.005000  loss: 0.5749 (0.6305)  loss_classifier: 0.2043 (0.2531)  loss_box_reg: 0.2580 (0.2981)  loss_objectness: 0.0702 (0.0666)  loss_rpn_box_reg: 0.0126 (0.0128)  time: 0.2383  data: 0.0402  max mem: 1060
# Epoch: [2]  [160/287]  eta: 0:00:22  lr: 0.005000  loss: 0.5915 (0.6308)  loss_classifier: 0.2245 (0.2533)  loss_box_reg: 0.2566 (0.2985)  loss_objectness: 0.0599 (0.0664)  loss_rpn_box_reg: 0.0094 (0.0126)  time: 0.2557  data: 0.0478  max mem: 1060
# Epoch: [2]  [170/287]  eta: 0:00:20  lr: 0.005000  loss: 0.5915 (0.6285)  loss_classifier: 0.2245 (0.2518)  loss_box_reg: 0.2834 (0.2989)  loss_objectness: 0.0390 (0.0654)  loss_rpn_box_reg: 0.0091 (0.0125)  time: 0.1815  data: 0.0317  max mem: 1060
# Epoch: [2]  [180/287]  eta: 0:00:18  lr: 0.005000  loss: 0.6213 (0.6309)  loss_classifier: 0.2520 (0.2534)  loss_box_reg: 0.2833 (0.2997)  loss_objectness: 0.0457 (0.0654)  loss_rpn_box_reg: 0.0095 (0.0124)  time: 0.1326  data: 0.0186  max mem: 1060
# Epoch: [2]  [190/287]  eta: 0:00:16  lr: 0.005000  loss: 0.6336 (0.6328)  loss_classifier: 0.2645 (0.2547)  loss_box_reg: 0.2833 (0.3006)  loss_objectness: 0.0517 (0.0654)  loss_rpn_box_reg: 0.0082 (0.0122)  time: 0.1353  data: 0.0186  max mem: 1060
# Epoch: [2]  [200/287]  eta: 0:00:14  lr: 0.005000  loss: 0.6844 (0.6353)  loss_classifier: 0.2728 (0.2555)  loss_box_reg: 0.3531 (0.3026)  loss_objectness: 0.0548 (0.0650)  loss_rpn_box_reg: 0.0095 (0.0122)  time: 0.1335  data: 0.0172  max mem: 1060
# Epoch: [2]  [210/287]  eta: 0:00:12  lr: 0.005000  loss: 0.7097 (0.6391)  loss_classifier: 0.2751 (0.2564)  loss_box_reg: 0.3677 (0.3050)  loss_objectness: 0.0548 (0.0654)  loss_rpn_box_reg: 0.0109 (0.0123)  time: 0.1313  data: 0.0171  max mem: 1060
# Epoch: [2]  [220/287]  eta: 0:00:10  lr: 0.005000  loss: 0.6745 (0.6406)  loss_classifier: 0.2444 (0.2565)  loss_box_reg: 0.3170 (0.3073)  loss_objectness: 0.0454 (0.0644)  loss_rpn_box_reg: 0.0116 (0.0124)  time: 0.1228  data: 0.0155  max mem: 1060
# Epoch: [2]  [230/287]  eta: 0:00:09  lr: 0.005000  loss: 0.6150 (0.6423)  loss_classifier: 0.2400 (0.2574)  loss_box_reg: 0.2992 (0.3081)  loss_objectness: 0.0436 (0.0643)  loss_rpn_box_reg: 0.0112 (0.0124)  time: 0.1205  data: 0.0146  max mem: 1060
# Epoch: [2]  [240/287]  eta: 0:00:07  lr: 0.005000  loss: 0.6438 (0.6441)  loss_classifier: 0.2799 (0.2587)  loss_box_reg: 0.3029 (0.3086)  loss_objectness: 0.0595 (0.0644)  loss_rpn_box_reg: 0.0110 (0.0124)  time: 0.1717  data: 0.0198  max mem: 1060
# Epoch: [2]  [250/287]  eta: 0:00:06  lr: 0.005000  loss: 0.6043 (0.6440)  loss_classifier: 0.2722 (0.2591)  loss_box_reg: 0.2905 (0.3075)  loss_objectness: 0.0595 (0.0649)  loss_rpn_box_reg: 0.0094 (0.0124)  time: 0.2442  data: 0.0426  max mem: 1060
# Epoch: [2]  [260/287]  eta: 0:00:04  lr: 0.005000  loss: 0.6043 (0.6465)  loss_classifier: 0.2392 (0.2594)  loss_box_reg: 0.2905 (0.3089)  loss_objectness: 0.0611 (0.0658)  loss_rpn_box_reg: 0.0082 (0.0124)  time: 0.2086  data: 0.0411  max mem: 1060
# Epoch: [2]  [270/287]  eta: 0:00:02  lr: 0.005000  loss: 0.6780 (0.6473)  loss_classifier: 0.2379 (0.2594)  loss_box_reg: 0.3167 (0.3103)  loss_objectness: 0.0517 (0.0653)  loss_rpn_box_reg: 0.0093 (0.0124)  time: 0.1355  data: 0.0152  max mem: 1060
# Epoch: [2]  [280/287]  eta: 0:00:01  lr: 0.005000  loss: 0.6286 (0.6475)  loss_classifier: 0.2374 (0.2599)  loss_box_reg: 0.3081 (0.3100)  loss_objectness: 0.0512 (0.0653)  loss_rpn_box_reg: 0.0078 (0.0123)  time: 0.1412  data: 0.0156  max mem: 1060
# Epoch: [2]  [286/287]  eta: 0:00:00  lr: 0.005000  loss: 0.6393 (0.6507)  loss_classifier: 0.2814 (0.2610)  loss_box_reg: 0.3141 (0.3125)  loss_objectness: 0.0472 (0.0649)  loss_rpn_box_reg: 0.0078 (0.0123)  time: 0.1400  data: 0.0168  max mem: 1064
# Epoch: [2] Total time: 0:00:47 (0.1656 s / it)
# creating index...
# index created!
# Test:  [ 0/61]  eta: 0:00:25  model_time: 0.0421 (0.0421)  evaluator_time: 0.0019 (0.0019)  time: 0.4139  data: 0.3683  max mem: 1064
# Test:  [60/61]  eta: 0:00:00  model_time: 0.0231 (0.0247)  evaluator_time: 0.0010 (0.0011)  time: 0.0282  data: 0.0033  max mem: 1064
# Test: Total time: 0:00:02 (0.0401 s / it)
# Averaged stats: model_time: 0.0231 (0.0247)  evaluator_time: 0.0010 (0.0011)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.296
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.721
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.103
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.300
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.318
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.482
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.482
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.489
# Epoch: [3]  [  0/287]  eta: 0:02:52  lr: 0.000500  loss: 0.6556 (0.6556)  loss_classifier: 0.2820 (0.2820)  loss_box_reg: 0.2979 (0.2979)  loss_objectness: 0.0559 (0.0559)  loss_rpn_box_reg: 0.0199 (0.0199)  time: 0.6022  data: 0.3884  max mem: 1064
# Epoch: [3]  [ 10/287]  eta: 0:01:00  lr: 0.000500  loss: 0.6423 (0.6563)  loss_classifier: 0.2666 (0.2832)  loss_box_reg: 0.3299 (0.3262)  loss_objectness: 0.0303 (0.0374)  loss_rpn_box_reg: 0.0093 (0.0094)  time: 0.2191  data: 0.0878  max mem: 1064
# Epoch: [3]  [ 20/287]  eta: 0:00:55  lr: 0.000500  loss: 0.5613 (0.6092)  loss_classifier: 0.2516 (0.2638)  loss_box_reg: 0.2546 (0.2880)  loss_objectness: 0.0364 (0.0475)  loss_rpn_box_reg: 0.0093 (0.0100)  time: 0.1882  data: 0.0445  max mem: 1064
# Epoch: [3]  [ 30/287]  eta: 0:00:55  lr: 0.000500  loss: 0.5885 (0.6407)  loss_classifier: 0.2582 (0.2731)  loss_box_reg: 0.2446 (0.3033)  loss_objectness: 0.0563 (0.0537)  loss_rpn_box_reg: 0.0107 (0.0106)  time: 0.2146  data: 0.0360  max mem: 1064
# Epoch: [3]  [ 40/287]  eta: 0:00:49  lr: 0.000500  loss: 0.6929 (0.6422)  loss_classifier: 0.2874 (0.2723)  loss_box_reg: 0.3218 (0.3062)  loss_objectness: 0.0563 (0.0529)  loss_rpn_box_reg: 0.0111 (0.0108)  time: 0.1917  data: 0.0280  max mem: 1064
# Epoch: [3]  [ 50/287]  eta: 0:00:49  lr: 0.000500  loss: 0.6549 (0.6486)  loss_classifier: 0.2870 (0.2728)  loss_box_reg: 0.3218 (0.3090)  loss_objectness: 0.0550 (0.0560)  loss_rpn_box_reg: 0.0089 (0.0108)  time: 0.1957  data: 0.0199  max mem: 1064
# Epoch: [3]  [ 60/287]  eta: 0:00:46  lr: 0.000500  loss: 0.6549 (0.6483)  loss_classifier: 0.2645 (0.2709)  loss_box_reg: 0.3369 (0.3101)  loss_objectness: 0.0417 (0.0567)  loss_rpn_box_reg: 0.0072 (0.0106)  time: 0.2110  data: 0.0257  max mem: 1064
# Epoch: [3]  [ 70/287]  eta: 0:00:41  lr: 0.000500  loss: 0.6595 (0.6479)  loss_classifier: 0.2507 (0.2693)  loss_box_reg: 0.3462 (0.3140)  loss_objectness: 0.0374 (0.0542)  loss_rpn_box_reg: 0.0071 (0.0105)  time: 0.1550  data: 0.0215  max mem: 1064
# Epoch: [3]  [ 80/287]  eta: 0:00:38  lr: 0.000500  loss: 0.6934 (0.6584)  loss_classifier: 0.2533 (0.2724)  loss_box_reg: 0.3344 (0.3177)  loss_objectness: 0.0414 (0.0578)  loss_rpn_box_reg: 0.0092 (0.0106)  time: 0.1372  data: 0.0167  max mem: 1064
# Epoch: [3]  [ 90/287]  eta: 0:00:36  lr: 0.000500  loss: 0.6986 (0.6528)  loss_classifier: 0.2569 (0.2700)  loss_box_reg: 0.3185 (0.3148)  loss_objectness: 0.0556 (0.0575)  loss_rpn_box_reg: 0.0089 (0.0106)  time: 0.1489  data: 0.0195  max mem: 1064
# Epoch: [3]  [100/287]  eta: 0:00:33  lr: 0.000500  loss: 0.5621 (0.6465)  loss_classifier: 0.2454 (0.2675)  loss_box_reg: 0.2601 (0.3083)  loss_objectness: 0.0561 (0.0598)  loss_rpn_box_reg: 0.0091 (0.0109)  time: 0.1367  data: 0.0182  max mem: 1064
# Epoch: [3]  [110/287]  eta: 0:00:30  lr: 0.000500  loss: 0.5647 (0.6430)  loss_classifier: 0.2454 (0.2663)  loss_box_reg: 0.2530 (0.3062)  loss_objectness: 0.0527 (0.0594)  loss_rpn_box_reg: 0.0100 (0.0111)  time: 0.1285  data: 0.0175  max mem: 1064
# Epoch: [3]  [120/287]  eta: 0:00:28  lr: 0.000500  loss: 0.5950 (0.6407)  loss_classifier: 0.2439 (0.2656)  loss_box_reg: 0.2978 (0.3046)  loss_objectness: 0.0458 (0.0592)  loss_rpn_box_reg: 0.0100 (0.0114)  time: 0.1367  data: 0.0188  max mem: 1064
# Epoch: [3]  [130/287]  eta: 0:00:26  lr: 0.000500  loss: 0.5950 (0.6341)  loss_classifier: 0.2439 (0.2623)  loss_box_reg: 0.2846 (0.3031)  loss_objectness: 0.0389 (0.0572)  loss_rpn_box_reg: 0.0100 (0.0114)  time: 0.1411  data: 0.0171  max mem: 1064
# Epoch: [3]  [140/287]  eta: 0:00:25  lr: 0.000500  loss: 0.5989 (0.6357)  loss_classifier: 0.2447 (0.2628)  loss_box_reg: 0.2747 (0.3044)  loss_objectness: 0.0310 (0.0572)  loss_rpn_box_reg: 0.0072 (0.0113)  time: 0.1791  data: 0.0281  max mem: 1064
# Epoch: [3]  [150/287]  eta: 0:00:23  lr: 0.000500  loss: 0.6432 (0.6364)  loss_classifier: 0.2689 (0.2631)  loss_box_reg: 0.2993 (0.3051)  loss_objectness: 0.0505 (0.0571)  loss_rpn_box_reg: 0.0082 (0.0112)  time: 0.1898  data: 0.0292  max mem: 1064
# Epoch: [3]  [160/287]  eta: 0:00:21  lr: 0.000500  loss: 0.6507 (0.6362)  loss_classifier: 0.2642 (0.2634)  loss_box_reg: 0.2893 (0.3042)  loss_objectness: 0.0513 (0.0576)  loss_rpn_box_reg: 0.0090 (0.0110)  time: 0.1776  data: 0.0223  max mem: 1064
# Epoch: [3]  [170/287]  eta: 0:00:20  lr: 0.000500  loss: 0.5915 (0.6330)  loss_classifier: 0.2557 (0.2630)  loss_box_reg: 0.2541 (0.3025)  loss_objectness: 0.0447 (0.0566)  loss_rpn_box_reg: 0.0080 (0.0109)  time: 0.1774  data: 0.0269  max mem: 1064
# Epoch: [3]  [180/287]  eta: 0:00:18  lr: 0.000500  loss: 0.5273 (0.6298)  loss_classifier: 0.2216 (0.2620)  loss_box_reg: 0.2517 (0.3009)  loss_objectness: 0.0447 (0.0561)  loss_rpn_box_reg: 0.0080 (0.0108)  time: 0.1413  data: 0.0216  max mem: 1064
# Epoch: [3]  [190/287]  eta: 0:00:16  lr: 0.000500  loss: 0.5153 (0.6233)  loss_classifier: 0.2216 (0.2600)  loss_box_reg: 0.2164 (0.2971)  loss_objectness: 0.0351 (0.0556)  loss_rpn_box_reg: 0.0068 (0.0106)  time: 0.1270  data: 0.0150  max mem: 1064
# Epoch: [3]  [200/287]  eta: 0:00:14  lr: 0.000500  loss: 0.4815 (0.6181)  loss_classifier: 0.2014 (0.2578)  loss_box_reg: 0.2164 (0.2941)  loss_objectness: 0.0465 (0.0557)  loss_rpn_box_reg: 0.0068 (0.0105)  time: 0.1360  data: 0.0171  max mem: 1064
# Epoch: [3]  [210/287]  eta: 0:00:12  lr: 0.000500  loss: 0.4824 (0.6145)  loss_classifier: 0.2132 (0.2567)  loss_box_reg: 0.2244 (0.2925)  loss_objectness: 0.0412 (0.0548)  loss_rpn_box_reg: 0.0098 (0.0105)  time: 0.1573  data: 0.0214  max mem: 1064
# Epoch: [3]  [220/287]  eta: 0:00:11  lr: 0.000500  loss: 0.4883 (0.6108)  loss_classifier: 0.2164 (0.2553)  loss_box_reg: 0.2344 (0.2904)  loss_objectness: 0.0358 (0.0547)  loss_rpn_box_reg: 0.0097 (0.0104)  time: 0.1727  data: 0.0226  max mem: 1064
# Epoch: [3]  [230/287]  eta: 0:00:09  lr: 0.000500  loss: 0.4996 (0.6113)  loss_classifier: 0.2233 (0.2551)  loss_box_reg: 0.2278 (0.2909)  loss_objectness: 0.0408 (0.0548)  loss_rpn_box_reg: 0.0095 (0.0105)  time: 0.1871  data: 0.0277  max mem: 1064
# Epoch: [3]  [240/287]  eta: 0:00:07  lr: 0.000500  loss: 0.5383 (0.6097)  loss_classifier: 0.2349 (0.2545)  loss_box_reg: 0.2488 (0.2902)  loss_objectness: 0.0419 (0.0543)  loss_rpn_box_reg: 0.0102 (0.0106)  time: 0.1997  data: 0.0319  max mem: 1064
# Epoch: [3]  [250/287]  eta: 0:00:06  lr: 0.000500  loss: 0.5655 (0.6117)  loss_classifier: 0.2528 (0.2555)  loss_box_reg: 0.2610 (0.2911)  loss_objectness: 0.0469 (0.0544)  loss_rpn_box_reg: 0.0102 (0.0107)  time: 0.2237  data: 0.0365  max mem: 1064
# Epoch: [3]  [260/287]  eta: 0:00:04  lr: 0.000500  loss: 0.6517 (0.6122)  loss_classifier: 0.2584 (0.2558)  loss_box_reg: 0.3119 (0.2917)  loss_objectness: 0.0487 (0.0540)  loss_rpn_box_reg: 0.0096 (0.0107)  time: 0.2153  data: 0.0358  max mem: 1064
# Epoch: [3]  [270/287]  eta: 0:00:02  lr: 0.000500  loss: 0.6248 (0.6117)  loss_classifier: 0.2311 (0.2556)  loss_box_reg: 0.2887 (0.2913)  loss_objectness: 0.0487 (0.0542)  loss_rpn_box_reg: 0.0082 (0.0107)  time: 0.1931  data: 0.0334  max mem: 1064
# Epoch: [3]  [280/287]  eta: 0:00:01  lr: 0.000500  loss: 0.6248 (0.6123)  loss_classifier: 0.2545 (0.2555)  loss_box_reg: 0.3181 (0.2924)  loss_objectness: 0.0455 (0.0538)  loss_rpn_box_reg: 0.0072 (0.0106)  time: 0.1648  data: 0.0266  max mem: 1064
# Epoch: [3]  [286/287]  eta: 0:00:00  lr: 0.000500  loss: 0.5721 (0.6107)  loss_classifier: 0.2545 (0.2551)  loss_box_reg: 0.2940 (0.2912)  loss_objectness: 0.0455 (0.0539)  loss_rpn_box_reg: 0.0066 (0.0105)  time: 0.1288  data: 0.0152  max mem: 1064
# Epoch: [3] Total time: 0:00:49 (0.1716 s / it)
# creating index...
# index created!
# Test:  [ 0/61]  eta: 0:00:24  model_time: 0.0557 (0.0557)  evaluator_time: 0.0018 (0.0018)  time: 0.4050  data: 0.3415  max mem: 1064
# Test:  [60/61]  eta: 0:00:00  model_time: 0.0227 (0.0243)  evaluator_time: 0.0008 (0.0010)  time: 0.0274  data: 0.0029  max mem: 1064
# Test: Total time: 0:00:02 (0.0389 s / it)
# Averaged stats: model_time: 0.0227 (0.0243)  evaluator_time: 0.0008 (0.0010)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.423
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.811
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.400
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.430
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.440
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.540
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.540
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.548
# Epoch: [4]  [  0/287]  eta: 0:02:39  lr: 0.000500  loss: 0.4542 (0.4542)  loss_classifier: 0.1964 (0.1964)  loss_box_reg: 0.2371 (0.2371)  loss_objectness: 0.0167 (0.0167)  loss_rpn_box_reg: 0.0040 (0.0040)  time: 0.5551  data: 0.4161  max mem: 1064
# Epoch: [4]  [ 10/287]  eta: 0:01:13  lr: 0.000500  loss: 0.5455 (0.5759)  loss_classifier: 0.2497 (0.2507)  loss_box_reg: 0.2449 (0.2788)  loss_objectness: 0.0321 (0.0400)  loss_rpn_box_reg: 0.0057 (0.0064)  time: 0.2664  data: 0.0858  max mem: 1064
# Epoch: [4]  [ 20/287]  eta: 0:00:58  lr: 0.000500  loss: 0.5455 (0.5759)  loss_classifier: 0.2497 (0.2459)  loss_box_reg: 0.2643 (0.2795)  loss_objectness: 0.0378 (0.0430)  loss_rpn_box_reg: 0.0070 (0.0075)  time: 0.2032  data: 0.0420  max mem: 1064
# Epoch: [4]  [ 30/287]  eta: 0:00:54  lr: 0.000500  loss: 0.5580 (0.5789)  loss_classifier: 0.2252 (0.2456)  loss_box_reg: 0.2627 (0.2706)  loss_objectness: 0.0577 (0.0548)  loss_rpn_box_reg: 0.0079 (0.0079)  time: 0.1824  data: 0.0288  max mem: 1064
# Epoch: [4]  [ 40/287]  eta: 0:00:47  lr: 0.000500  loss: 0.5472 (0.5778)  loss_classifier: 0.2255 (0.2443)  loss_box_reg: 0.2523 (0.2729)  loss_objectness: 0.0515 (0.0523)  loss_rpn_box_reg: 0.0084 (0.0082)  time: 0.1627  data: 0.0223  max mem: 1064
# Epoch: [4]  [ 50/287]  eta: 0:00:44  lr: 0.000500  loss: 0.5472 (0.5873)  loss_classifier: 0.2312 (0.2492)  loss_box_reg: 0.2523 (0.2767)  loss_objectness: 0.0469 (0.0531)  loss_rpn_box_reg: 0.0079 (0.0083)  time: 0.1469  data: 0.0192  max mem: 1064
# Epoch: [4]  [ 60/287]  eta: 0:00:41  lr: 0.000500  loss: 0.5445 (0.5835)  loss_classifier: 0.2370 (0.2488)  loss_box_reg: 0.2577 (0.2762)  loss_objectness: 0.0385 (0.0503)  loss_rpn_box_reg: 0.0074 (0.0082)  time: 0.1611  data: 0.0214  max mem: 1064
# Epoch: [4]  [ 70/287]  eta: 0:00:38  lr: 0.000500  loss: 0.5236 (0.5786)  loss_classifier: 0.2130 (0.2476)  loss_box_reg: 0.2655 (0.2748)  loss_objectness: 0.0343 (0.0481)  loss_rpn_box_reg: 0.0074 (0.0081)  time: 0.1615  data: 0.0237  max mem: 1064
# Epoch: [4]  [ 80/287]  eta: 0:00:36  lr: 0.000500  loss: 0.4918 (0.5693)  loss_classifier: 0.1975 (0.2431)  loss_box_reg: 0.2762 (0.2714)  loss_objectness: 0.0327 (0.0464)  loss_rpn_box_reg: 0.0072 (0.0083)  time: 0.1613  data: 0.0265  max mem: 1064
# Epoch: [4]  [ 90/287]  eta: 0:00:33  lr: 0.000500  loss: 0.5687 (0.5788)  loss_classifier: 0.2445 (0.2461)  loss_box_reg: 0.2795 (0.2775)  loss_objectness: 0.0367 (0.0464)  loss_rpn_box_reg: 0.0088 (0.0087)  time: 0.1403  data: 0.0230  max mem: 1064
# Epoch: [4]  [100/287]  eta: 0:00:31  lr: 0.000500  loss: 0.6340 (0.5883)  loss_classifier: 0.2426 (0.2487)  loss_box_reg: 0.3269 (0.2851)  loss_objectness: 0.0362 (0.0456)  loss_rpn_box_reg: 0.0089 (0.0090)  time: 0.1311  data: 0.0192  max mem: 1064
# Epoch: [4]  [110/287]  eta: 0:00:30  lr: 0.000500  loss: 0.6052 (0.5884)  loss_classifier: 0.2287 (0.2481)  loss_box_reg: 0.3269 (0.2842)  loss_objectness: 0.0362 (0.0470)  loss_rpn_box_reg: 0.0087 (0.0090)  time: 0.1761  data: 0.0280  max mem: 1064
# Epoch: [4]  [120/287]  eta: 0:00:29  lr: 0.000500  loss: 0.5988 (0.5992)  loss_classifier: 0.2401 (0.2507)  loss_box_reg: 0.3147 (0.2922)  loss_objectness: 0.0411 (0.0472)  loss_rpn_box_reg: 0.0087 (0.0092)  time: 0.2077  data: 0.0347  max mem: 1064
# Epoch: [4]  [130/287]  eta: 0:00:27  lr: 0.000500  loss: 0.6519 (0.6040)  loss_classifier: 0.2504 (0.2513)  loss_box_reg: 0.3499 (0.2965)  loss_objectness: 0.0406 (0.0468)  loss_rpn_box_reg: 0.0087 (0.0093)  time: 0.1764  data: 0.0267  max mem: 1064
# Epoch: [4]  [140/287]  eta: 0:00:24  lr: 0.000500  loss: 0.6355 (0.6066)  loss_classifier: 0.2534 (0.2528)  loss_box_reg: 0.3265 (0.2964)  loss_objectness: 0.0406 (0.0480)  loss_rpn_box_reg: 0.0102 (0.0094)  time: 0.1318  data: 0.0163  max mem: 1064
# Epoch: [4]  [150/287]  eta: 0:00:22  lr: 0.000500  loss: 0.5721 (0.6011)  loss_classifier: 0.2398 (0.2500)  loss_box_reg: 0.2930 (0.2941)  loss_objectness: 0.0279 (0.0476)  loss_rpn_box_reg: 0.0096 (0.0094)  time: 0.1157  data: 0.0142  max mem: 1064
# Epoch: [4]  [160/287]  eta: 0:00:20  lr: 0.000500  loss: 0.5361 (0.6023)  loss_classifier: 0.2226 (0.2504)  loss_box_reg: 0.2592 (0.2946)  loss_objectness: 0.0298 (0.0478)  loss_rpn_box_reg: 0.0084 (0.0095)  time: 0.1093  data: 0.0113  max mem: 1064
# Epoch: [4]  [170/287]  eta: 0:00:18  lr: 0.000500  loss: 0.5653 (0.6019)  loss_classifier: 0.2486 (0.2502)  loss_box_reg: 0.2684 (0.2946)  loss_objectness: 0.0376 (0.0477)  loss_rpn_box_reg: 0.0084 (0.0095)  time: 0.1232  data: 0.0131  max mem: 1064
# Epoch: [4]  [180/287]  eta: 0:00:17  lr: 0.000500  loss: 0.5603 (0.5996)  loss_classifier: 0.2379 (0.2498)  loss_box_reg: 0.2570 (0.2927)  loss_objectness: 0.0401 (0.0474)  loss_rpn_box_reg: 0.0086 (0.0096)  time: 0.1575  data: 0.0235  max mem: 1064
# Epoch: [4]  [190/287]  eta: 0:00:15  lr: 0.000500  loss: 0.5683 (0.6007)  loss_classifier: 0.2412 (0.2498)  loss_box_reg: 0.2850 (0.2938)  loss_objectness: 0.0397 (0.0475)  loss_rpn_box_reg: 0.0073 (0.0095)  time: 0.1916  data: 0.0297  max mem: 1064
# Epoch: [4]  [200/287]  eta: 0:00:14  lr: 0.000500  loss: 0.5660 (0.5979)  loss_classifier: 0.2294 (0.2492)  loss_box_reg: 0.2645 (0.2918)  loss_objectness: 0.0391 (0.0475)  loss_rpn_box_reg: 0.0064 (0.0094)  time: 0.1858  data: 0.0304  max mem: 1064
# Epoch: [4]  [210/287]  eta: 0:00:12  lr: 0.000500  loss: 0.6091 (0.6037)  loss_classifier: 0.2511 (0.2515)  loss_box_reg: 0.2645 (0.2956)  loss_objectness: 0.0377 (0.0472)  loss_rpn_box_reg: 0.0068 (0.0094)  time: 0.1678  data: 0.0253  max mem: 1064
# Epoch: [4]  [220/287]  eta: 0:00:11  lr: 0.000500  loss: 0.6022 (0.6014)  loss_classifier: 0.2511 (0.2509)  loss_box_reg: 0.2739 (0.2932)  loss_objectness: 0.0377 (0.0479)  loss_rpn_box_reg: 0.0093 (0.0094)  time: 0.1926  data: 0.0272  max mem: 1064
# Epoch: [4]  [230/287]  eta: 0:00:09  lr: 0.000500  loss: 0.5119 (0.6015)  loss_classifier: 0.2330 (0.2512)  loss_box_reg: 0.2286 (0.2929)  loss_objectness: 0.0377 (0.0480)  loss_rpn_box_reg: 0.0093 (0.0094)  time: 0.2106  data: 0.0319  max mem: 1064
# Epoch: [4]  [240/287]  eta: 0:00:07  lr: 0.000500  loss: 0.5548 (0.5989)  loss_classifier: 0.2341 (0.2506)  loss_box_reg: 0.2363 (0.2912)  loss_objectness: 0.0318 (0.0477)  loss_rpn_box_reg: 0.0065 (0.0094)  time: 0.1695  data: 0.0236  max mem: 1064
# Epoch: [4]  [250/287]  eta: 0:00:06  lr: 0.000500  loss: 0.5236 (0.5980)  loss_classifier: 0.2052 (0.2501)  loss_box_reg: 0.2437 (0.2908)  loss_objectness: 0.0311 (0.0476)  loss_rpn_box_reg: 0.0086 (0.0094)  time: 0.1218  data: 0.0146  max mem: 1064
# Epoch: [4]  [260/287]  eta: 0:00:04  lr: 0.000500  loss: 0.5510 (0.5987)  loss_classifier: 0.2065 (0.2504)  loss_box_reg: 0.2650 (0.2914)  loss_objectness: 0.0311 (0.0475)  loss_rpn_box_reg: 0.0073 (0.0094)  time: 0.1153  data: 0.0122  max mem: 1064
# Epoch: [4]  [270/287]  eta: 0:00:02  lr: 0.000500  loss: 0.6195 (0.5995)  loss_classifier: 0.2573 (0.2504)  loss_box_reg: 0.3029 (0.2918)  loss_objectness: 0.0396 (0.0480)  loss_rpn_box_reg: 0.0065 (0.0094)  time: 0.1516  data: 0.0199  max mem: 1064
# Epoch: [4]  [280/287]  eta: 0:00:01  lr: 0.000500  loss: 0.6664 (0.6014)  loss_classifier: 0.2697 (0.2513)  loss_box_reg: 0.3048 (0.2922)  loss_objectness: 0.0506 (0.0484)  loss_rpn_box_reg: 0.0083 (0.0094)  time: 0.1742  data: 0.0270  max mem: 1064
# Epoch: [4]  [286/287]  eta: 0:00:00  lr: 0.000500  loss: 0.6579 (0.6024)  loss_classifier: 0.2771 (0.2518)  loss_box_reg: 0.3048 (0.2927)  loss_objectness: 0.0461 (0.0484)  loss_rpn_box_reg: 0.0102 (0.0095)  time: 0.1530  data: 0.0226  max mem: 1064
# Epoch: [4] Total time: 0:00:46 (0.1629 s / it)
# creating index...
# index created!
# Test:  [ 0/61]  eta: 0:00:26  model_time: 0.0667 (0.0667)  evaluator_time: 0.0018 (0.0018)  time: 0.4365  data: 0.3660  max mem: 1064
# Test:  [60/61]  eta: 0:00:00  model_time: 0.0276 (0.0294)  evaluator_time: 0.0013 (0.0013)  time: 0.0368  data: 0.0053  max mem: 1064
# Test: Total time: 0:00:03 (0.0499 s / it)
# Averaged stats: model_time: 0.0276 (0.0294)  evaluator_time: 0.0013 (0.0013)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.415
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.785
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.376
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.422
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.422
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.560
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.568
# That's it!
# Saving
# Saved
