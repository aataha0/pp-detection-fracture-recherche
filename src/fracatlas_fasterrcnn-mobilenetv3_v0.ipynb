# %%
# %pip uninstall torch torchvision torchaudio torchtext torchdata fastai -y
# %pip install torchvision==0.16 torch==2.1

import torch
import torchvision

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

print("pytorch", torch.__version__)
print("torchvision", torchvision.__version__)
# Out:
# Found existing installation: torch 2.0.1+cu118
# Uninstalling torch-2.0.1+cu118:
#   Successfully uninstalled torch-2.0.1+cu118
# Found existing installation: torchvision 0.15.2+cu118
# Uninstalling torchvision-0.15.2+cu118:
#   Successfully uninstalled torchvision-0.15.2+cu118
# Found existing installation: torchaudio 2.0.2+cu118
# Uninstalling torchaudio-2.0.2+cu118:
#   Successfully uninstalled torchaudio-2.0.2+cu118
# Found existing installation: torchtext 0.15.2
# Uninstalling torchtext-0.15.2:
#   Successfully uninstalled torchtext-0.15.2
# Found existing installation: torchdata 0.6.1
# Uninstalling torchdata-0.6.1:
#   Successfully uninstalled torchdata-0.6.1
# Found existing installation: fastai 2.7.12
# Uninstalling fastai-2.7.12:
#   Successfully uninstalled fastai-2.7.12
# Collecting torchvision==0.16
#   Downloading torchvision-0.16.0-cp310-cp310-manylinux1_x86_64.whl (6.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 52.9 MB/s eta 0:00:00
# Collecting torch==2.1
#   Downloading torch-2.1.0-cp310-cp310-manylinux1_x86_64.whl (670.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 670.2/670.2 MB 1.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16) (1.23.5)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16) (2.31.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision==0.16) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch==2.1) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch==2.1)
#   Downloading nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 44.8 MB/s eta 0:00:00
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch==2.1)
#   Downloading nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 60.3 MB/s eta 0:00:00
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch==2.1)
#   Downloading nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 91.4 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch==2.1)
#   Downloading nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 2.2 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch==2.1)
#   Downloading nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 3.8 MB/s eta 0:00:00
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch==2.1)
#   Downloading nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 8.3 MB/s eta 0:00:00
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch==2.1)
#   Downloading nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 11.7 MB/s eta 0:00:00
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch==2.1)
#   Downloading nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 8.5 MB/s eta 0:00:00
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch==2.1)
#   Downloading nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 6.5 MB/s eta 0:00:00
# Collecting nvidia-nccl-cu12==2.18.1 (from torch==2.1)
#   Downloading nvidia_nccl_cu12-2.18.1-py3-none-manylinux1_x86_64.whl (209.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.8/209.8 MB 2.3 MB/s eta 0:00:00
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch==2.1)
#   Downloading nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 13.4 MB/s eta 0:00:00
# Collecting triton==2.1.0 (from torch==2.1)
#   Downloading triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 9.0 MB/s eta 0:00:00
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch==2.1)
#   Downloading nvidia_nvjitlink_cu12-12.2.140-py3-none-manylinux1_x86_64.whl (20.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.2/20.2 MB 77.6 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch==2.1) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->torchvision==0.16) (2023.7.22)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch==2.1) (1.3.0)
# Installing collected packages: triton, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision
#   Attempting uninstall: triton
#     Found existing installation: triton 2.0.0
#     Uninstalling triton-2.0.0:
#       Successfully uninstalled triton-2.0.0
# Successfully installed nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.18.1 nvidia-nvjitlink-cu12-12.2.140 nvidia-nvtx-cu12-12.1.105 torch-2.1.0 torchvision-0.16.0 triton-2.1.0
# pytorch 2.1.0+cu121
# torchvision 0.16.0+cu121

# %%
from torchvision.transforms import functional as F
from torchvision.datasets.vision import VisionDataset
from torchvision.datasets.utils import download_and_extract_archive, verify_str_arg
from torchvision.ops import box_area

from PIL import Image

import collections
import os
from xml.etree.ElementTree import Element as ET_Element

try:
    from defusedxml.ElementTree import parse as ET_parse
except ImportError:
    from xml.etree.ElementTree import parse as ET_parse
from typing import Any, Callable, Dict, List, Optional, Tuple


class FracAtlasDetection(VisionDataset):
    """FracAtlas dataset."""

    def __init__(
        self,
        root: str,
        image_set: str = "train",
        # download: bool = False,
        transform: Optional[Callable] = None,
        target_transform: Optional[Callable] = None,
        transforms: Optional[Callable] = None,
    ):
        super().__init__(root, transforms, transform, target_transform)

        valid_image_sets = ["test", "train", "val"]
        self.image_set = verify_str_arg(image_set, "image_set", valid_image_sets)

        self.url = "https://figshare.com/ndownloader/files/41725659"
        self.filename = "fracatlas.zip"

        # if download:
        if not os.path.isdir("data/FracAtlas"):
            os.makedirs("data", exist_ok=True)
            download_and_extract_archive(self.url, os.path.dirname(self.root), filename=self.filename, remove_finished=True)
            for subdir in ["Fractured", "Non_fractured"]:
                dirpath = os.path.join(self.root, "images")
                subdirpath = os.path.join(dirpath, subdir)
                for f in os.listdir(subdirpath):
                    if not f.lower().endswith(".jpg"): continue
                    os.rename(os.path.join(subdirpath, f), os.path.join(dirpath, f))
                os.rmdir(subdirpath)
            print(os.listdir("data"))
        if not os.path.isdir(self.root):
            raise RuntimeError(
                "Dataset not found or corrupted. You can use download=True to download it"
            )

        splits_dir = os.path.join(self.root, "Utilities", "Fracture Split")
        splits_f = os.path.join(splits_dir, image_set.rstrip("\n") + ".csv")
        with open(os.path.join(splits_f)) as f:
            file_names = [
                os.path.splitext(x.strip())[0]
                for x in f.readlines()
                if x.strip() != "image_id"
            ]

        image_dir = os.path.join(self.root, "images")
        self.images = [os.path.join(image_dir, x + ".jpg") for x in file_names]

        target_dir = os.path.join(self.root, "Annotations", "PASCAL VOC")
        self.targets = [os.path.join(target_dir, x + ".xml") for x in file_names]

        assert len(self.images) == len(self.targets)

    @property
    def annotations(self) -> List[str]:
        return self.targets

    def __getitem__(self, index: int) -> Tuple[Any, Any]:
        """
        Args:
            index (int): Index

        Returns:
            tuple: (image, target) where target is a dictionary of the XML tree.
        """
        img = Image.open(self.images[index]).convert("RGB")
        img = F.to_tensor(img)
        voc_dict = self.parse_voc_xml(ET_parse(self.annotations[index]).getroot())
        target = self.voc_dict_to_target(index, voc_dict)
        # print(target)

        if self.transforms is not None:
            img, target = self.transforms(img, target)

        return img, target

    def __len__(self) -> int:
        return len(self.images)

    @staticmethod
    def parse_voc_xml(node: ET_Element) -> Dict[str, Any]:
        voc_dict: Dict[str, Any] = {}
        children = list(node)
        if children:
            def_dic: Dict[str, Any] = collections.defaultdict(list)
            for dc in map(FracAtlasDetection.parse_voc_xml, children):
                for ind, v in dc.items():
                    def_dic[ind].append(v)
            if node.tag == "annotation":
                def_dic["object"] = [def_dic["object"]]
            voc_dict = {
                node.tag: {
                    ind: v[0] if len(v) == 1 else v for ind, v in def_dic.items()
                }
            }
        if node.text:
            text = node.text.strip()
            if not children:
                voc_dict[node.tag] = text
        return voc_dict

    def voc_dict_to_target(self, index: int, item):
        width = int(item["annotation"]["size"]["width"])
        height = int(item["annotation"]["size"]["height"])

        num_fractures = len(item["annotation"]["object"])

        boxes = [
            (
                int(obj["bndbox"]["xmin"]),
                int(obj["bndbox"]["ymin"]),
                int(obj["bndbox"]["xmax"]),
                int(obj["bndbox"]["ymax"]),
            )
            for obj in item["annotation"]["object"]
        ]

        # guard against no boxes via resizing (https://github.com/pytorch/vision/blob/aa32c9376c46eb284f2b091f3eb98aec4fd64b03/references/detection/coco_utils.py#L63-L66)
        boxes = torch.as_tensor(boxes, dtype=torch.float32).reshape(-1, 4)
        boxes[:, 2:] += boxes[:, :2]
        boxes[:, 0::2].clamp_(min=0, max=width)
        boxes[:, 1::2].clamp_(min=0, max=height)

        # extract labels
        labels = torch.ones((num_fractures,), dtype=torch.int64)

        image_id = index
        area = box_area(boxes)

        # suppose all instances are not crowd
        iscrowd = torch.zeros((num_fractures,), dtype=torch.int64)

        # remove invalid boxes (https://github.com/pytorch/vision/blob/aa32c9376c46eb284f2b091f3eb98aec4fd64b03/references/detection/coco_utils.py#L82-L85)
        keep = (boxes[:, 3] > boxes[:, 1]) & (boxes[:, 2] > boxes[:, 0])
        boxes = boxes[keep]

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd

        return target

# %%
from torchvision.transforms import v2 as T


def get_transform(train):
    transforms = []
    # if train:
    #     transforms.append(T.RandomHorizontalFlip(0.5))
    transforms.append(T.ToImage())
    transforms.append(T.ToDtype(torch.float32, scale=True))
    # transforms.append(T.ToDtype(torch.float))
    # transforms.append(T.ToPureTensor())
    return T.Compose(transforms)

# %%
# os.makedirs("lib", exist_ok=True)
if not os.path.exists("engine.py"):
    os.system(
        "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/engine.py -O engine.py"
    )
if not os.path.exists("utils.py"):
    os.system(
        "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/utils.py -O utils.py"
    )
if not os.path.exists("transforms.py"):
    os.system(
        "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/transforms.py -O transforms.py"
    )
if not os.path.exists("coco_utils.py"):
    os.system(
        "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_utils.py -O coco_utils.py"
    )
if not os.path.exists("coco_eval.py"):
    os.system(
        "wget https://raw.githubusercontent.com/pytorch/vision/main/references/detection/coco_eval.py -O coco_eval.py"
    )

# you also need to tweak them a bit to work with relative imports

# %%
from torchvision.models.detection import fasterrcnn_mobilenet_v3_large_fpn, FasterRCNN_MobileNet_V3_Large_FPN_Weights
from utils import collate_fn

model = fasterrcnn_mobilenet_v3_large_fpn(weights=FasterRCNN_MobileNet_V3_Large_FPN_Weights.DEFAULT)
dataset = FracAtlasDetection("data/FracAtlas", image_set="train", transform=get_transform(train=True))
data_loader = torch.utils.data.DataLoader(
  dataset,
  batch_size=2,
  shuffle=True,
  num_workers=4,
  collate_fn=collate_fn,
)

# For Training
images, targets = next(iter(data_loader))
images = list(image for image in images)
targets = [{k: v for k, v in t.items()} for t in targets]
output = model(images, targets)  # Returns losses and detections
print(output)

# For inference
model.eval()
x = [torch.rand(3, 300, 400), torch.rand(3, 500, 400)]
predictions = model(x)  # Returns predictions
print(predictions[0])
# Out:
# Downloading: "https://download.pytorch.org/models/fasterrcnn_mobilenet_v3_large_fpn-fb6a3cc7.pth" to /root/.cache/torch/hub/checkpoints/fasterrcnn_mobilenet_v3_large_fpn-fb6a3cc7.pth
# 100%|██████████| 74.2M/74.2M [00:00<00:00, 88.3MB/s]
# Downloading https://s3-eu-west-1.amazonaws.com/pfigshare-u-files/41725659/FracAtlas.zip?X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=AKIAIYCQYOYV5JSSROOA/20231010/eu-west-1/s3/aws4_request&X-Amz-Date=20231010T215330Z&X-Amz-Expires=10&X-Amz-SignedHeaders=host&X-Amz-Signature=99ebc6179fa3a75fece8de63adcb9b14133a6a8845f74c39aa97879f7173d9ec to data/fracatlas.zip
# 100%|██████████| 338412751/338412751 [00:10<00:00, 31810498.68it/s]
# Extracting data/fracatlas.zip to data
# ['FracAtlas']
# {'loss_classifier': tensor(0.3213, grad_fn=<NllLossBackward0>), 'loss_box_reg': tensor(0.0964, grad_fn=<DivBackward0>), 'loss_objectness': tensor(0.5832, grad_fn=<BinaryCrossEntropyWithLogitsBackward0>), 'loss_rpn_box_reg': tensor(0.0271, grad_fn=<DivBackward0>)}
# {'boxes': tensor([], size=(0, 4), grad_fn=<StackBackward0>), 'labels': tensor([], dtype=torch.int64), 'scores': tensor([], grad_fn=<IndexBackward0>)}

# %%
from engine import train_one_epoch, evaluate
from utils import collate_fn

device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
print("device:", device)

# use our dataset and defined transformations
dataset = FracAtlasDetection('data/FracAtlas', image_set="train", transform=get_transform(train=True))
dataset_test = FracAtlasDetection('data/FracAtlas', image_set="test", transform=get_transform(train=False))

# split the dataset in train and test set
# indices = torch.randperm(len(dataset)).tolist()
# dataset = torch.utils.data.Subset(dataset, indices[:-50])
# dataset_test = torch.utils.data.Subset(dataset_test, indices[-50:])

# define training and validation data loaders
data_loader = torch.utils.data.DataLoader(
    dataset,
    batch_size=2,
    shuffle=True,
    num_workers=4,
    collate_fn=collate_fn,
)

data_loader_test = torch.utils.data.DataLoader(
    dataset_test,
    batch_size=1,
    shuffle=False,
    num_workers=4,
    collate_fn=collate_fn,
)

model = fasterrcnn_mobilenet_v3_large_fpn(weights=FasterRCNN_MobileNet_V3_Large_FPN_Weights.DEFAULT)

# move model to the right device
model.to(device)

# construct an optimizer
params = [p for p in model.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(
    params,
    lr=0.005,
    momentum=0.9,
    weight_decay=0.0005
)

# and a learning rate scheduler
lr_scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,
    step_size=3,
    gamma=0.1
)

# let's train it for 5 epochs
num_epochs = 5

for epoch in range(num_epochs):
    # train for one epoch, printing every 10 iterations
    train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq=10)
    # update the learning rate
    lr_scheduler.step()
    # evaluate on the test dataset
    evaluate(model, data_loader_test, device=device)

print("That's it!")

print("Saving")
torch.save(model, 'fracatlas_fasterrcnn-mobilenetv3_v0.pth')
print("Saved")
# Out:
# device: cuda
# Epoch: [0]  [  0/287]  eta: 0:36:53  lr: 0.000022  loss: 0.9439 (0.9439)  loss_classifier: 0.4129 (0.4129)  loss_box_reg: 0.1684 (0.1684)  loss_objectness: 0.3015 (0.3015)  loss_rpn_box_reg: 0.0612 (0.0612)  time: 7.7131  data: 0.3437  max mem: 680
# Epoch: [0]  [ 10/287]  eta: 0:04:09  lr: 0.000197  loss: 1.1501 (1.2120)  loss_classifier: 0.4129 (0.4657)  loss_box_reg: 0.1699 (0.2663)  loss_objectness: 0.3277 (0.4198)  loss_rpn_box_reg: 0.0569 (0.0602)  time: 0.9011  data: 0.0555  max mem: 940
# Epoch: [0]  [ 20/287]  eta: 0:02:29  lr: 0.000372  loss: 0.9730 (1.0891)  loss_classifier: 0.2977 (0.3591)  loss_box_reg: 0.2033 (0.2560)  loss_objectness: 0.3259 (0.4096)  loss_rpn_box_reg: 0.0539 (0.0645)  time: 0.2013  data: 0.0243  max mem: 943
# Epoch: [0]  [ 30/287]  eta: 0:01:55  lr: 0.000546  loss: 0.7218 (0.9585)  loss_classifier: 0.2202 (0.3121)  loss_box_reg: 0.2190 (0.2491)  loss_objectness: 0.2108 (0.3425)  loss_rpn_box_reg: 0.0312 (0.0549)  time: 0.2009  data: 0.0253  max mem: 946
# Epoch: [0]  [ 40/287]  eta: 0:01:34  lr: 0.000721  loss: 0.6382 (0.8909)  loss_classifier: 0.1866 (0.2858)  loss_box_reg: 0.2518 (0.2585)  loss_objectness: 0.1335 (0.2936)  loss_rpn_box_reg: 0.0289 (0.0531)  time: 0.2002  data: 0.0230  max mem: 946
# Epoch: [0]  [ 50/287]  eta: 0:01:24  lr: 0.000896  loss: 0.6816 (0.8507)  loss_classifier: 0.1955 (0.2672)  loss_box_reg: 0.3213 (0.2756)  loss_objectness: 0.1268 (0.2607)  loss_rpn_box_reg: 0.0237 (0.0472)  time: 0.2141  data: 0.0284  max mem: 946
# Epoch: [0]  [ 60/287]  eta: 0:01:13  lr: 0.001070  loss: 0.7250 (0.8410)  loss_classifier: 0.1955 (0.2624)  loss_box_reg: 0.3649 (0.2850)  loss_objectness: 0.1378 (0.2506)  loss_rpn_box_reg: 0.0211 (0.0430)  time: 0.2003  data: 0.0324  max mem: 948
# Epoch: [0]  [ 70/287]  eta: 0:01:05  lr: 0.001245  loss: 0.7718 (0.8432)  loss_classifier: 0.2443 (0.2649)  loss_box_reg: 0.3290 (0.3038)  loss_objectness: 0.1378 (0.2340)  loss_rpn_box_reg: 0.0212 (0.0405)  time: 0.1603  data: 0.0239  max mem: 1034
# Epoch: [0]  [ 80/287]  eta: 0:00:59  lr: 0.001420  loss: 0.8241 (0.8488)  loss_classifier: 0.2564 (0.2680)  loss_box_reg: 0.4000 (0.3226)  loss_objectness: 0.1044 (0.2197)  loss_rpn_box_reg: 0.0187 (0.0385)  time: 0.1719  data: 0.0224  max mem: 1034
# Epoch: [0]  [ 90/287]  eta: 0:00:55  lr: 0.001594  loss: 0.6388 (0.8168)  loss_classifier: 0.2092 (0.2588)  loss_box_reg: 0.3250 (0.3172)  loss_objectness: 0.0800 (0.2043)  loss_rpn_box_reg: 0.0186 (0.0365)  time: 0.2209  data: 0.0364  max mem: 1034
# Epoch: [0]  [100/287]  eta: 0:00:51  lr: 0.001769  loss: 0.6077 (0.8140)  loss_classifier: 0.2048 (0.2642)  loss_box_reg: 0.2902 (0.3227)  loss_objectness: 0.0741 (0.1925)  loss_rpn_box_reg: 0.0152 (0.0346)  time: 0.2363  data: 0.0449  max mem: 1034
# Epoch: [0]  [110/287]  eta: 0:00:47  lr: 0.001944  loss: 0.7407 (0.8089)  loss_classifier: 0.3035 (0.2655)  loss_box_reg: 0.3529 (0.3298)  loss_objectness: 0.0589 (0.1804)  loss_rpn_box_reg: 0.0112 (0.0331)  time: 0.1953  data: 0.0294  max mem: 1034
# Epoch: [0]  [120/287]  eta: 0:00:42  lr: 0.002118  loss: 0.6668 (0.7977)  loss_classifier: 0.2591 (0.2650)  loss_box_reg: 0.3296 (0.3281)  loss_objectness: 0.0498 (0.1732)  loss_rpn_box_reg: 0.0112 (0.0315)  time: 0.1553  data: 0.0171  max mem: 1034
# Epoch: [0]  [130/287]  eta: 0:00:38  lr: 0.002293  loss: 0.6451 (0.7880)  loss_classifier: 0.2374 (0.2642)  loss_box_reg: 0.3142 (0.3262)  loss_objectness: 0.0828 (0.1676)  loss_rpn_box_reg: 0.0096 (0.0300)  time: 0.1397  data: 0.0195  max mem: 1034
# Epoch: [0]  [140/287]  eta: 0:00:35  lr: 0.002468  loss: 0.6794 (0.7888)  loss_classifier: 0.2422 (0.2659)  loss_box_reg: 0.3533 (0.3306)  loss_objectness: 0.0828 (0.1633)  loss_rpn_box_reg: 0.0092 (0.0290)  time: 0.1550  data: 0.0213  max mem: 1034
# Epoch: [0]  [150/287]  eta: 0:00:32  lr: 0.002642  loss: 0.7267 (0.7842)  loss_classifier: 0.2607 (0.2651)  loss_box_reg: 0.3639 (0.3327)  loss_objectness: 0.0806 (0.1585)  loss_rpn_box_reg: 0.0126 (0.0279)  time: 0.1565  data: 0.0180  max mem: 1034
# Epoch: [0]  [160/287]  eta: 0:00:29  lr: 0.002817  loss: 0.7853 (0.7810)  loss_classifier: 0.2541 (0.2643)  loss_box_reg: 0.3640 (0.3349)  loss_objectness: 0.0845 (0.1546)  loss_rpn_box_reg: 0.0126 (0.0272)  time: 0.1448  data: 0.0161  max mem: 1034
# Epoch: [0]  [170/287]  eta: 0:00:26  lr: 0.002992  loss: 0.7853 (0.7828)  loss_classifier: 0.2541 (0.2671)  loss_box_reg: 0.3990 (0.3390)  loss_objectness: 0.0786 (0.1500)  loss_rpn_box_reg: 0.0140 (0.0267)  time: 0.1272  data: 0.0149  max mem: 1034
# Epoch: [0]  [180/287]  eta: 0:00:23  lr: 0.003166  loss: 0.7375 (0.7823)  loss_classifier: 0.2766 (0.2686)  loss_box_reg: 0.3596 (0.3399)  loss_objectness: 0.0777 (0.1477)  loss_rpn_box_reg: 0.0140 (0.0262)  time: 0.1274  data: 0.0150  max mem: 1034
# Epoch: [0]  [190/287]  eta: 0:00:21  lr: 0.003341  loss: 0.7300 (0.7805)  loss_classifier: 0.2693 (0.2689)  loss_box_reg: 0.3089 (0.3412)  loss_objectness: 0.0802 (0.1448)  loss_rpn_box_reg: 0.0133 (0.0257)  time: 0.1598  data: 0.0210  max mem: 1034
# Epoch: [0]  [200/287]  eta: 0:00:18  lr: 0.003515  loss: 0.6673 (0.7754)  loss_classifier: 0.2478 (0.2680)  loss_box_reg: 0.3267 (0.3402)  loss_objectness: 0.0821 (0.1419)  loss_rpn_box_reg: 0.0130 (0.0253)  time: 0.1854  data: 0.0225  max mem: 1059
# Epoch: [0]  [210/287]  eta: 0:00:16  lr: 0.003690  loss: 0.6237 (0.7686)  loss_classifier: 0.2267 (0.2669)  loss_box_reg: 0.2829 (0.3379)  loss_objectness: 0.0786 (0.1390)  loss_rpn_box_reg: 0.0130 (0.0248)  time: 0.2074  data: 0.0216  max mem: 1059
# Epoch: [0]  [220/287]  eta: 0:00:14  lr: 0.003865  loss: 0.6492 (0.7665)  loss_classifier: 0.2393 (0.2676)  loss_box_reg: 0.2908 (0.3393)  loss_objectness: 0.0482 (0.1352)  loss_rpn_box_reg: 0.0110 (0.0244)  time: 0.1812  data: 0.0230  max mem: 1059
# Epoch: [0]  [230/287]  eta: 0:00:11  lr: 0.004039  loss: 0.7011 (0.7634)  loss_classifier: 0.2416 (0.2677)  loss_box_reg: 0.3650 (0.3398)  loss_objectness: 0.0442 (0.1319)  loss_rpn_box_reg: 0.0110 (0.0240)  time: 0.1404  data: 0.0190  max mem: 1059
# Epoch: [0]  [240/287]  eta: 0:00:09  lr: 0.004214  loss: 0.7309 (0.7661)  loss_classifier: 0.2754 (0.2694)  loss_box_reg: 0.3836 (0.3440)  loss_objectness: 0.0575 (0.1291)  loss_rpn_box_reg: 0.0103 (0.0235)  time: 0.1294  data: 0.0157  max mem: 1059
# Epoch: [0]  [250/287]  eta: 0:00:07  lr: 0.004389  loss: 0.7502 (0.7684)  loss_classifier: 0.2754 (0.2718)  loss_box_reg: 0.3939 (0.3477)  loss_objectness: 0.0510 (0.1257)  loss_rpn_box_reg: 0.0105 (0.0232)  time: 0.1229  data: 0.0164  max mem: 1059
# Epoch: [0]  [260/287]  eta: 0:00:05  lr: 0.004563  loss: 0.6720 (0.7655)  loss_classifier: 0.2558 (0.2712)  loss_box_reg: 0.3657 (0.3470)  loss_objectness: 0.0437 (0.1244)  loss_rpn_box_reg: 0.0136 (0.0229)  time: 0.1234  data: 0.0153  max mem: 1059
# Epoch: [0]  [270/287]  eta: 0:00:03  lr: 0.004738  loss: 0.6395 (0.7630)  loss_classifier: 0.2452 (0.2709)  loss_box_reg: 0.3295 (0.3474)  loss_objectness: 0.0528 (0.1222)  loss_rpn_box_reg: 0.0096 (0.0225)  time: 0.1306  data: 0.0144  max mem: 1059
# Epoch: [0]  [280/287]  eta: 0:00:01  lr: 0.004913  loss: 0.6238 (0.7606)  loss_classifier: 0.2452 (0.2703)  loss_box_reg: 0.3224 (0.3479)  loss_objectness: 0.0524 (0.1203)  loss_rpn_box_reg: 0.0072 (0.0222)  time: 0.1337  data: 0.0153  max mem: 1059
# Epoch: [0]  [286/287]  eta: 0:00:00  lr: 0.005000  loss: 0.6367 (0.7586)  loss_classifier: 0.2381 (0.2700)  loss_box_reg: 0.3174 (0.3476)  loss_objectness: 0.0575 (0.1191)  loss_rpn_box_reg: 0.0097 (0.0219)  time: 0.1194  data: 0.0138  max mem: 1059
# Epoch: [0] Total time: 0:00:55 (0.1939 s / it)
# creating index...
# index created!
# Test:  [ 0/61]  eta: 0:00:47  model_time: 0.1779 (0.1779)  evaluator_time: 0.0167 (0.0167)  time: 0.7800  data: 0.5839  max mem: 1059
# Test:  [60/61]  eta: 0:00:00  model_time: 0.0361 (0.0397)  evaluator_time: 0.0016 (0.0019)  time: 0.0455  data: 0.0088  max mem: 1059
# Test: Total time: 0:00:04 (0.0665 s / it)
# Averaged stats: model_time: 0.0361 (0.0397)  evaluator_time: 0.0016 (0.0019)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.255
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.687
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.081
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.259
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.267
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.430
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.430
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.436
# Epoch: [1]  [  0/287]  eta: 0:05:41  lr: 0.005000  loss: 0.5893 (0.5893)  loss_classifier: 0.2683 (0.2683)  loss_box_reg: 0.2341 (0.2341)  loss_objectness: 0.0787 (0.0787)  loss_rpn_box_reg: 0.0082 (0.0082)  time: 1.1887  data: 1.0281  max mem: 1059
# Epoch: [1]  [ 10/287]  eta: 0:01:09  lr: 0.005000  loss: 0.7002 (0.6859)  loss_classifier: 0.3041 (0.2870)  loss_box_reg: 0.3157 (0.3283)  loss_objectness: 0.0538 (0.0552)  loss_rpn_box_reg: 0.0092 (0.0154)  time: 0.2507  data: 0.1145  max mem: 1059
# Epoch: [1]  [ 20/287]  eta: 0:00:56  lr: 0.005000  loss: 0.7002 (0.7161)  loss_classifier: 0.2790 (0.2707)  loss_box_reg: 0.3628 (0.3661)  loss_objectness: 0.0501 (0.0644)  loss_rpn_box_reg: 0.0098 (0.0149)  time: 0.1644  data: 0.0266  max mem: 1059
# Epoch: [1]  [ 30/287]  eta: 0:00:45  lr: 0.005000  loss: 0.6845 (0.7269)  loss_classifier: 0.2696 (0.2743)  loss_box_reg: 0.3628 (0.3680)  loss_objectness: 0.0518 (0.0693)  loss_rpn_box_reg: 0.0130 (0.0153)  time: 0.1390  data: 0.0201  max mem: 1059
# Epoch: [1]  [ 40/287]  eta: 0:00:41  lr: 0.005000  loss: 0.6157 (0.7031)  loss_classifier: 0.2100 (0.2649)  loss_box_reg: 0.3125 (0.3564)  loss_objectness: 0.0517 (0.0674)  loss_rpn_box_reg: 0.0136 (0.0145)  time: 0.1168  data: 0.0132  max mem: 1059
# Epoch: [1]  [ 50/287]  eta: 0:00:38  lr: 0.005000  loss: 0.6034 (0.6956)  loss_classifier: 0.2100 (0.2591)  loss_box_reg: 0.3149 (0.3604)  loss_objectness: 0.0365 (0.0620)  loss_rpn_box_reg: 0.0105 (0.0141)  time: 0.1406  data: 0.0186  max mem: 1059
# Epoch: [1]  [ 60/287]  eta: 0:00:38  lr: 0.005000  loss: 0.6468 (0.6918)  loss_classifier: 0.2423 (0.2613)  loss_box_reg: 0.3244 (0.3548)  loss_objectness: 0.0359 (0.0616)  loss_rpn_box_reg: 0.0115 (0.0142)  time: 0.1803  data: 0.0279  max mem: 1059
# Epoch: [1]  [ 70/287]  eta: 0:00:39  lr: 0.005000  loss: 0.6468 (0.6946)  loss_classifier: 0.2634 (0.2645)  loss_box_reg: 0.3134 (0.3555)  loss_objectness: 0.0460 (0.0607)  loss_rpn_box_reg: 0.0121 (0.0139)  time: 0.2246  data: 0.0455  max mem: 1059
# Epoch: [1]  [ 80/287]  eta: 0:00:37  lr: 0.005000  loss: 0.6205 (0.6962)  loss_classifier: 0.2690 (0.2660)  loss_box_reg: 0.3577 (0.3572)  loss_objectness: 0.0423 (0.0595)  loss_rpn_box_reg: 0.0096 (0.0134)  time: 0.2112  data: 0.0399  max mem: 1059
# Epoch: [1]  [ 90/287]  eta: 0:00:34  lr: 0.005000  loss: 0.7911 (0.7089)  loss_classifier: 0.2910 (0.2699)  loss_box_reg: 0.4060 (0.3649)  loss_objectness: 0.0492 (0.0610)  loss_rpn_box_reg: 0.0082 (0.0131)  time: 0.1539  data: 0.0217  max mem: 1059
# Epoch: [1]  [100/287]  eta: 0:00:31  lr: 0.005000  loss: 0.7509 (0.7080)  loss_classifier: 0.2910 (0.2690)  loss_box_reg: 0.4060 (0.3655)  loss_objectness: 0.0502 (0.0603)  loss_rpn_box_reg: 0.0086 (0.0132)  time: 0.1207  data: 0.0145  max mem: 1059
# Epoch: [1]  [110/287]  eta: 0:00:29  lr: 0.005000  loss: 0.7077 (0.7050)  loss_classifier: 0.2559 (0.2679)  loss_box_reg: 0.3250 (0.3622)  loss_objectness: 0.0544 (0.0615)  loss_rpn_box_reg: 0.0118 (0.0134)  time: 0.1316  data: 0.0170  max mem: 1059
# Epoch: [1]  [120/287]  eta: 0:00:27  lr: 0.005000  loss: 0.7003 (0.7019)  loss_classifier: 0.2478 (0.2668)  loss_box_reg: 0.3250 (0.3592)  loss_objectness: 0.0525 (0.0625)  loss_rpn_box_reg: 0.0130 (0.0134)  time: 0.1372  data: 0.0167  max mem: 1059
# Epoch: [1]  [130/287]  eta: 0:00:25  lr: 0.005000  loss: 0.7003 (0.7042)  loss_classifier: 0.2541 (0.2681)  loss_box_reg: 0.3300 (0.3601)  loss_objectness: 0.0420 (0.0625)  loss_rpn_box_reg: 0.0130 (0.0135)  time: 0.1269  data: 0.0124  max mem: 1059
# Epoch: [1]  [140/287]  eta: 0:00:23  lr: 0.005000  loss: 0.7233 (0.7072)  loss_classifier: 0.2784 (0.2697)  loss_box_reg: 0.3404 (0.3621)  loss_objectness: 0.0401 (0.0621)  loss_rpn_box_reg: 0.0105 (0.0133)  time: 0.1406  data: 0.0192  max mem: 1059
# Epoch: [1]  [150/287]  eta: 0:00:21  lr: 0.005000  loss: 0.6036 (0.6979)  loss_classifier: 0.2307 (0.2661)  loss_box_reg: 0.3339 (0.3572)  loss_objectness: 0.0408 (0.0615)  loss_rpn_box_reg: 0.0105 (0.0132)  time: 0.1328  data: 0.0172  max mem: 1059
# Epoch: [1]  [160/287]  eta: 0:00:19  lr: 0.005000  loss: 0.6027 (0.6938)  loss_classifier: 0.2039 (0.2639)  loss_box_reg: 0.3317 (0.3562)  loss_objectness: 0.0403 (0.0602)  loss_rpn_box_reg: 0.0118 (0.0135)  time: 0.1193  data: 0.0119  max mem: 1059
# Epoch: [1]  [170/287]  eta: 0:00:18  lr: 0.005000  loss: 0.6251 (0.6897)  loss_classifier: 0.2132 (0.2618)  loss_box_reg: 0.3458 (0.3544)  loss_objectness: 0.0381 (0.0601)  loss_rpn_box_reg: 0.0120 (0.0134)  time: 0.1616  data: 0.0191  max mem: 1059
# Epoch: [1]  [180/287]  eta: 0:00:16  lr: 0.005000  loss: 0.6719 (0.6972)  loss_classifier: 0.2402 (0.2654)  loss_box_reg: 0.3401 (0.3588)  loss_objectness: 0.0381 (0.0595)  loss_rpn_box_reg: 0.0118 (0.0136)  time: 0.1823  data: 0.0285  max mem: 1059
# Epoch: [1]  [190/287]  eta: 0:00:15  lr: 0.005000  loss: 0.7473 (0.7002)  loss_classifier: 0.2964 (0.2668)  loss_box_reg: 0.3543 (0.3598)  loss_objectness: 0.0456 (0.0599)  loss_rpn_box_reg: 0.0110 (0.0137)  time: 0.1823  data: 0.0271  max mem: 1059
# Epoch: [1]  [200/287]  eta: 0:00:14  lr: 0.005000  loss: 0.6919 (0.6981)  loss_classifier: 0.2782 (0.2672)  loss_box_reg: 0.3529 (0.3581)  loss_objectness: 0.0434 (0.0592)  loss_rpn_box_reg: 0.0094 (0.0136)  time: 0.1928  data: 0.0263  max mem: 1059
# Epoch: [1]  [210/287]  eta: 0:00:12  lr: 0.005000  loss: 0.5725 (0.6905)  loss_classifier: 0.2390 (0.2646)  loss_box_reg: 0.2564 (0.3538)  loss_objectness: 0.0331 (0.0587)  loss_rpn_box_reg: 0.0094 (0.0135)  time: 0.1825  data: 0.0311  max mem: 1059
# Epoch: [1]  [220/287]  eta: 0:00:10  lr: 0.005000  loss: 0.5891 (0.6906)  loss_classifier: 0.2217 (0.2647)  loss_box_reg: 0.2721 (0.3530)  loss_objectness: 0.0536 (0.0594)  loss_rpn_box_reg: 0.0116 (0.0135)  time: 0.1661  data: 0.0309  max mem: 1059
# Epoch: [1]  [230/287]  eta: 0:00:09  lr: 0.005000  loss: 0.6155 (0.6849)  loss_classifier: 0.2217 (0.2623)  loss_box_reg: 0.3123 (0.3508)  loss_objectness: 0.0536 (0.0584)  loss_rpn_box_reg: 0.0118 (0.0134)  time: 0.1547  data: 0.0231  max mem: 1059
# Epoch: [1]  [240/287]  eta: 0:00:07  lr: 0.005000  loss: 0.5952 (0.6856)  loss_classifier: 0.2255 (0.2633)  loss_box_reg: 0.3123 (0.3503)  loss_objectness: 0.0396 (0.0587)  loss_rpn_box_reg: 0.0090 (0.0133)  time: 0.1603  data: 0.0251  max mem: 1059
# Epoch: [1]  [250/287]  eta: 0:00:05  lr: 0.005000  loss: 0.7314 (0.6904)  loss_classifier: 0.2752 (0.2647)  loss_box_reg: 0.3799 (0.3538)  loss_objectness: 0.0437 (0.0582)  loss_rpn_box_reg: 0.0090 (0.0136)  time: 0.1371  data: 0.0218  max mem: 1059
# Epoch: [1]  [260/287]  eta: 0:00:04  lr: 0.005000  loss: 0.7581 (0.6909)  loss_classifier: 0.2851 (0.2653)  loss_box_reg: 0.3909 (0.3540)  loss_objectness: 0.0380 (0.0580)  loss_rpn_box_reg: 0.0131 (0.0138)  time: 0.1712  data: 0.0215  max mem: 1059
# Epoch: [1]  [270/287]  eta: 0:00:02  lr: 0.005000  loss: 0.6399 (0.6886)  loss_classifier: 0.2459 (0.2644)  loss_box_reg: 0.3377 (0.3523)  loss_objectness: 0.0423 (0.0582)  loss_rpn_box_reg: 0.0131 (0.0137)  time: 0.2258  data: 0.0318  max mem: 1059
# Epoch: [1]  [280/287]  eta: 0:00:01  lr: 0.005000  loss: 0.6204 (0.6885)  loss_classifier: 0.2178 (0.2639)  loss_box_reg: 0.3155 (0.3534)  loss_objectness: 0.0375 (0.0575)  loss_rpn_box_reg: 0.0124 (0.0138)  time: 0.2129  data: 0.0359  max mem: 1059
# Epoch: [1]  [286/287]  eta: 0:00:00  lr: 0.005000  loss: 0.6606 (0.6878)  loss_classifier: 0.2243 (0.2638)  loss_box_reg: 0.3155 (0.3527)  loss_objectness: 0.0404 (0.0576)  loss_rpn_box_reg: 0.0108 (0.0137)  time: 0.1837  data: 0.0277  max mem: 1059
# Epoch: [1] Total time: 0:00:47 (0.1662 s / it)
# creating index...
# index created!
# Test:  [ 0/61]  eta: 0:00:26  model_time: 0.0495 (0.0495)  evaluator_time: 0.0028 (0.0028)  time: 0.4388  data: 0.3847  max mem: 1059
# Test:  [60/61]  eta: 0:00:00  model_time: 0.0252 (0.0259)  evaluator_time: 0.0010 (0.0011)  time: 0.0311  data: 0.0034  max mem: 1059
# Test: Total time: 0:00:02 (0.0423 s / it)
# Averaged stats: model_time: 0.0252 (0.0259)  evaluator_time: 0.0010 (0.0011)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.346
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.739
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.291
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.352
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.379
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.454
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.454
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.461
# Epoch: [2]  [  0/287]  eta: 0:02:42  lr: 0.005000  loss: 0.4772 (0.4772)  loss_classifier: 0.2444 (0.2444)  loss_box_reg: 0.1419 (0.1419)  loss_objectness: 0.0791 (0.0791)  loss_rpn_box_reg: 0.0119 (0.0119)  time: 0.5676  data: 0.4309  max mem: 1059
# Epoch: [2]  [ 10/287]  eta: 0:00:52  lr: 0.005000  loss: 0.5776 (0.5837)  loss_classifier: 0.2295 (0.2319)  loss_box_reg: 0.3211 (0.3086)  loss_objectness: 0.0307 (0.0335)  loss_rpn_box_reg: 0.0102 (0.0097)  time: 0.1887  data: 0.0520  max mem: 1059
# Epoch: [2]  [ 20/287]  eta: 0:00:44  lr: 0.005000  loss: 0.6059 (0.6504)  loss_classifier: 0.2295 (0.2488)  loss_box_reg: 0.3331 (0.3631)  loss_objectness: 0.0230 (0.0298)  loss_rpn_box_reg: 0.0070 (0.0088)  time: 0.1452  data: 0.0187  max mem: 1059
# Epoch: [2]  [ 30/287]  eta: 0:00:38  lr: 0.005000  loss: 0.6112 (0.6321)  loss_classifier: 0.2254 (0.2411)  loss_box_reg: 0.3080 (0.3496)  loss_objectness: 0.0257 (0.0322)  loss_rpn_box_reg: 0.0070 (0.0092)  time: 0.1301  data: 0.0207  max mem: 1059
# Epoch: [2]  [ 40/287]  eta: 0:00:34  lr: 0.005000  loss: 0.6112 (0.6484)  loss_classifier: 0.2118 (0.2455)  loss_box_reg: 0.3080 (0.3614)  loss_objectness: 0.0276 (0.0317)  loss_rpn_box_reg: 0.0096 (0.0099)  time: 0.1127  data: 0.0138  max mem: 1059
# Epoch: [2]  [ 50/287]  eta: 0:00:33  lr: 0.005000  loss: 0.6628 (0.6844)  loss_classifier: 0.2491 (0.2631)  loss_box_reg: 0.3590 (0.3782)  loss_objectness: 0.0229 (0.0325)  loss_rpn_box_reg: 0.0098 (0.0105)  time: 0.1275  data: 0.0114  max mem: 1059
# Epoch: [2]  [ 60/287]  eta: 0:00:37  lr: 0.005000  loss: 0.7405 (0.6932)  loss_classifier: 0.2816 (0.2688)  loss_box_reg: 0.3590 (0.3776)  loss_objectness: 0.0418 (0.0359)  loss_rpn_box_reg: 0.0104 (0.0109)  time: 0.2173  data: 0.0272  max mem: 1059
# Epoch: [2]  [ 70/287]  eta: 0:00:37  lr: 0.005000  loss: 0.6579 (0.6742)  loss_classifier: 0.2629 (0.2628)  loss_box_reg: 0.3151 (0.3628)  loss_objectness: 0.0437 (0.0373)  loss_rpn_box_reg: 0.0108 (0.0113)  time: 0.2498  data: 0.0362  max mem: 1059
# Epoch: [2]  [ 80/287]  eta: 0:00:34  lr: 0.005000  loss: 0.6484 (0.6932)  loss_classifier: 0.2691 (0.2721)  loss_box_reg: 0.3151 (0.3714)  loss_objectness: 0.0391 (0.0384)  loss_rpn_box_reg: 0.0102 (0.0114)  time: 0.1783  data: 0.0257  max mem: 1059
# Epoch: [2]  [ 90/287]  eta: 0:00:32  lr: 0.005000  loss: 0.7990 (0.7028)  loss_classifier: 0.3209 (0.2754)  loss_box_reg: 0.4120 (0.3776)  loss_objectness: 0.0422 (0.0386)  loss_rpn_box_reg: 0.0101 (0.0112)  time: 0.1280  data: 0.0167  max mem: 1059
# Epoch: [2]  [100/287]  eta: 0:00:29  lr: 0.005000  loss: 0.7990 (0.6988)  loss_classifier: 0.2513 (0.2723)  loss_box_reg: 0.3385 (0.3760)  loss_objectness: 0.0411 (0.0387)  loss_rpn_box_reg: 0.0116 (0.0118)  time: 0.1226  data: 0.0149  max mem: 1059
# Epoch: [2]  [110/287]  eta: 0:00:28  lr: 0.005000  loss: 0.7456 (0.7012)  loss_classifier: 0.2467 (0.2717)  loss_box_reg: 0.3937 (0.3785)  loss_objectness: 0.0306 (0.0391)  loss_rpn_box_reg: 0.0125 (0.0120)  time: 0.1409  data: 0.0193  max mem: 1059
# Epoch: [2]  [120/287]  eta: 0:00:26  lr: 0.005000  loss: 0.6930 (0.6997)  loss_classifier: 0.2653 (0.2722)  loss_box_reg: 0.3820 (0.3766)  loss_objectness: 0.0283 (0.0388)  loss_rpn_box_reg: 0.0082 (0.0120)  time: 0.1388  data: 0.0196  max mem: 1059
# Epoch: [2]  [130/287]  eta: 0:00:24  lr: 0.005000  loss: 0.6669 (0.6957)  loss_classifier: 0.2530 (0.2711)  loss_box_reg: 0.3283 (0.3736)  loss_objectness: 0.0283 (0.0391)  loss_rpn_box_reg: 0.0108 (0.0120)  time: 0.1367  data: 0.0189  max mem: 1059
# Epoch: [2]  [140/287]  eta: 0:00:22  lr: 0.005000  loss: 0.5179 (0.6840)  loss_classifier: 0.2289 (0.2668)  loss_box_reg: 0.2750 (0.3657)  loss_objectness: 0.0284 (0.0397)  loss_rpn_box_reg: 0.0102 (0.0118)  time: 0.1347  data: 0.0161  max mem: 1059
# Epoch: [2]  [150/287]  eta: 0:00:21  lr: 0.005000  loss: 0.5179 (0.6793)  loss_classifier: 0.1974 (0.2648)  loss_box_reg: 0.2684 (0.3620)  loss_objectness: 0.0390 (0.0408)  loss_rpn_box_reg: 0.0093 (0.0118)  time: 0.1670  data: 0.0229  max mem: 1059
# Epoch: [2]  [160/287]  eta: 0:00:20  lr: 0.005000  loss: 0.5462 (0.6753)  loss_classifier: 0.2149 (0.2628)  loss_box_reg: 0.2661 (0.3586)  loss_objectness: 0.0473 (0.0423)  loss_rpn_box_reg: 0.0092 (0.0116)  time: 0.2121  data: 0.0331  max mem: 1059
# Epoch: [2]  [170/287]  eta: 0:00:19  lr: 0.005000  loss: 0.6390 (0.6787)  loss_classifier: 0.2296 (0.2641)  loss_box_reg: 0.3546 (0.3616)  loss_objectness: 0.0343 (0.0414)  loss_rpn_box_reg: 0.0090 (0.0116)  time: 0.2218  data: 0.0362  max mem: 1059
# Epoch: [2]  [180/287]  eta: 0:00:17  lr: 0.005000  loss: 0.6363 (0.6769)  loss_classifier: 0.2296 (0.2631)  loss_box_reg: 0.3572 (0.3608)  loss_objectness: 0.0294 (0.0415)  loss_rpn_box_reg: 0.0073 (0.0115)  time: 0.1822  data: 0.0285  max mem: 1059
# Epoch: [2]  [190/287]  eta: 0:00:15  lr: 0.005000  loss: 0.5826 (0.6737)  loss_classifier: 0.2190 (0.2614)  loss_box_reg: 0.3302 (0.3591)  loss_objectness: 0.0436 (0.0417)  loss_rpn_box_reg: 0.0082 (0.0115)  time: 0.1354  data: 0.0180  max mem: 1059
# Epoch: [2]  [200/287]  eta: 0:00:13  lr: 0.005000  loss: 0.5641 (0.6684)  loss_classifier: 0.2059 (0.2591)  loss_box_reg: 0.3096 (0.3557)  loss_objectness: 0.0454 (0.0421)  loss_rpn_box_reg: 0.0082 (0.0115)  time: 0.1392  data: 0.0188  max mem: 1059
# Epoch: [2]  [210/287]  eta: 0:00:12  lr: 0.005000  loss: 0.5579 (0.6679)  loss_classifier: 0.2328 (0.2593)  loss_box_reg: 0.2590 (0.3553)  loss_objectness: 0.0329 (0.0417)  loss_rpn_box_reg: 0.0091 (0.0117)  time: 0.1776  data: 0.0271  max mem: 1059
# Epoch: [2]  [220/287]  eta: 0:00:11  lr: 0.005000  loss: 0.6212 (0.6664)  loss_classifier: 0.2373 (0.2590)  loss_box_reg: 0.3158 (0.3537)  loss_objectness: 0.0313 (0.0420)  loss_rpn_box_reg: 0.0127 (0.0118)  time: 0.2139  data: 0.0387  max mem: 1059
# Epoch: [2]  [230/287]  eta: 0:00:09  lr: 0.005000  loss: 0.6518 (0.6631)  loss_classifier: 0.2285 (0.2579)  loss_box_reg: 0.3158 (0.3517)  loss_objectness: 0.0358 (0.0418)  loss_rpn_box_reg: 0.0121 (0.0118)  time: 0.1677  data: 0.0281  max mem: 1059
# Epoch: [2]  [240/287]  eta: 0:00:07  lr: 0.005000  loss: 0.6281 (0.6653)  loss_classifier: 0.2516 (0.2586)  loss_box_reg: 0.3115 (0.3537)  loss_objectness: 0.0317 (0.0411)  loss_rpn_box_reg: 0.0107 (0.0119)  time: 0.1966  data: 0.0321  max mem: 1059
# Epoch: [2]  [250/287]  eta: 0:00:06  lr: 0.005000  loss: 0.6607 (0.6703)  loss_classifier: 0.2683 (0.2589)  loss_box_reg: 0.3976 (0.3585)  loss_objectness: 0.0275 (0.0409)  loss_rpn_box_reg: 0.0109 (0.0119)  time: 0.2366  data: 0.0448  max mem: 1059
# Epoch: [2]  [260/287]  eta: 0:00:04  lr: 0.005000  loss: 0.7011 (0.6723)  loss_classifier: 0.2560 (0.2594)  loss_box_reg: 0.3976 (0.3591)  loss_objectness: 0.0401 (0.0417)  loss_rpn_box_reg: 0.0109 (0.0120)  time: 0.1745  data: 0.0300  max mem: 1059
# Epoch: [2]  [270/287]  eta: 0:00:02  lr: 0.005000  loss: 0.5730 (0.6684)  loss_classifier: 0.2103 (0.2575)  loss_box_reg: 0.2842 (0.3569)  loss_objectness: 0.0525 (0.0421)  loss_rpn_box_reg: 0.0123 (0.0120)  time: 0.1462  data: 0.0204  max mem: 1059
# Epoch: [2]  [280/287]  eta: 0:00:01  lr: 0.005000  loss: 0.5640 (0.6696)  loss_classifier: 0.2051 (0.2576)  loss_box_reg: 0.2878 (0.3578)  loss_objectness: 0.0391 (0.0420)  loss_rpn_box_reg: 0.0098 (0.0121)  time: 0.1357  data: 0.0171  max mem: 1059
# Epoch: [2]  [286/287]  eta: 0:00:00  lr: 0.005000  loss: 0.6361 (0.6693)  loss_classifier: 0.2180 (0.2571)  loss_box_reg: 0.2976 (0.3582)  loss_objectness: 0.0366 (0.0418)  loss_rpn_box_reg: 0.0079 (0.0121)  time: 0.1211  data: 0.0135  max mem: 1059
# Epoch: [2] Total time: 0:00:47 (0.1660 s / it)
# creating index...
# index created!
# Test:  [ 0/61]  eta: 0:00:27  model_time: 0.0446 (0.0446)  evaluator_time: 0.0018 (0.0018)  time: 0.4491  data: 0.4011  max mem: 1059
# Test:  [60/61]  eta: 0:00:00  model_time: 0.0235 (0.0258)  evaluator_time: 0.0011 (0.0011)  time: 0.0297  data: 0.0036  max mem: 1059
# Test: Total time: 0:00:02 (0.0428 s / it)
# Averaged stats: model_time: 0.0235 (0.0258)  evaluator_time: 0.0011 (0.0011)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.383
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.805
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.295
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.390
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.422
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.499
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.499
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.506
# Epoch: [3]  [  0/287]  eta: 0:05:31  lr: 0.000500  loss: 0.6091 (0.6091)  loss_classifier: 0.2355 (0.2355)  loss_box_reg: 0.3336 (0.3336)  loss_objectness: 0.0274 (0.0274)  loss_rpn_box_reg: 0.0126 (0.0126)  time: 1.1551  data: 0.9505  max mem: 1059
# Epoch: [3]  [ 10/287]  eta: 0:00:58  lr: 0.000500  loss: 0.5093 (0.5563)  loss_classifier: 0.1922 (0.2107)  loss_box_reg: 0.2719 (0.3069)  loss_objectness: 0.0274 (0.0295)  loss_rpn_box_reg: 0.0094 (0.0092)  time: 0.2108  data: 0.0986  max mem: 1059
# Epoch: [3]  [ 20/287]  eta: 0:00:51  lr: 0.000500  loss: 0.5522 (0.6001)  loss_classifier: 0.1978 (0.2204)  loss_box_reg: 0.2892 (0.3408)  loss_objectness: 0.0235 (0.0289)  loss_rpn_box_reg: 0.0094 (0.0100)  time: 0.1455  data: 0.0197  max mem: 1059
# Epoch: [3]  [ 30/287]  eta: 0:00:51  lr: 0.000500  loss: 0.6121 (0.6109)  loss_classifier: 0.2179 (0.2215)  loss_box_reg: 0.3552 (0.3518)  loss_objectness: 0.0233 (0.0263)  loss_rpn_box_reg: 0.0104 (0.0113)  time: 0.1943  data: 0.0324  max mem: 1059
# Epoch: [3]  [ 40/287]  eta: 0:00:48  lr: 0.000500  loss: 0.6121 (0.6124)  loss_classifier: 0.2052 (0.2210)  loss_box_reg: 0.3550 (0.3547)  loss_objectness: 0.0236 (0.0260)  loss_rpn_box_reg: 0.0080 (0.0106)  time: 0.1986  data: 0.0324  max mem: 1059
# Epoch: [3]  [ 50/287]  eta: 0:00:44  lr: 0.000500  loss: 0.5476 (0.6234)  loss_classifier: 0.2096 (0.2310)  loss_box_reg: 0.3151 (0.3551)  loss_objectness: 0.0260 (0.0268)  loss_rpn_box_reg: 0.0080 (0.0104)  time: 0.1666  data: 0.0247  max mem: 1059
# Epoch: [3]  [ 60/287]  eta: 0:00:40  lr: 0.000500  loss: 0.5899 (0.6177)  loss_classifier: 0.2096 (0.2275)  loss_box_reg: 0.3184 (0.3519)  loss_objectness: 0.0287 (0.0280)  loss_rpn_box_reg: 0.0097 (0.0102)  time: 0.1400  data: 0.0190  max mem: 1059
# Epoch: [3]  [ 70/287]  eta: 0:00:37  lr: 0.000500  loss: 0.5383 (0.6075)  loss_classifier: 0.2004 (0.2247)  loss_box_reg: 0.3303 (0.3450)  loss_objectness: 0.0263 (0.0273)  loss_rpn_box_reg: 0.0082 (0.0105)  time: 0.1403  data: 0.0209  max mem: 1059
# Epoch: [3]  [ 80/287]  eta: 0:00:35  lr: 0.000500  loss: 0.5268 (0.5937)  loss_classifier: 0.2004 (0.2215)  loss_box_reg: 0.2768 (0.3348)  loss_objectness: 0.0195 (0.0269)  loss_rpn_box_reg: 0.0082 (0.0104)  time: 0.1541  data: 0.0230  max mem: 1059
# Epoch: [3]  [ 90/287]  eta: 0:00:34  lr: 0.000500  loss: 0.5090 (0.5963)  loss_classifier: 0.2100 (0.2212)  loss_box_reg: 0.2746 (0.3380)  loss_objectness: 0.0170 (0.0266)  loss_rpn_box_reg: 0.0085 (0.0105)  time: 0.1827  data: 0.0284  max mem: 1059
# Epoch: [3]  [100/287]  eta: 0:00:31  lr: 0.000500  loss: 0.5459 (0.5992)  loss_classifier: 0.2154 (0.2236)  loss_box_reg: 0.3291 (0.3382)  loss_objectness: 0.0174 (0.0271)  loss_rpn_box_reg: 0.0076 (0.0103)  time: 0.1678  data: 0.0287  max mem: 1059
# Epoch: [3]  [110/287]  eta: 0:00:29  lr: 0.000500  loss: 0.5455 (0.5922)  loss_classifier: 0.2154 (0.2219)  loss_box_reg: 0.2722 (0.3324)  loss_objectness: 0.0270 (0.0275)  loss_rpn_box_reg: 0.0076 (0.0104)  time: 0.1183  data: 0.0157  max mem: 1059
# Epoch: [3]  [120/287]  eta: 0:00:27  lr: 0.000500  loss: 0.5605 (0.6032)  loss_classifier: 0.2157 (0.2250)  loss_box_reg: 0.3127 (0.3407)  loss_objectness: 0.0189 (0.0271)  loss_rpn_box_reg: 0.0086 (0.0104)  time: 0.1341  data: 0.0182  max mem: 1059
# Epoch: [3]  [130/287]  eta: 0:00:25  lr: 0.000500  loss: 0.6179 (0.6048)  loss_classifier: 0.2517 (0.2283)  loss_box_reg: 0.3184 (0.3391)  loss_objectness: 0.0179 (0.0272)  loss_rpn_box_reg: 0.0085 (0.0102)  time: 0.1643  data: 0.0272  max mem: 1059
# Epoch: [3]  [140/287]  eta: 0:00:25  lr: 0.000500  loss: 0.5056 (0.6015)  loss_classifier: 0.1957 (0.2257)  loss_box_reg: 0.2867 (0.3382)  loss_objectness: 0.0288 (0.0274)  loss_rpn_box_reg: 0.0086 (0.0102)  time: 0.2153  data: 0.0360  max mem: 1059
# Epoch: [3]  [150/287]  eta: 0:00:23  lr: 0.000500  loss: 0.5361 (0.6056)  loss_classifier: 0.1828 (0.2259)  loss_box_reg: 0.3169 (0.3424)  loss_objectness: 0.0289 (0.0272)  loss_rpn_box_reg: 0.0085 (0.0101)  time: 0.2190  data: 0.0352  max mem: 1059
# Epoch: [3]  [160/287]  eta: 0:00:22  lr: 0.000500  loss: 0.5688 (0.6039)  loss_classifier: 0.2068 (0.2262)  loss_box_reg: 0.3230 (0.3407)  loss_objectness: 0.0197 (0.0272)  loss_rpn_box_reg: 0.0066 (0.0099)  time: 0.1889  data: 0.0312  max mem: 1059
# Epoch: [3]  [170/287]  eta: 0:00:20  lr: 0.000500  loss: 0.5497 (0.6017)  loss_classifier: 0.2018 (0.2247)  loss_box_reg: 0.2930 (0.3404)  loss_objectness: 0.0177 (0.0269)  loss_rpn_box_reg: 0.0058 (0.0098)  time: 0.1838  data: 0.0320  max mem: 1059
# Epoch: [3]  [180/287]  eta: 0:00:18  lr: 0.000500  loss: 0.5502 (0.6028)  loss_classifier: 0.2018 (0.2251)  loss_box_reg: 0.2819 (0.3414)  loss_objectness: 0.0161 (0.0266)  loss_rpn_box_reg: 0.0055 (0.0097)  time: 0.1393  data: 0.0218  max mem: 1059
# Epoch: [3]  [190/287]  eta: 0:00:16  lr: 0.000500  loss: 0.5058 (0.5976)  loss_classifier: 0.2033 (0.2242)  loss_box_reg: 0.2561 (0.3373)  loss_objectness: 0.0142 (0.0264)  loss_rpn_box_reg: 0.0058 (0.0096)  time: 0.1177  data: 0.0149  max mem: 1059
# Epoch: [3]  [200/287]  eta: 0:00:14  lr: 0.000500  loss: 0.5058 (0.5962)  loss_classifier: 0.1938 (0.2231)  loss_box_reg: 0.2733 (0.3373)  loss_objectness: 0.0177 (0.0262)  loss_rpn_box_reg: 0.0061 (0.0095)  time: 0.1139  data: 0.0144  max mem: 1059
# Epoch: [3]  [210/287]  eta: 0:00:12  lr: 0.000500  loss: 0.5300 (0.5951)  loss_classifier: 0.1938 (0.2223)  loss_box_reg: 0.2959 (0.3373)  loss_objectness: 0.0187 (0.0262)  loss_rpn_box_reg: 0.0053 (0.0094)  time: 0.1216  data: 0.0146  max mem: 1059
# Epoch: [3]  [220/287]  eta: 0:00:10  lr: 0.000500  loss: 0.5390 (0.5946)  loss_classifier: 0.1973 (0.2221)  loss_box_reg: 0.3386 (0.3375)  loss_objectness: 0.0117 (0.0257)  loss_rpn_box_reg: 0.0048 (0.0092)  time: 0.1502  data: 0.0183  max mem: 1059
# Epoch: [3]  [230/287]  eta: 0:00:09  lr: 0.000500  loss: 0.5378 (0.5928)  loss_classifier: 0.1809 (0.2224)  loss_box_reg: 0.3338 (0.3355)  loss_objectness: 0.0139 (0.0257)  loss_rpn_box_reg: 0.0064 (0.0092)  time: 0.1985  data: 0.0299  max mem: 1059
# Epoch: [3]  [240/287]  eta: 0:00:08  lr: 0.000500  loss: 0.5481 (0.5980)  loss_classifier: 0.1986 (0.2236)  loss_box_reg: 0.3329 (0.3397)  loss_objectness: 0.0164 (0.0256)  loss_rpn_box_reg: 0.0064 (0.0091)  time: 0.2491  data: 0.0454  max mem: 1059
# Epoch: [3]  [250/287]  eta: 0:00:06  lr: 0.000500  loss: 0.5707 (0.5947)  loss_classifier: 0.2138 (0.2230)  loss_box_reg: 0.3100 (0.3370)  loss_objectness: 0.0263 (0.0258)  loss_rpn_box_reg: 0.0053 (0.0090)  time: 0.2017  data: 0.0365  max mem: 1059
# Epoch: [3]  [260/287]  eta: 0:00:04  lr: 0.000500  loss: 0.5418 (0.5939)  loss_classifier: 0.1967 (0.2236)  loss_box_reg: 0.2728 (0.3355)  loss_objectness: 0.0228 (0.0257)  loss_rpn_box_reg: 0.0053 (0.0090)  time: 0.1420  data: 0.0199  max mem: 1059
# Epoch: [3]  [270/287]  eta: 0:00:02  lr: 0.000500  loss: 0.5928 (0.5996)  loss_classifier: 0.2332 (0.2249)  loss_box_reg: 0.3422 (0.3401)  loss_objectness: 0.0194 (0.0257)  loss_rpn_box_reg: 0.0051 (0.0089)  time: 0.1430  data: 0.0190  max mem: 1059
# Epoch: [3]  [280/287]  eta: 0:00:01  lr: 0.000500  loss: 0.6689 (0.6004)  loss_classifier: 0.2589 (0.2250)  loss_box_reg: 0.3473 (0.3407)  loss_objectness: 0.0189 (0.0258)  loss_rpn_box_reg: 0.0054 (0.0090)  time: 0.1386  data: 0.0186  max mem: 1059
# Epoch: [3]  [286/287]  eta: 0:00:00  lr: 0.000500  loss: 0.4817 (0.5975)  loss_classifier: 0.1735 (0.2239)  loss_box_reg: 0.2700 (0.3390)  loss_objectness: 0.0138 (0.0256)  loss_rpn_box_reg: 0.0046 (0.0089)  time: 0.1271  data: 0.0186  max mem: 1059
# Epoch: [3] Total time: 0:00:47 (0.1666 s / it)
# creating index...
# index created!
# Test:  [ 0/61]  eta: 0:00:26  model_time: 0.0717 (0.0717)  evaluator_time: 0.0020 (0.0020)  time: 0.4419  data: 0.3663  max mem: 1059
# Test:  [60/61]  eta: 0:00:00  model_time: 0.0251 (0.0268)  evaluator_time: 0.0010 (0.0011)  time: 0.0309  data: 0.0039  max mem: 1059
# Test: Total time: 0:00:02 (0.0437 s / it)
# Averaged stats: model_time: 0.0251 (0.0268)  evaluator_time: 0.0010 (0.0011)
# Accumulating evaluation results...
# DONE (t=0.01s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.502
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.838
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.521
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.509
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.496
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.572
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.572
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.580
# Epoch: [4]  [  0/287]  eta: 0:03:56  lr: 0.000500  loss: 0.2618 (0.2618)  loss_classifier: 0.0991 (0.0991)  loss_box_reg: 0.1460 (0.1460)  loss_objectness: 0.0144 (0.0144)  loss_rpn_box_reg: 0.0023 (0.0023)  time: 0.8225  data: 0.5320  max mem: 1059
# Epoch: [4]  [ 10/287]  eta: 0:01:30  lr: 0.000500  loss: 0.5823 (0.5284)  loss_classifier: 0.2039 (0.1944)  loss_box_reg: 0.3152 (0.3015)  loss_objectness: 0.0217 (0.0246)  loss_rpn_box_reg: 0.0088 (0.0081)  time: 0.3276  data: 0.1283  max mem: 1059
# Epoch: [4]  [ 20/287]  eta: 0:01:13  lr: 0.000500  loss: 0.5155 (0.5091)  loss_classifier: 0.2025 (0.1876)  loss_box_reg: 0.3077 (0.2912)  loss_objectness: 0.0155 (0.0215)  loss_rpn_box_reg: 0.0089 (0.0089)  time: 0.2485  data: 0.0649  max mem: 1059
# Epoch: [4]  [ 30/287]  eta: 0:01:04  lr: 0.000500  loss: 0.4107 (0.5063)  loss_classifier: 0.1506 (0.1894)  loss_box_reg: 0.2335 (0.2865)  loss_objectness: 0.0153 (0.0219)  loss_rpn_box_reg: 0.0065 (0.0084)  time: 0.2113  data: 0.0334  max mem: 1059
# Epoch: [4]  [ 40/287]  eta: 0:00:57  lr: 0.000500  loss: 0.4107 (0.5074)  loss_classifier: 0.1720 (0.1903)  loss_box_reg: 0.2335 (0.2876)  loss_objectness: 0.0154 (0.0218)  loss_rpn_box_reg: 0.0060 (0.0077)  time: 0.1869  data: 0.0314  max mem: 1059
# Epoch: [4]  [ 50/287]  eta: 0:00:49  lr: 0.000500  loss: 0.5127 (0.5229)  loss_classifier: 0.1914 (0.1944)  loss_box_reg: 0.2834 (0.2996)  loss_objectness: 0.0210 (0.0210)  loss_rpn_box_reg: 0.0049 (0.0079)  time: 0.1388  data: 0.0243  max mem: 1059
# Epoch: [4]  [ 60/287]  eta: 0:00:44  lr: 0.000500  loss: 0.5402 (0.5392)  loss_classifier: 0.2083 (0.2030)  loss_box_reg: 0.3153 (0.3060)  loss_objectness: 0.0210 (0.0221)  loss_rpn_box_reg: 0.0068 (0.0081)  time: 0.1189  data: 0.0130  max mem: 1059
# Epoch: [4]  [ 70/287]  eta: 0:00:42  lr: 0.000500  loss: 0.6132 (0.5562)  loss_classifier: 0.2083 (0.2085)  loss_box_reg: 0.3633 (0.3175)  loss_objectness: 0.0210 (0.0217)  loss_rpn_box_reg: 0.0081 (0.0084)  time: 0.1616  data: 0.0222  max mem: 1059
# Epoch: [4]  [ 80/287]  eta: 0:00:39  lr: 0.000500  loss: 0.5065 (0.5517)  loss_classifier: 0.1952 (0.2077)  loss_box_reg: 0.2865 (0.3142)  loss_objectness: 0.0132 (0.0212)  loss_rpn_box_reg: 0.0074 (0.0085)  time: 0.1749  data: 0.0292  max mem: 1059
# Epoch: [4]  [ 90/287]  eta: 0:00:36  lr: 0.000500  loss: 0.5044 (0.5589)  loss_classifier: 0.1993 (0.2100)  loss_box_reg: 0.2865 (0.3202)  loss_objectness: 0.0143 (0.0207)  loss_rpn_box_reg: 0.0054 (0.0081)  time: 0.1475  data: 0.0267  max mem: 1059
# Epoch: [4]  [100/287]  eta: 0:00:34  lr: 0.000500  loss: 0.5044 (0.5581)  loss_classifier: 0.2283 (0.2104)  loss_box_reg: 0.2943 (0.3193)  loss_objectness: 0.0156 (0.0203)  loss_rpn_box_reg: 0.0047 (0.0081)  time: 0.1687  data: 0.0258  max mem: 1059
# Epoch: [4]  [110/287]  eta: 0:00:33  lr: 0.000500  loss: 0.4378 (0.5561)  loss_classifier: 0.2091 (0.2087)  loss_box_reg: 0.2296 (0.3188)  loss_objectness: 0.0168 (0.0205)  loss_rpn_box_reg: 0.0074 (0.0082)  time: 0.2120  data: 0.0334  max mem: 1059
# Epoch: [4]  [120/287]  eta: 0:00:31  lr: 0.000500  loss: 0.5001 (0.5560)  loss_classifier: 0.1784 (0.2106)  loss_box_reg: 0.2349 (0.3167)  loss_objectness: 0.0207 (0.0205)  loss_rpn_box_reg: 0.0088 (0.0082)  time: 0.1951  data: 0.0328  max mem: 1059
# Epoch: [4]  [130/287]  eta: 0:00:28  lr: 0.000500  loss: 0.5154 (0.5584)  loss_classifier: 0.2047 (0.2118)  loss_box_reg: 0.2789 (0.3175)  loss_objectness: 0.0211 (0.0210)  loss_rpn_box_reg: 0.0081 (0.0082)  time: 0.1354  data: 0.0187  max mem: 1059
# Epoch: [4]  [140/287]  eta: 0:00:26  lr: 0.000500  loss: 0.5693 (0.5568)  loss_classifier: 0.1974 (0.2109)  loss_box_reg: 0.3104 (0.3172)  loss_objectness: 0.0160 (0.0205)  loss_rpn_box_reg: 0.0048 (0.0083)  time: 0.1167  data: 0.0126  max mem: 1059
# Epoch: [4]  [150/287]  eta: 0:00:23  lr: 0.000500  loss: 0.5391 (0.5518)  loss_classifier: 0.1905 (0.2095)  loss_box_reg: 0.2778 (0.3136)  loss_objectness: 0.0143 (0.0205)  loss_rpn_box_reg: 0.0064 (0.0082)  time: 0.1248  data: 0.0141  max mem: 1060
# Epoch: [4]  [160/287]  eta: 0:00:21  lr: 0.000500  loss: 0.5484 (0.5584)  loss_classifier: 0.2064 (0.2102)  loss_box_reg: 0.3116 (0.3190)  loss_objectness: 0.0225 (0.0209)  loss_rpn_box_reg: 0.0073 (0.0083)  time: 0.1157  data: 0.0140  max mem: 1060
# Epoch: [4]  [170/287]  eta: 0:00:19  lr: 0.000500  loss: 0.5595 (0.5564)  loss_classifier: 0.2046 (0.2094)  loss_box_reg: 0.3293 (0.3172)  loss_objectness: 0.0241 (0.0216)  loss_rpn_box_reg: 0.0078 (0.0083)  time: 0.1318  data: 0.0153  max mem: 1060
# Epoch: [4]  [180/287]  eta: 0:00:17  lr: 0.000500  loss: 0.5378 (0.5630)  loss_classifier: 0.1990 (0.2116)  loss_box_reg: 0.2963 (0.3218)  loss_objectness: 0.0156 (0.0213)  loss_rpn_box_reg: 0.0080 (0.0083)  time: 0.1523  data: 0.0212  max mem: 1060
# Epoch: [4]  [190/287]  eta: 0:00:16  lr: 0.000500  loss: 0.5105 (0.5626)  loss_classifier: 0.2045 (0.2122)  loss_box_reg: 0.2878 (0.3209)  loss_objectness: 0.0152 (0.0212)  loss_rpn_box_reg: 0.0076 (0.0083)  time: 0.1359  data: 0.0177  max mem: 1060
# Epoch: [4]  [200/287]  eta: 0:00:14  lr: 0.000500  loss: 0.4947 (0.5674)  loss_classifier: 0.2045 (0.2140)  loss_box_reg: 0.2642 (0.3237)  loss_objectness: 0.0176 (0.0215)  loss_rpn_box_reg: 0.0050 (0.0082)  time: 0.1388  data: 0.0162  max mem: 1060
# Epoch: [4]  [210/287]  eta: 0:00:12  lr: 0.000500  loss: 0.5116 (0.5662)  loss_classifier: 0.1952 (0.2126)  loss_box_reg: 0.3054 (0.3244)  loss_objectness: 0.0112 (0.0209)  loss_rpn_box_reg: 0.0056 (0.0082)  time: 0.1687  data: 0.0289  max mem: 1060
# Epoch: [4]  [220/287]  eta: 0:00:11  lr: 0.000500  loss: 0.4854 (0.5630)  loss_classifier: 0.1631 (0.2106)  loss_box_reg: 0.2910 (0.3232)  loss_objectness: 0.0112 (0.0210)  loss_rpn_box_reg: 0.0065 (0.0081)  time: 0.1606  data: 0.0293  max mem: 1060
# Epoch: [4]  [230/287]  eta: 0:00:09  lr: 0.000500  loss: 0.4607 (0.5622)  loss_classifier: 0.1561 (0.2098)  loss_box_reg: 0.2838 (0.3236)  loss_objectness: 0.0169 (0.0208)  loss_rpn_box_reg: 0.0064 (0.0081)  time: 0.1787  data: 0.0263  max mem: 1060
# Epoch: [4]  [240/287]  eta: 0:00:07  lr: 0.000500  loss: 0.4550 (0.5570)  loss_classifier: 0.1559 (0.2072)  loss_box_reg: 0.2707 (0.3209)  loss_objectness: 0.0169 (0.0208)  loss_rpn_box_reg: 0.0064 (0.0081)  time: 0.1896  data: 0.0288  max mem: 1060
# Epoch: [4]  [250/287]  eta: 0:00:06  lr: 0.000500  loss: 0.4928 (0.5591)  loss_classifier: 0.1721 (0.2079)  loss_box_reg: 0.2628 (0.3227)  loss_objectness: 0.0117 (0.0204)  loss_rpn_box_reg: 0.0047 (0.0080)  time: 0.1667  data: 0.0272  max mem: 1060
# Epoch: [4]  [260/287]  eta: 0:00:04  lr: 0.000500  loss: 0.5760 (0.5640)  loss_classifier: 0.1997 (0.2092)  loss_box_reg: 0.3835 (0.3262)  loss_objectness: 0.0117 (0.0206)  loss_rpn_box_reg: 0.0070 (0.0081)  time: 0.1596  data: 0.0243  max mem: 1060
# Epoch: [4]  [270/287]  eta: 0:00:02  lr: 0.000500  loss: 0.5743 (0.5636)  loss_classifier: 0.1939 (0.2085)  loss_box_reg: 0.3409 (0.3264)  loss_objectness: 0.0154 (0.0206)  loss_rpn_box_reg: 0.0085 (0.0081)  time: 0.1414  data: 0.0202  max mem: 1060
# Epoch: [4]  [280/287]  eta: 0:00:01  lr: 0.000500  loss: 0.5462 (0.5646)  loss_classifier: 0.2083 (0.2090)  loss_box_reg: 0.2766 (0.3269)  loss_objectness: 0.0133 (0.0207)  loss_rpn_box_reg: 0.0059 (0.0081)  time: 0.1486  data: 0.0198  max mem: 1060
# Epoch: [4]  [286/287]  eta: 0:00:00  lr: 0.000500  loss: 0.6527 (0.5690)  loss_classifier: 0.2252 (0.2103)  loss_box_reg: 0.3519 (0.3300)  loss_objectness: 0.0131 (0.0206)  loss_rpn_box_reg: 0.0059 (0.0081)  time: 0.1353  data: 0.0171  max mem: 1060
# Epoch: [4] Total time: 0:00:47 (0.1650 s / it)
# creating index...
# index created!
# Test:  [ 0/61]  eta: 0:00:26  model_time: 0.0683 (0.0683)  evaluator_time: 0.0019 (0.0019)  time: 0.4424  data: 0.3703  max mem: 1060
# Test:  [60/61]  eta: 0:00:00  model_time: 0.0382 (0.0347)  evaluator_time: 0.0015 (0.0014)  time: 0.0511  data: 0.0086  max mem: 1060
# Test: Total time: 0:00:03 (0.0592 s / it)
# Averaged stats: model_time: 0.0382 (0.0347)  evaluator_time: 0.0015 (0.0014)
# Accumulating evaluation results...
# DONE (t=0.02s).
# IoU metric: bbox
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.499
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.846
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.508
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.506
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.503
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.561
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.561
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = -1.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.000
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.570
# That's it!
# Saving
# Saved
